# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from calc import (
    generate_coproduct_lci,
    read_data,
    # calc,
    postprocess,
    generate_final_lci,
    generate_coproduct_lci,
    data_check,
    # calculate_allocation_ratio,
    # allocation,
)
# from allocation import calculate_allocation_ratio, format_input
from utils import (
    biorefinery_conversion, display_units, energy, mass, calculate_lca, emission_factor, primary_units, unit_conversion, metrics, 
    mass_to_energy, convert_transport_lci, properties, metric_units, combined_ci_table, end_use
)
import numpy as np
import plotly.express as px

# %%
def generate_carbon_credit(cprice, cunit, main_product_category, fossil_ghg, biofuel_ghg):
    '''
    Calcualte carbon credits
    '''
    cunit = cunit[2:]
    cprice = cprice * mass.loc[cunit, metric_units['GHG']]    # Calculate carbon price in $/g
    
    fuel_credit = cprice * (fossil_ghg - biofuel_ghg)    # calculate carbon credit, the results are in $/MJ for fuels
    
    if main_product_category in ['Process fuel']:
        fuel_credit = fuel_credit * energy.loc['MJ', 'GGE']    # calculate carbon credit in $/GGE for fuels
        
    return fuel_credit
    
    # df_conversion = pd.DataFrame(
    #         {
    #             "Input Amount": [1, 1],
    #             "Unit": [cunit, bunit],
    #             "Primary Unit": [display_units[main_product_category]] * 2,
    #             "Resource": [main_incumbent_resource, main_product_resource],
    #         }
    #     )
    #     df_conversion = pd.merge(
    #         df_conversion, properties, left_on="Resource", right_index=True, how="left"
    #     )
    #     f_conversion_ratio, b_conversion_ratio = df_conversion.apply(
    #         unit_conversion, axis=1
    #     ).values

# %%
generate_carbon_credit(200, '$/metric ton', 'Process Fuel', 90, 20)
# Out:
# 0.013999999999999999

# %%
coproduct_res = pd.DataFrame()
lci_mapping, coproduct_mapping, final_process_mapping = read_data(
        # "2021 Biochem SOT via BDO_working.xlsm"
        # "Feedstock test2-with INL data.xlsm"
    # "static/biochemical conversion via BDO.xlsm"
        # "sludge HTL3.xlsm"
    "static/Algae HTL.xlsm"
    )
updated_coproduct_mapping = coproduct_mapping.copy()
overall_lci, final_process = generate_final_lci(
    lci_mapping, updated_coproduct_mapping, final_process_mapping, True, apply_loss_factor=True
)
# res_new = postprocess(calculate_lca(overall_lci, False))
# coproduct_lci = generate_coproduct_lci(
#     lci_mapping, updated_coproduct_mapping, final_process_mapping
# )
# if coproduct_lci is not None:
#     coproduct_res = postprocess(calculate_lca(coproduct_lci, False))
    
# res_new = res_new[
#         ~res_new["Pathway"].str.contains("Incumbent")
#     ]

# %%
test = calculate_lca(overall_lci, False)

# %%
test.to_csv('tt.csv')

# %%
res_new['GHG_Sum'].sum()/907.18474
# Out:
# 356.16439727996186

# %%
ng = pd.Series({'Input Amount': 15.48781362465110000,
               'Unit': 'kg',
               'Primary Unit': 'mmBTU',
               'LHV': 47.1418136613636,
               'Density': 0.776922656678549})
unit_conversion(ng)
# Out:
# 0.6920236724105463

# %%
res_new.to_csv('testing.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 res_new.to_csv('testing.csv', index=False)
#
# File ~/.local/share/virtualenvs/Interactive-SCSA_Dash-1VXIutmm/lib/python3.9/site-packages/pandas/core/generic.py:3563, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3552 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3554 formatter = DataFrameFormatter(
#    3555     frame=df,
#    3556     header=header,
#    (...)
#    3560     decimal=decimal,
#    3561 )
# -> 3563 return DataFrameRenderer(formatter).to_csv(
#    3564     path_or_buf,
#    3565     line_terminator=line_terminator,
#    3566     sep=sep,
#    3567     encoding=encoding,
#    3568     errors=errors,
#    3569     compression=compression,
#    3570     quoting=quoting,
#    3571     columns=columns,
#    3572     index_label=index_label,
#    3573     mode=mode,
#    3574     chunksize=chunksize,
#    3575     quotechar=quotechar,
#    3576     date_format=date_format,
#    3577     doublequote=doublequote,
#    3578     escapechar=escapechar,
#    3579     storage_options=storage_options,
#    3580 )
#
# File ~/.local/share/virtualenvs/Interactive-SCSA_Dash-1VXIutmm/lib/python3.9/site-packages/pandas/io/formats/format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~/.local/share/virtualenvs/Interactive-SCSA_Dash-1VXIutmm/lib/python3.9/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/.local/share/virtualenvs/Interactive-SCSA_Dash-1VXIutmm/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'testing.csv'

# %%
res_new['GHG_Sum'].sum()

# %%
def calculate_lca2(df_lci, include_incumbent=True):
    """
    Calculate LCA results from LCI

    Parameters:
        df_lci: LCI table
        include_incumbent: whether to include the incumbent product in the result dataframe.
    """

    # df_lci["ID"] = df_lci["ID"].str.lower()
    # res = pd.merge(df_lci, lookup_table, left_on="ID", right_index=True, how="left")
    # res["Primary Unit"] = res["Primary Unit"].str.lower()

    if include_incumbent:
        # Separate out the incumbent product that the main product is compared with
        incumbent_resource = (
            df_lci.loc[df_lci["Type"] == "Main Product", "Incumbent Product"]
            # .fillna("")
            .values[0]
        )
        incumbent_end_use = (
            df_lci.loc[df_lci["Type"] == "Main Product", "End Use of Incumbent Product"]
            # .fillna("")
            .values[0]
        )
        incumbent_category = df_lci.loc[
            df_lci["Type"] == "Main Product", "Category"
        ].values[0]

        main_product = df_lci.loc[df_lci["Type"] == "Main Product", "Resource"].values[
            0
        ]
        df_lci["Pathway"] = main_product.title() + " (Modeled)"

        df_incumbent = pd.DataFrame(
            {
                "Pathway": [incumbent_resource.title() + " (Incumbent)"],
                "Type": ["Input"],
                "Category": [incumbent_category],
                "Resource": [incumbent_resource],
                "Process": [incumbent_resource + " (Incumbent)"],
                "End Use": [incumbent_end_use],
                "Amount": [1],
                "Unit": [primary_units[incumbent_category]],
            }
        )
        df_lci = pd.concat([df_lci, df_incumbent])
        # return df_lci
    df_emission_factor = df_lci.apply(emission_factor, axis=1)
    res = pd.concat([df_lci, df_emission_factor], axis=1)
    # res["Primary Unit"] = res["Category"].map(primary_units).str.lower()
    res["Primary Unit"] = res["Category"].map(primary_units)

    # res["Unit"] = res["Unit"].str.lower()
    res["Resource"] = res["Resource"].str.lower()

    # res["CO2 (w/ C in VOC & CO)"] = (
    #     res["CO2"]
    #     + res["CO"] * co_carbon / co2_carbon
    #     + res["VOC"] * voc_carbon / co2_carbon
    # )
    # res["GHG"] = (
    #     res["CO2 (w/ C in VOC & CO)"] * co2_gwp
    #     + res["Biogenic CO2"] * co2_gwp
    #     + res["CH4"] * ch4_gwp
    #     + res["N2O"] * n2o_gwp
    # )

    # Do unit conversion before calculation
    res = res.rename(columns={"Amount": "Input Amount"})
    return res
    res["Amount"] = res.apply(unit_conversion, axis=1)
    res["Unit"] = res["Primary Unit"]
    res["Amount"] = (
        res["Amount"] / res.loc[res["Type"] == "Main Product", "Amount"].sum()
    )
    if include_incumbent:
        res.loc[res["Pathway"].str.contains("Incumbent"), "Amount"] = 1
    # res = res[res["Type"] != "Main Product"]
    main_product_category = res.loc[res["Type"] == "Main Product", "Category"].values[0]
    calculation_unit = primary_units[main_product_category]
    target_unit = display_units[main_product_category]

    for metric in metrics:
        res[metric + "_Sum"] = res["Amount"] * res[metric]

    # Use MJ as the unit of energy metrics
    for metric in [
        "Total energy, Btu",
        "Fossil fuels, Btu",
        "Coal, Btu",
        "Natural gas, Btu",
        "Petroleum, Btu",
    ]:
        res[metric + "_Sum"] = res[metric + "_Sum"] * energy.loc["MJ", "BTU"]

    if main_product_category in ["Process fuel", "Electricity"]:
        for metric in metrics:
            res[metric + "_Sum"] = (
                res[metric + "_Sum"] / energy.loc[target_unit, calculation_unit]
            )  # Convert the functional unit from calculation unit to target unit
    return res

# %%
calculate_lca2(overall_lci, False)
# Out:
#            Type        Category     Resource   End Use  Input Amount Unit  \
# 0         Input     Electricity  electricity      coal      0.000000  kWh
# 1         Input     Electricity  electricity  u.s. mix      0.000000  kWh
# 2         Input  Infrastructure     concrete                0.024190   kg
# 3         Input  Infrastructure        steel                0.000968   kg
# 4         Input  Infrastructure      plastic                0.005418   kg
# 5         Input  Infrastructure    cast iron                0.003387   kg
# 6         Input     Electricity  electricity  u.s. mix      0.603066  kWh
# 7  Main Product         Biomass        algae                1.000000   kg
#
#    Moisture Previous Stage Always Use Displacement Method for Co-Product?  \
# 0       0.0            NaN                                             No
# 1       0.0            NaN                                             No
# 2       0.0            NaN                                             No
# 3       0.0            NaN                                             No
# 4       0.0            NaN                                             No
# 5       0.0            NaN                                             No
# 6       0.0            NaN                                             No
# 7       0.0            NaN                                             No
#
#    Product Train  ...         PM10       PM2.5           SOx         BC  \
# 0            NaN  ...    49.480132   21.970511    310.847441   0.897709
# 1            NaN  ...    13.192309    7.550840     76.085923   0.431430
# 2            NaN  ...    69.307302   24.008349     34.061905   0.914880
# 3            NaN  ...  1295.842999  625.982969   8333.518828   7.508462
# 4            NaN  ...   293.339647  136.335718  21999.239751  13.221757
# 5            NaN  ...   839.965799  384.324683   2911.785756   5.701712
# 6            NaN  ...    13.192309    7.550840     76.085923   0.431430
# 7            NaN  ...     0.000000    0.000000      0.000000   0.000000
#
#           OC           CH4        N2O           CO2 Biogenic CO2  Primary Unit
# 0   1.726461    498.260189   7.163679  3.089751e+05            0         mmBTU
# 1   2.137337    264.626355   2.393447  1.201839e+05            0         mmBTU
# 2   2.190960     39.663695   0.692922  8.560445e+04            0           NaN
# 3  21.921922   3643.703767  20.196000  2.043733e+06            0           NaN
# 4  39.242848  20977.408248  34.054314  1.727464e+06            0           NaN
# 5  14.702716   3814.277903  15.557361  7.109855e+05            0           NaN
# 6   2.137337    264.626355   2.393447  1.201839e+05            0         mmBTU
# 7   0.000000      0.000000   0.000000  0.000000e+00            0           ton
#
# [8 rows x 40 columns]

# %%
res_new['GHG_Sum'].sum()
# Out:
# 0.18593617482822963

# %%
res_new.to_csv('testing.csv')

# %%
coproduct_res2 = pd.DataFrame()
lci_mapping, coproduct_mapping, final_process_mapping = read_data(
        # "2021 Biochem SOT via BDO_working.xlsm"
        "Feedstock test2-with INL data.xlsm"
    # "biochemical conversion via Acids.xlsm"
        # "sludge HTL3.xlsm"
    )
updated_coproduct_mapping = coproduct_mapping.copy()
overall_lci2, final_process = generate_final_lci(
    lci_mapping, updated_coproduct_mapping, final_process_mapping, True
)
res_new2 = postprocess(calculate_lca(overall_lci))
coproduct_lci2= generate_coproduct_lci(
    lci_mapping, updated_coproduct_mapping, final_process_mapping
)
if coproduct_lci2 is not None:
    coproduct_res2 = postprocess(calculate_lca(coproduct_lci2))
    
res_new2 = res_new2[
        ~res_new2["Pathway"].str.contains("Incumbent")
    ]

# %%
coproduct_lci[['Type', 'Resource', 'Amount', 'Unit', 'Process', 'Product Train']]
# Out:
#             Type                 Resource       Amount   Unit  \
# 0          Input              corn stover     0.008709    ton
# 1          Input                   diesel   775.411430    BTU
# 2          Input              electricity     0.000000    BTU
# 3          Input              natural gas     0.000000    BTU
# 4          Input              electricity   201.951831    BTU
# 5          Input                   diesel     0.000000    BTU
# 6          Input              natural gas     0.000000    BTU
# 7          Input                   diesel     0.000350  mmBTU
# 8          Input                   diesel     0.000278  mmBTU
# 9          Input              electricity    86.729037    BTU
# 10         Input                   diesel     0.000000    BTU
# 11         Input              natural gas     0.000000    BTU
# 12         Input              electricity  2109.196149    BTU
# 13         Input                   diesel     0.000000    BTU
# 14         Input              natural gas     0.000000    BTU
# 15         Input              electricity     5.794640    BTU
# 16         Input                   diesel    49.392406    BTU
# 17         Input              natural gas     0.000000    BTU
# 18         Input              electricity     0.000000    BTU
# 19         Input                   diesel     0.000000    BTU
# 20         Input              natural gas     0.000000    BTU
# 21         Input                   diesel     0.000358  mmBTU
# 22         Input                   diesel     0.000284  mmBTU
# 23         Input            sulfuric acid     4.971965     kg
# 24         Input                  caustic     0.803853     kg
# 25         Input                  caustic     0.155642     kg
# 26         Input         sodium carbonate     0.518807     kg
# 27         Input                  ammonia     0.004825     kg
# 28         Input                  ammonia     0.008638     kg
# 29         Input                  ammonia     0.164206     kg
# 30         Input                  glucose     0.102074     kg
# 31         Input        corn steep liquor     0.071467     kg
# 32         Input                 corn oil     0.000564     kg
# 33         Input           host nutrients     0.002843     kg
# 34         Input           sulfur dioxide     0.000693     kg
# 35         Input     diammonium phosphate     0.007981     kg
# 36         Input               flocculant     0.033899     kg
# 37         Input                 hydrogen     0.067313     kg
# 38         Input         boiler chemicals     0.000043     kg
# 39         Input                 fgd lime     0.014253     kg
# 40         Input  cooling tower chemicals     0.000099     kg
# 41         Input                    water    11.709661     kg
# 42         Input              natural gas     0.498054     kg
# 43         Input              electricity     1.393307    kWh
# 44         Input              electricity     1.678335    kWh
# 45         Input              electricity     1.545962    kWh
# 46    Co-product      sodium sulfate salt    -1.074736     kg
# 47  Main Product          betaketoadipate     1.000000     kg
#
#                           Process Product Train
# 0          Harvest and collection           NaN
# 1          Harvest and collection           NaN
# 2          Harvest and collection           NaN
# 3          Harvest and collection           NaN
# 4                   Field storage           NaN
# 5                   Field storage           NaN
# 6                   Field storage           NaN
# 7         Transportation to depot           NaN
# 8         Transportation to depot           NaN
# 9                   Depot storage           NaN
# 10                  Depot storage           NaN
# 11                  Depot storage           NaN
# 12                  Preprocessing           NaN
# 13                  Preprocessing           NaN
# 14                  Preprocessing           NaN
# 15                       Handling           NaN
# 16                       Handling           NaN
# 17                       Handling           NaN
# 18                       Blending           NaN
# 19                       Blending           NaN
# 20                       Blending           NaN
# 21  Transportation to biorefinery           NaN
# 22  Transportation to biorefinery           NaN
# 23                Fuel production  Main product
# 24                Fuel production  Main product
# 25                Fuel production          Both
# 26                Fuel production          Both
# 27                Fuel production           NaN
# 28                Fuel production  Main product
# 29                Fuel production          Both
# 30                Fuel production           NaN
# 31                Fuel production           NaN
# 32                Fuel production           NaN
# 33                Fuel production           NaN
# 34                Fuel production           NaN
# 35                Fuel production           NaN
# 36                Fuel production           NaN
# 37                Fuel production           NaN
# 38                Fuel production          Both
# 39                Fuel production          Both
# 40                Fuel production          Both
# 41                Fuel production          Both
# 42                Fuel production          Both
# 43                Fuel production           NaN
# 44                Fuel production  Main product
# 45                Fuel production          Both
# 46                Fuel production          Both
# 47                Fuel production  Main product

# %%
coproduct_lci2[['Type', 'Resource', 'Amount', 'Unit', 'Process', 'Product Train']]
# Out:
#             Type                 Resource       Amount   Unit  \
# 0          Input              corn stover     0.008709    ton
# 1          Input                   diesel   775.411430    BTU
# 2          Input              electricity     0.000000    BTU
# 3          Input              natural gas     0.000000    BTU
# 4          Input              electricity   201.951831    BTU
# 5          Input                   diesel     0.000000    BTU
# 6          Input              natural gas     0.000000    BTU
# 7          Input                   diesel     0.000350  mmBTU
# 8          Input                   diesel     0.000278  mmBTU
# 9          Input              electricity    86.729037    BTU
# 10         Input                   diesel     0.000000    BTU
# 11         Input              natural gas     0.000000    BTU
# 12         Input              electricity  2109.196149    BTU
# 13         Input                   diesel     0.000000    BTU
# 14         Input              natural gas     0.000000    BTU
# 15         Input              electricity     5.794640    BTU
# 16         Input                   diesel    49.392406    BTU
# 17         Input              natural gas     0.000000    BTU
# 18         Input              electricity     0.000000    BTU
# 19         Input                   diesel     0.000000    BTU
# 20         Input              natural gas     0.000000    BTU
# 21         Input                   diesel     0.000358  mmBTU
# 22         Input                   diesel     0.000284  mmBTU
# 23         Input            sulfuric acid     4.971965     kg
# 24         Input                  caustic     0.803853     kg
# 25         Input                  caustic     0.155642     kg
# 26         Input         sodium carbonate     0.518807     kg
# 27         Input                  ammonia     0.008638     kg
# 28         Input                  ammonia     0.164206     kg
# 29         Input         boiler chemicals     0.000043     kg
# 30         Input                 fgd lime     0.014253     kg
# 31         Input  cooling tower chemicals     0.000099     kg
# 32         Input                    water    11.709661     kg
# 33         Input              natural gas     0.498054     kg
# 34         Input              electricity     1.678335    kWh
# 35         Input              electricity     1.545962    kWh
# 36    Co-product      sodium sulfate salt    -1.074736     kg
# 37  Main Product          betaketoadipate     1.000000     kg
#
#                           Process Product Train
# 0          Harvest and collection           NaN
# 1          Harvest and collection           NaN
# 2          Harvest and collection           NaN
# 3          Harvest and collection           NaN
# 4                   Field storage           NaN
# 5                   Field storage           NaN
# 6                   Field storage           NaN
# 7         Transportation to depot           NaN
# 8         Transportation to depot           NaN
# 9                   Depot storage           NaN
# 10                  Depot storage           NaN
# 11                  Depot storage           NaN
# 12                  Preprocessing           NaN
# 13                  Preprocessing           NaN
# 14                  Preprocessing           NaN
# 15                       Handling           NaN
# 16                       Handling           NaN
# 17                       Handling           NaN
# 18                       Blending           NaN
# 19                       Blending           NaN
# 20                       Blending           NaN
# 21  Transportation to biorefinery           NaN
# 22  Transportation to biorefinery           NaN
# 23                Fuel production  Main product
# 24                Fuel production  Main product
# 25                Fuel production          Both
# 26                Fuel production          Both
# 27                Fuel production  Main product
# 28                Fuel production          Both
# 29                Fuel production          Both
# 30                Fuel production          Both
# 31                Fuel production          Both
# 32                Fuel production          Both
# 33                Fuel production          Both
# 34                Fuel production  Main product
# 35                Fuel production          Both
# 36                Fuel production          Both
# 37                Fuel production  Main product

# %%
coproduct_res['GHG_Sum'].sum()
# Out:
# 15.839038489856517

# %%
coproduct_res2['GHG_Sum'].sum()
# Out:
# 14.314371923158589

# %%
coproduct_res[['Type', 'Resource', 'Input Amount', 'Unit', 'Process', 'GHG_Sum', 'Product Train']]
# Out:
#             Type                 Resource  Input Amount   Unit  \
# 0          Input              Corn Stover      0.008709    ton
# 1          Input                   Diesel    775.411430  mmBTU
# 2          Input              Electricity      0.000000  mmBTU
# 3          Input              Natural Gas      0.000000  mmBTU
# 4          Input              Electricity    201.951831  mmBTU
# 5          Input                   Diesel      0.000000  mmBTU
# 6          Input              Natural Gas      0.000000  mmBTU
# 7          Input                   Diesel      0.000350  mmBTU
# 8          Input                   Diesel      0.000278  mmBTU
# 9          Input              Electricity     86.729037  mmBTU
# 10         Input                   Diesel      0.000000  mmBTU
# 11         Input              Natural Gas      0.000000  mmBTU
# 12         Input              Electricity   2109.196149  mmBTU
# 13         Input                   Diesel      0.000000  mmBTU
# 14         Input              Natural Gas      0.000000  mmBTU
# 15         Input              Electricity      5.794640  mmBTU
# 16         Input                   Diesel     49.392406  mmBTU
# 17         Input              Natural Gas      0.000000  mmBTU
# 18         Input              Electricity      0.000000  mmBTU
# 19         Input                   Diesel      0.000000  mmBTU
# 20         Input              Natural Gas      0.000000  mmBTU
# 21         Input                   Diesel      0.000358  mmBTU
# 22         Input                   Diesel      0.000284  mmBTU
# 23         Input            Sulfuric Acid      4.971965      g
# 24         Input                  Caustic      0.803853      g
# 25         Input                  Caustic      0.155642      g
# 26         Input         Sodium Carbonate      0.518807      g
# 27         Input                  Ammonia      0.004825      g
# 28         Input                  Ammonia      0.008638      g
# 29         Input                  Ammonia      0.164206      g
# 30         Input                  Glucose      0.102074      g
# 31         Input        Corn Steep Liquor      0.071467      g
# 32         Input                 Corn Oil      0.000564      g
# 33         Input           Host Nutrients      0.002843      g
# 34         Input           Sulfur Dioxide      0.000693      g
# 35         Input     Diammonium Phosphate      0.007981      g
# 36         Input               Flocculant      0.033899      g
# 37         Input                 Hydrogen      0.067313  mmBTU
# 38         Input         Boiler Chemicals      0.000043      g
# 39         Input                 FGD Lime      0.014253      g
# 40         Input  Cooling Tower Chemicals      0.000099      g
# 41         Input                    Water     11.709661    gal
# 42         Input              Natural Gas      0.498054  mmBTU
# 43         Input              Electricity      1.393307  mmBTU
# 44         Input              Electricity      1.678335  mmBTU
# 45         Input              Electricity      1.545962  mmBTU
# 46    Co-product      Sodium Sulfate Salt     -1.074736      g
# 47  Main Product          Betaketoadipate      1.000000      g
# 0          Input              Adipic Acid      1.000000      g
#
#                           Process   GHG_Sum Product Train
# 0          Harvest and collection  0.023400           NaN
# 1          Harvest and collection  0.073501           NaN
# 2          Harvest and collection  0.000000           NaN
# 3          Harvest and collection  0.000000           NaN
# 4                   Field storage  0.026027           NaN
# 5                   Field storage  0.000000           NaN
# 6                   Field storage  0.000000           NaN
# 7         Transportation to depot  0.033148           NaN
# 8         Transportation to depot  0.026311           NaN
# 9                   Depot storage  0.011178           NaN
# 10                  Depot storage  0.000000           NaN
# 11                  Depot storage  0.000000           NaN
# 12                  Preprocessing  0.271832           NaN
# 13                  Preprocessing  0.000000           NaN
# 14                  Preprocessing  0.000000           NaN
# 15                       Handling  0.000747           NaN
# 16                       Handling  0.004683           NaN
# 17                       Handling  0.000000           NaN
# 18                       Blending  0.000000           NaN
# 19                       Blending  0.000000           NaN
# 20                       Blending  0.000000           NaN
# 21  Transportation to biorefinery  0.033847           NaN
# 22  Transportation to biorefinery  0.026867           NaN
# 23                Fuel production  0.215708  Main product
# 24                Fuel production  1.615067  Main product
# 25                Fuel production  0.312709          Both
# 26                Fuel production  0.581343          Both
# 27                Fuel production  0.012716           NaN
# 28                Fuel production  0.022766  Main product
# 29                Fuel production  0.432773          Both
# 30                Fuel production  0.078735           NaN
# 31                Fuel production  0.119498           NaN
# 32                Fuel production  0.000037           NaN
# 33                Fuel production  0.000000           NaN
# 34                Fuel production  0.000000           NaN
# 35                Fuel production  0.013339           NaN
# 36                Fuel production  0.043120           NaN
# 37                Fuel production  0.644509           NaN
# 38                Fuel production  0.000000          Both
# 39                Fuel production  0.018281          Both
# 40                Fuel production  0.000000          Both
# 41                Fuel production  0.000000          Both
# 42                Fuel production  1.618407          Both
# 43                Fuel production  0.612713           NaN
# 44                Fuel production  0.738056  Main product
# 45                Fuel production  0.679844          Both
# 46                Fuel production -0.199395          Both
# 47                Fuel production -1.650000  Main product
# 0         adipic acid (Incumbent)  9.397273           NaN

# %%
coproduct_res2[['Type', 'Resource', 'Input Amount', 'Unit', 'Process', 'GHG_Sum', 'Product Train']]
# Out:
#             Type                 Resource  Input Amount   Unit  \
# 0          Input              Corn Stover      0.008709    ton
# 1          Input                   Diesel    775.411430  mmBTU
# 2          Input              Electricity      0.000000  mmBTU
# 3          Input              Natural Gas      0.000000  mmBTU
# 4          Input              Electricity    201.951831  mmBTU
# 5          Input                   Diesel      0.000000  mmBTU
# 6          Input              Natural Gas      0.000000  mmBTU
# 7          Input                   Diesel      0.000350  mmBTU
# 8          Input                   Diesel      0.000278  mmBTU
# 9          Input              Electricity     86.729037  mmBTU
# 10         Input                   Diesel      0.000000  mmBTU
# 11         Input              Natural Gas      0.000000  mmBTU
# 12         Input              Electricity   2109.196149  mmBTU
# 13         Input                   Diesel      0.000000  mmBTU
# 14         Input              Natural Gas      0.000000  mmBTU
# 15         Input              Electricity      5.794640  mmBTU
# 16         Input                   Diesel     49.392406  mmBTU
# 17         Input              Natural Gas      0.000000  mmBTU
# 18         Input              Electricity      0.000000  mmBTU
# 19         Input                   Diesel      0.000000  mmBTU
# 20         Input              Natural Gas      0.000000  mmBTU
# 21         Input                   Diesel      0.000358  mmBTU
# 22         Input                   Diesel      0.000284  mmBTU
# 23         Input            Sulfuric Acid      4.971965      g
# 24         Input                  Caustic      0.803853      g
# 25         Input                  Caustic      0.155642      g
# 26         Input         Sodium Carbonate      0.518807      g
# 27         Input                  Ammonia      0.008638      g
# 28         Input                  Ammonia      0.164206      g
# 29         Input         Boiler Chemicals      0.000043      g
# 30         Input                 FGD Lime      0.014253      g
# 31         Input  Cooling Tower Chemicals      0.000099      g
# 32         Input                    Water     11.709661    gal
# 33         Input              Natural Gas      0.498054  mmBTU
# 34         Input              Electricity      1.678335  mmBTU
# 35         Input              Electricity      1.545962  mmBTU
# 36    Co-product      Sodium Sulfate Salt     -1.074736      g
# 37  Main Product          Betaketoadipate      1.000000      g
# 0          Input              Adipic Acid      1.000000      g
#
#                           Process   GHG_Sum Product Train
# 0          Harvest and collection  0.023400           NaN
# 1          Harvest and collection  0.073501           NaN
# 2          Harvest and collection  0.000000           NaN
# 3          Harvest and collection  0.000000           NaN
# 4                   Field storage  0.026027           NaN
# 5                   Field storage  0.000000           NaN
# 6                   Field storage  0.000000           NaN
# 7         Transportation to depot  0.033148           NaN
# 8         Transportation to depot  0.026311           NaN
# 9                   Depot storage  0.011178           NaN
# 10                  Depot storage  0.000000           NaN
# 11                  Depot storage  0.000000           NaN
# 12                  Preprocessing  0.271832           NaN
# 13                  Preprocessing  0.000000           NaN
# 14                  Preprocessing  0.000000           NaN
# 15                       Handling  0.000747           NaN
# 16                       Handling  0.004683           NaN
# 17                       Handling  0.000000           NaN
# 18                       Blending  0.000000           NaN
# 19                       Blending  0.000000           NaN
# 20                       Blending  0.000000           NaN
# 21  Transportation to biorefinery  0.033847           NaN
# 22  Transportation to biorefinery  0.026867           NaN
# 23                Fuel production  0.215708  Main product
# 24                Fuel production  1.615067  Main product
# 25                Fuel production  0.312709          Both
# 26                Fuel production  0.581343          Both
# 27                Fuel production  0.022766  Main product
# 28                Fuel production  0.432773          Both
# 29                Fuel production  0.000000          Both
# 30                Fuel production  0.018281          Both
# 31                Fuel production  0.000000          Both
# 32                Fuel production  0.000000          Both
# 33                Fuel production  1.618407          Both
# 34                Fuel production  0.738056  Main product
# 35                Fuel production  0.679844          Both
# 36                Fuel production -0.199395          Both
# 37                Fuel production -1.650000  Main product
# 0         adipic acid (Incumbent)  9.397273           NaN

# %%
res_new[['Type', 'Resource', 'Amount', 'GHG_Sum']]
# Out:
#             Type                         Resource        Amount    GHG_Sum
# 0          Input                      Corn Stover      0.207442   0.528322
# 1          Input                           Diesel      0.018471   1.659465
# 2          Input                      Electricity      0.000000   0.000000
# 3          Input                      Natural Gas      0.000000   0.000000
# 4          Input                      Electricity      0.004811   0.587633
# 5          Input                           Diesel      0.000000   0.000000
# 6          Input                      Natural Gas      0.000000   0.000000
# 7          Input                           Diesel      0.008349   0.748390
# 8          Input                           Diesel      0.006626   0.594042
# 9          Input                      Electricity      0.002066   0.252362
# 10         Input                           Diesel      0.000000   0.000000
# 11         Input                      Natural Gas      0.000000   0.000000
# 12         Input                      Electricity      0.050242   6.137275
# 13         Input                           Diesel      0.000000   0.000000
# 14         Input                      Natural Gas      0.000000   0.000000
# 15         Input                      Electricity      0.000138   0.016861
# 16         Input                           Diesel      0.001177   0.105720
# 17         Input                      Natural Gas      0.000000   0.000000
# 18         Input                      Electricity      0.000000   0.000000
# 19         Input                           Diesel      0.000000   0.000000
# 20         Input                      Natural Gas      0.000000   0.000000
# 21         Input                           Diesel      0.008525   0.764188
# 22         Input                           Diesel      0.006766   0.606582
# 23         Input                          Caustic   3707.468554   7.060183
# 24         Input                 Sodium Carbonate  12358.228519  13.125262
# 25         Input                          Ammonia    114.931525   0.287101
# 26         Input                          Ammonia   3911.469437   9.770925
# 27         Input                          Glucose   2431.441110   1.777640
# 28         Input                Corn Steep Liquor   1702.373895   2.697955
# 29         Input                         Corn Oil     13.432327   0.000827
# 30         Input                   Host Nutrients     67.727479   0.000000
# 31         Input                   Sulfur Dioxide     16.506983   0.000000
# 32         Input             Diammonium Phosphate    190.114359   0.301156
# 33         Input                       Flocculant    807.481442   0.973541
# 34         Input                         Hydrogen      0.182351  14.551373
# 35         Input                 Boiler Chemicals      1.013238   0.000000
# 36         Input                         FGD Lime    339.512942   0.412732
# 37         Input          Cooling Tower Chemicals      2.369489   0.000000
# 38         Input                            Water     73.685482   0.000000
# 39         Input                      Natural Gas      0.530101  36.539524
# 40         Input                      Electricity      0.113246  13.833515
# 41         Input                      Electricity      0.125654  15.349150
# 42    Co-product              Sodium Sulfate Salt -25600.739563  -4.501841
# 43  Main Product  Renewable Diesel - Bichem (Bdo)      1.000000   0.138768

# %%
res_new2[['Type', 'Resource', 'Amount', 'GHG_Sum']]
# Out:
#             Type                 Resource        Amount    GHG_Sum
# 0          Input              Corn Stover      0.207452   0.528346
# 1          Input                   Diesel      0.018472   1.659540
# 2          Input              Electricity      0.000000   0.000000
# 3          Input              Natural Gas      0.000000   0.000000
# 4          Input              Electricity      0.004811   0.587660
# 5          Input                   Diesel      0.000000   0.000000
# 6          Input              Natural Gas      0.000000   0.000000
# 7          Input                   Diesel      0.008349   0.748424
# 8          Input                   Diesel      0.006626   0.594069
# 9          Input              Electricity      0.002066   0.252373
# 10         Input                   Diesel      0.000000   0.000000
# 11         Input              Natural Gas      0.000000   0.000000
# 12         Input              Electricity      0.050244   6.137552
# 13         Input                   Diesel      0.000000   0.000000
# 14         Input              Natural Gas      0.000000   0.000000
# 15         Input              Electricity      0.000138   0.016862
# 16         Input                   Diesel      0.001177   0.105724
# 17         Input              Natural Gas      0.000000   0.000000
# 18         Input              Electricity      0.000000   0.000000
# 19         Input                   Diesel      0.000000   0.000000
# 20         Input              Natural Gas      0.000000   0.000000
# 21         Input                   Diesel      0.008525   0.764222
# 22         Input                   Diesel      0.006766   0.606609
# 23         Input                  Caustic   3707.635920   7.060502
# 24         Input         Sodium Carbonate  12358.786407  13.125854
# 25         Input                  Ammonia    135.723186   0.339039
# 26         Input                  Ammonia   3911.646013   9.771366
# 27         Input                  Glucose   2871.300398   2.099223
# 28         Input        Corn Steep Liquor   2010.341448   3.186027
# 29         Input                 Corn Oil     15.862299   0.000977
# 30         Input           Host Nutrients     79.979703   0.000000
# 31         Input           Sulfur Dioxide     19.493175   0.000000
# 32         Input     Diammonium Phosphate    224.506952   0.355636
# 33         Input               Flocculant    953.558684   1.149659
# 34         Input                 Hydrogen      0.215339  17.183786
# 35         Input         Boiler Chemicals      1.013283   0.000000
# 36         Input                 FGD Lime    339.528268   0.412751
# 37         Input  Cooling Tower Chemicals      2.369596   0.000000
# 38         Input                    Water     73.688808   0.000000
# 39         Input              Natural Gas      0.530125  36.541173
# 40         Input              Electricity      0.133733  16.336064
# 41         Input              Electricity      0.125660  15.349843
# 42    Co-product      Sodium Sulfate Salt -25601.895258  -4.502044
# 43  Main Product         Renewable Diesel      1.000000   0.138768

# %%
sheet = 'Fuel production'
if "Process" in coproduct_mapping[sheet]:
    if "Mass" in coproduct_mapping[sheet]:
        df = format_input(lci_mapping[sheet], basis="mass")

# %%
def allocation2(df, basis="mass"):
    """
    Calcuate the LCI data after allocation

    Parameters:
        df: the original LCI dataframe that contains inputs and outputs
        basis: the basis for process-level allocation. Must be one of the following: "mass", "energy", or "value".
    """
    ratio = calculate_allocation_ratio(df, basis)

    not_allocated = (df["Type"] == "Main Product") | (
        (df["Type"] == "Co-product")
        & (df["Always Use Displacement Method for Co-Product?"] == "No")
        & (
            df["Amount"] > 0
        )  # if amount is less than zero, it means displacement method has been applied (for example, if displacement method is used for a process)
    )
    allocated = df[~not_allocated].copy()

    allocated['Ratio'] = allocated["Product Train"].fillna(
        "Both"
    ).map({"Both": ratio, "Co-product": 0, "Main product": 1}).fillna(ratio)
    
    allocated["Amount"] = allocated["Amount"] * allocated["Product Train"].fillna(
        "Both"
    ).map({"Both": ratio, "Co-product": 0, "Main product": 1}).fillna(ratio)
    print(allocated[['Resource', 'Product Train', 'Amount', 'Ratio']])
    allocated = allocated[allocated["Amount"] != 0]
    allocated.loc[
        (allocated["Type"] == "Co-product") & (allocated["Amount"] > 0), "Amount"
    ] = -allocated.loc[
        (allocated["Type"] == "Co-product") & (allocated["Amount"] > 0), "Amount"
    ]  # Only for the co-products for which displacement methods should but have not been applied

    return pd.concat(
        [allocated, df[df["Type"].isin(["Main Product"])]], ignore_index=True
    )

# %%
allocation2(df)['Product Train'].unique()
# Out:
#                    Resource Product Train      Amount     Ratio
# 0               corn stover          Both  169.273948  0.831334
# 1             sulfuric acid    Co-product    0.000000  0.000000
# 2                   caustic    Co-product    0.000000  0.000000
# 3                   caustic          Both    4.062575  0.831334
# 4          sodium carbonate          Both   13.541916  0.831334
# 5                   ammonia  Main product    0.151491  1.000000
# 6                   ammonia    Co-product    0.000000  0.000000
# 7                   ammonia          Both    4.550434  0.831334
# 8                   glucose  Main product    3.204882  1.000000
# 9         corn steep liquor  Main product    2.995448  1.000000
# 10                 corn oil  Main product    0.017705  1.000000
# 11           host nutrients  Main product    0.089272  1.000000
# 12           sulfur dioxide  Main product    0.021758  1.000000
# 13     diammonium phosphate  Main product    0.411988  1.000000
# 14               flocculant  Main product    0.995563  1.000000
# 15                 hydrogen  Main product    0.000000  1.000000
# 16         boiler chemicals          Both    0.000624  0.831334
# 17                 fgd lime          Both    0.400779  0.831334
# 18  cooling tower chemicals          Both    0.002596  0.831334
# 19                    water          Both  533.977433  0.831334
# 20              natural gas          Both    0.203129  0.831334
# 21              electricity  Main product   54.228972  1.000000
# 22              electricity    Co-product    0.000000  0.000000
# 23              electricity          Both   63.709475  0.831334
# 24              natural gas  Main Product    0.079070  0.831334
# 25                  toluene  Main Product    0.182816  0.831334
# 28      sodium sulfate salt          Both   29.736374  0.831334
# array(['Both', 'Main product', 'Main Product'], dtype=object)

# %%
allocation2(df)
# Out:
#                    Resource Product Train      Amount     Ratio
# 0               corn stover          Both  169.273948  0.831334
# 1             sulfuric acid    Co-product    0.000000  0.000000
# 2                   caustic    Co-product    0.000000  0.000000
# 3                   caustic          Both    4.062575  0.831334
# 4          sodium carbonate          Both   13.541916  0.831334
# 5                   ammonia  Main product    0.151491  1.000000
# 6                   ammonia    Co-product    0.000000  0.000000
# 7                   ammonia          Both    4.550434  0.831334
# 8                   glucose  Main product    3.204882  1.000000
# 9         corn steep liquor  Main product    2.995448  1.000000
# 10                 corn oil  Main product    0.017705  1.000000
# 11           host nutrients  Main product    0.089272  1.000000
# 12           sulfur dioxide  Main product    0.021758  1.000000
# 13     diammonium phosphate  Main product    0.411988  1.000000
# 14               flocculant  Main product    0.995563  1.000000
# 15                 hydrogen  Main product    0.000000  1.000000
# 16         boiler chemicals          Both    0.000624  0.831334
# 17                 fgd lime          Both    0.400779  0.831334
# 18  cooling tower chemicals          Both    0.002596  0.831334
# 19                    water          Both  533.977433  0.831334
# 20              natural gas          Both    0.203129  0.831334
# 21              electricity  Main product   54.228972  1.000000
# 22              electricity    Co-product    0.000000  0.000000
# 23              electricity          Both   63.709475  0.831334
# 24              natural gas  Main Product    0.079070  0.831334
# 25                  toluene  Main Product    0.182816  0.831334
# 28      sodium sulfate salt          Both   29.736374  0.831334
#                         Type                 Category  \
# 0   Input from Another Stage                  Biomass
# 1                      Input  Chemicals and catalysts
# 2                      Input  Chemicals and catalysts
# 3                      Input  Chemicals and catalysts
# 4                      Input  Chemicals and catalysts
# 5                      Input  Chemicals and catalysts
# 6                      Input  Chemicals and catalysts
# 7                      Input  Chemicals and catalysts
# 8                      Input  Chemicals and catalysts
# 9                      Input  Chemicals and catalysts
# 10                     Input  Chemicals and catalysts
# 11                     Input  Chemicals and catalysts
# 12                     Input  Chemicals and catalysts
# 13                     Input  Chemicals and catalysts
# 14                     Input  Chemicals and catalysts
# 15                     Input                    Water
# 16                     Input             Process fuel
# 17                     Input              Electricity
# 18                     Input              Electricity
# 19                     Input             Process fuel
# 20                     Input  Chemicals and catalysts
# 21                Co-product  Chemicals and catalysts
# 22              Main Product             Process fuel
#
#                               Resource  \
# 0                          corn stover
# 1                              caustic
# 2                     sodium carbonate
# 3                              ammonia
# 4                              ammonia
# 5                              glucose
# 6                    corn steep liquor
# 7                             corn oil
# 8                       host nutrients
# 9                       sulfur dioxide
# 10                diammonium phosphate
# 11                          flocculant
# 12                    boiler chemicals
# 13                            fgd lime
# 14             cooling tower chemicals
# 15                               water
# 16                         natural gas
# 17                         electricity
# 18                         electricity
# 19                         natural gas
# 20                             toluene
# 21                 sodium sulfate salt
# 22  renewable diesel - biochem (acids)
#
#                                              End Use      Amount   Unit  \
# 0                                                     169.273948     kg
# 1                                                       4.062575     kg
# 2                                                use   13.541916     kg
# 3                                                       0.151491     kg
# 4                                                       4.550434     kg
# 5                                                       3.204882     kg
# 6                                                       2.995448     kg
# 7                                                       0.017705     kg
# 8                                                       0.089272     kg
# 9                                                       0.021758     kg
# 10                                                      0.411988     kg
# 11                                                      0.995563     kg
# 12                                                      0.000624     kg
# 13                                                      0.400779     kg
# 14                                                      0.002596     kg
# 15                                                    533.977433     kg
# 16  utility/ industrial boiler (>100 mmbtu/hr input)    0.203129     kg
# 17                                          u.s. mix   54.228972    kWh
# 18                                          u.s. mix   63.709475    kWh
# 19  utility/ industrial boiler (>100 mmbtu/hr input)    0.079070  mmBTU
# 20                                        combustion    0.182816     kg
# 21                                                    -29.736374     kg
# 22           fuel distribution and vehicle operation    1.000000  mmBTU
#
#     Moisture                 Previous Stage  \
# 0        0.2  Transportation to biorefinery
# 1        0.0                            NaN
# 2        0.0                            NaN
# 3        0.0                            NaN
# 4        0.0                            NaN
# 5        0.0                            NaN
# 6        0.0                            NaN
# 7        0.0                            NaN
# 8        0.0                            NaN
# 9        0.0                            NaN
# 10       0.0                            NaN
# 11       0.0                            NaN
# 12       0.0                            NaN
# 13       0.0                            NaN
# 14       0.0                            NaN
# 15       0.0                            NaN
# 16       0.0                            NaN
# 17       0.0                            NaN
# 18       0.0                            NaN
# 19       0.0                            NaN
# 20       0.0                            NaN
# 21       0.0                            NaN
# 22       0.0                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No          Both  ...
# 2                                              No          Both  ...
# 3                                              No  Main product  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No  Main product  ...
# 7                                              No  Main product  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No          Both  ...
# 13                                             No          Both  ...
# 14                                             No          Both  ...
# 15                                             No          Both  ...
# 16                                             No          Both  ...
# 17                                             No  Main product  ...
# 18                                             No          Both  ...
# 19                                             No  Main Product  ...
# 20                                             No  Main Product  ...
# 21                                            Yes          Both  ...
# 22                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN                  caustic
# 2            NaN                NaN         sodium carbonate
# 3            NaN                NaN                  ammonia
# 4            NaN                NaN                  ammonia
# 5            NaN                NaN                  glucose
# 6            NaN                NaN        corn steep liquor
# 7            NaN                NaN                 corn oil
# 8            NaN                NaN           host nutrients
# 9            NaN                NaN           sulfur dioxide
# 10           NaN                NaN     diammonium phosphate
# 11           NaN                NaN               flocculant
# 12           NaN                NaN         boiler chemicals
# 13           NaN                NaN                 fgd lime
# 14           NaN                NaN  cooling tower chemicals
# 15           NaN                NaN                    water
# 16           NaN                NaN              natural gas
# 17           NaN                NaN              electricity
# 18           NaN                NaN              electricity
# 19           NaN                NaN              natural gas
# 20           NaN                NaN                  toluene
# 21           NaN                NaN      sodium sulfate salt
# 22     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product          Process Note  \
# 0                                                     Fuel production  NaN
# 1                                                     Fuel production  NaN
# 2                                                use  Fuel production  NaN
# 3                                                     Fuel production  NaN
# 4                                                     Fuel production  NaN
# 5                                                     Fuel production  NaN
# 6                                                     Fuel production  NaN
# 7                                                     Fuel production  NaN
# 8                                                     Fuel production  NaN
# 9                                                     Fuel production  NaN
# 10                                                    Fuel production  NaN
# 11                                                    Fuel production  NaN
# 12                                                    Fuel production  NaN
# 13                                                    Fuel production  NaN
# 14                                                    Fuel production  NaN
# 15                                                    Fuel production  NaN
# 16  utility/ industrial boiler (>100 mmbtu/hr input)  Fuel production  NaN
# 17                                          u.s. mix  Fuel production  NaN
# 18                                          u.s. mix  Fuel production  NaN
# 19  utility/ industrial boiler (>100 mmbtu/hr input)  Fuel production  NaN
# 20                                        combustion  Fuel production  NaN
# 21                                                    Fuel production  NaN
# 22                                light duty vehicle  Fuel production  NaN
#
#          Incumbent Resource        LHV      Density     Ratio
# 0               Corn Stover  17.114708          NaN  0.831334
# 1                   Caustic        NaN          NaN  0.831334
# 2          Sodium carbonate        NaN          NaN  0.831334
# 3                   Ammonia        NaN          NaN  1.000000
# 4                   Ammonia        NaN          NaN  0.831334
# 5                   Glucose        NaN          NaN  1.000000
# 6         Corn Steep Liquor        NaN          NaN  1.000000
# 7                  Corn oil        NaN          NaN  1.000000
# 8            Host nutrients        NaN          NaN  1.000000
# 9            Sulfur Dioxide        NaN          NaN  1.000000
# 10     Diammonium Phosphate        NaN          NaN  1.000000
# 11               Flocculant        NaN          NaN  1.000000
# 12         Boiler Chemicals        NaN          NaN  0.831334
# 13                 FGD Lime        NaN          NaN  0.831334
# 14  Cooling Tower Chemicals        NaN          NaN  0.831334
# 15                    Water        NaN  1000.000000  0.831334
# 16              Natural Gas  47.141814     0.776923  0.831334
# 17              Electricity        NaN          NaN  1.000000
# 18              Electricity        NaN          NaN  0.831334
# 19              Natural Gas  47.141814     0.776923  0.831334
# 20                  Toluene        NaN          NaN  0.831334
# 21      Sodium sulfate salt        NaN          NaN  0.831334
# 22                   Diesel  43.995103   793.378565       NaN
#
# [23 rows x 22 columns]

# %%
re = res_new[(res_new['GHG_Sum']>0)&(res_new["Process"]=='Fuel production')]

# %%
re.loc[~re['Resource'].isin(['Natural Gas', 'Electricity']), 'GHG_Sum'].sum()
# Out:
# 44.206664906590035

# %%
re.loc[re['Resource'].isin(['Natural Gas', 'Electricity']), ['Resource', 'Amount', 'Unit', 'GHG_Sum']]
# Out:
#        Resource    Amount   Unit    GHG_Sum
# 38  Natural Gas  0.009076  mmBTU   0.625614
# 39  Electricity  0.185037  mmBTU  22.603015
# 40  Electricity  0.217386  mmBTU  26.554555
# 41  Natural Gas  0.079070  mmBTU   5.450262

# %%
lci_mapping['Fuel production']
# Out:
#                         Type                 Category  \
# 0   Input from Another Stage                  Biomass
# 1                      Input  Chemicals and catalysts
# 2                      Input  Chemicals and catalysts
# 3                      Input  Chemicals and catalysts
# 4                      Input  Chemicals and catalysts
# 5                      Input  Chemicals and catalysts
# 6                      Input  Chemicals and catalysts
# 7                      Input  Chemicals and catalysts
# 8                      Input  Chemicals and catalysts
# 9                      Input  Chemicals and catalysts
# 10                     Input  Chemicals and catalysts
# 11                     Input  Chemicals and catalysts
# 12                     Input  Chemicals and catalysts
# 13                     Input  Chemicals and catalysts
# 14                     Input  Chemicals and catalysts
# 15                     Input             Process fuel
# 16                     Input  Chemicals and catalysts
# 17                     Input  Chemicals and catalysts
# 18                     Input  Chemicals and catalysts
# 19                     Input                    Water
# 20                     Input             Process fuel
# 21                     Input              Electricity
# 22                     Input              Electricity
# 23                     Input              Electricity
# 24                     Input             Process fuel
# 25                     Input  Chemicals and catalysts
# 26              Main Product             Process fuel
# 27                Co-product  Chemicals and catalysts
# 28                Co-product  Chemicals and catalysts
#
#                               Resource  \
# 0                          Corn Stover
# 1                        Sulfuric Acid
# 2                              Caustic
# 3                              Caustic
# 4                     Sodium carbonate
# 5                              Ammonia
# 6                              Ammonia
# 7                              Ammonia
# 8                              Glucose
# 9                    Corn Steep Liquor
# 10                            Corn oil
# 11                      Host nutrients
# 12                      Sulfur Dioxide
# 13                Diammonium Phosphate
# 14                          Flocculant
# 15                            Hydrogen
# 16                    Boiler Chemicals
# 17                            FGD Lime
# 18             Cooling Tower Chemicals
# 19                               Water
# 20                         Natural Gas
# 21                         Electricity
# 22                         Electricity
# 23                         Electricity
# 24                         Natural Gas
# 25                             Toluene
# 26  Renewable Diesel - Biochem (Acids)
# 27                     Betaketoadipate
# 28                 Sodium sulfate salt
#
#                                              End Use         Amount   Unit  \
# 0                                                NaN  104166.667000     kg
# 1                                                NaN   11374.716100     kg
# 2                                                NaN    2279.962644     kg
# 3                                                NaN    2000.000000     kg
# 4                                                Use    6666.666670     kg
# 5                                                NaN      62.000000     kg
# 6                                                NaN      17.000000     kg
# 7                                                NaN    2240.172482     kg
# 8                                                NaN    1311.644900     kg
# 9                                                NaN    1225.931036     kg
# 10                                               NaN       7.246091     kg
# 11                                               NaN      36.535700     kg
# 12                                               NaN       8.904719     kg
# 13                                               NaN     168.612257     kg
# 14                                               NaN     407.448796     kg
# 15                                               NaN       0.000000     kg
# 16                                               NaN       0.307018     kg
# 17                                               NaN     197.302732     kg
# 18                                               NaN       1.278225     kg
# 19                                               NaN  262876.362000     kg
# 20  Utility/ Industrial Boiler (>100 mmBtu/hr input)     100.000000     kg
# 21                                          U.S. Mix   22194.000000    kWh
# 22                                          U.S. Mix    3311.000000    kWh
# 23                                          U.S. Mix   31364.087597    kWh
# 24  Utility/ Industrial Boiler (>100 mmBtu/hr input)      38.926145  mmBTU
# 25                                        Combustion      90.000000     kg
# 26           Fuel Distribution and Vehicle Operation     409.264628  mmBTU
# 27                                     Sequestration    1991.256090     kg
# 28                                               NaN   14639.176500     kg
#
#     Moisture                 Previous Stage  \
# 0       0.20  Transportation to biorefinery
# 1       0.07                            NaN
# 2        NaN                            NaN
# 3        NaN                            NaN
# 4        NaN                            NaN
# 5        NaN                            NaN
# 6        NaN                            NaN
# 7        NaN                            NaN
# 8        NaN                            NaN
# 9        NaN                            NaN
# 10       NaN                            NaN
# 11       NaN                            NaN
# 12       NaN                            NaN
# 13       NaN                            NaN
# 14       NaN                            NaN
# 15       NaN                            NaN
# 16       NaN                            NaN
# 17       NaN                            NaN
# 18       NaN                            NaN
# 19       NaN                            NaN
# 20       NaN                            NaN
# 21       NaN                            NaN
# 22       NaN                            NaN
# 23       NaN                            NaN
# 24       NaN                            NaN
# 25       NaN                            NaN
# 26       NaN                            NaN
# 27       NaN                            NaN
# 28       NaN                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  Payload  \
# 0                                             NaN          Both      NaN
# 1                                             NaN    Co-product      NaN
# 2                                             NaN    Co-product      NaN
# 3                                             NaN          Both      NaN
# 4                                             NaN          Both      NaN
# 5                                             NaN  Main product      NaN
# 6                                             NaN    Co-product      NaN
# 7                                             NaN          Both      NaN
# 8                                             NaN  Main product      NaN
# 9                                             NaN  Main product      NaN
# 10                                            NaN  Main product      NaN
# 11                                            NaN  Main product      NaN
# 12                                            NaN  Main product      NaN
# 13                                            NaN  Main product      NaN
# 14                                            NaN  Main product      NaN
# 15                                            NaN  Main product      NaN
# 16                                            NaN          Both      NaN
# 17                                            NaN          Both      NaN
# 18                                            NaN          Both      NaN
# 19                                            NaN          Both      NaN
# 20                                            NaN          Both      NaN
# 21                                            NaN  Main product      NaN
# 22                                            NaN    Co-product      NaN
# 23                                            NaN          Both      NaN
# 24                                            NaN  Main Product      NaN
# 25                                            NaN  Main Product      NaN
# 26                                            NaN  Main product      NaN
# 27                                             No    Co-product      NaN
# 28                                            Yes          Both      NaN
#
#     Payload Unit  Market Price Market Price Unit        Incumbent Product  \
# 0            NaN           NaN               NaN              Corn Stover
# 1            NaN           NaN               NaN            Sulfuric Acid
# 2            NaN           NaN               NaN                  Caustic
# 3            NaN           NaN               NaN                  Caustic
# 4            NaN           NaN               NaN         Sodium carbonate
# 5            NaN           NaN               NaN                  Ammonia
# 6            NaN           NaN               NaN                  Ammonia
# 7            NaN           NaN               NaN                  Ammonia
# 8            NaN           NaN               NaN                  Glucose
# 9            NaN           NaN               NaN        Corn Steep Liquor
# 10           NaN           NaN               NaN                 Corn oil
# 11           NaN           NaN               NaN           Host nutrients
# 12           NaN           NaN               NaN           Sulfur Dioxide
# 13           NaN           NaN               NaN     Diammonium Phosphate
# 14           NaN           NaN               NaN               Flocculant
# 15           NaN           NaN               NaN                 Hydrogen
# 16           NaN           NaN               NaN         Boiler Chemicals
# 17           NaN           NaN               NaN                 FGD Lime
# 18           NaN           NaN               NaN  Cooling Tower Chemicals
# 19           NaN           NaN               NaN                    Water
# 20           NaN           NaN               NaN              Natural Gas
# 21           NaN           NaN               NaN              Electricity
# 22           NaN           NaN               NaN              Electricity
# 23           NaN           NaN               NaN              Electricity
# 24           NaN           NaN               NaN              Natural Gas
# 25           NaN           NaN               NaN                  Toluene
# 26           NaN     21.535016           $/mmBTU                   Diesel
# 27           NaN      1.873939              $/kg              Adipic Acid
# 28           NaN           NaN               NaN      Sodium sulfate salt
#
#                         End Use of Incumbent Product          Process  Note
# 0                                                NaN  Fuel production   NaN
# 1                                                NaN  Fuel production   NaN
# 2                                                NaN  Fuel production   NaN
# 3                                                NaN  Fuel production   NaN
# 4                                                Use  Fuel production   NaN
# 5                                                NaN  Fuel production   NaN
# 6                                                NaN  Fuel production   NaN
# 7                                                NaN  Fuel production   NaN
# 8                                                NaN  Fuel production   NaN
# 9                                                NaN  Fuel production   NaN
# 10                                               NaN  Fuel production   NaN
# 11                                               NaN  Fuel production   NaN
# 12                                               NaN  Fuel production   NaN
# 13                                               NaN  Fuel production   NaN
# 14                                               NaN  Fuel production   NaN
# 15                                               NaN  Fuel production   NaN
# 16                                               NaN  Fuel production   NaN
# 17                                               NaN  Fuel production   NaN
# 18                                               NaN  Fuel production   NaN
# 19                                               NaN  Fuel production   NaN
# 20  Utility/ Industrial Boiler (>100 mmBtu/hr input)  Fuel production   NaN
# 21                                          U.S. Mix  Fuel production   NaN
# 22                                          U.S. Mix  Fuel production   NaN
# 23                                          U.S. Mix  Fuel production   NaN
# 24  Utility/ Industrial Boiler (>100 mmBtu/hr input)  Fuel production   NaN
# 25                                        Combustion  Fuel production   NaN
# 26                                Light Duty Vehicle  Fuel production   NaN
# 27                                               NaN  Fuel production   NaN
# 28                                               NaN  Fuel production   NaN

# %%
overall_lci.loc[overall_lci['Resource'].isin(['natural gas']), ['Product Train', 'Amount', 'Unit']]
# Out:
#    Product Train    Amount   Unit
# 3            NaN  0.000000    BTU
# 6            NaN  0.000000    BTU
# 11           NaN  0.000000    BTU
# 14           NaN  0.000000    BTU
# 17           NaN  0.000000    BTU
# 20           NaN  0.000000    BTU
# 38          Both  0.203129     kg
# 41  Main Product  0.079070  mmBTU

# %%
re[['Type', 'Resource', 'Amount', 'GHG_Sum', 'CO2_Sum']]
# Out:
#             Type                            Resource        Amount    GHG_Sum  \
# 0          Input                             Caustic   4062.574733   7.736417
# 1          Input                    Sodium Carbonate  13541.915782  14.382416
# 2          Input                             Ammonia    151.491225   0.378428
# 3          Input                             Ammonia   4550.434062  11.367071
# 4          Input                             Glucose   3204.882150   2.343107
# 5          Input                   Corn Steep Liquor   2995.448307   4.747243
# 6          Input                            Corn Oil     17.705148   0.001090
# 9          Input                Diammonium Phosphate    411.988346   0.652621
# 10         Input                          Flocculant    995.563184   1.200302
# 12         Input                            FGD Lime    400.778547   0.487210
# 15         Input                         Natural Gas      0.009076   0.625614
# 16         Input                         Electricity      0.185037  22.603015
# 17         Input                         Electricity      0.217386  26.554555
# 18         Input                         Natural Gas      0.095112   6.556043
# 19         Input                             Toluene    219.906618   0.928617
# 21  Main Product  Renewable Diesel - Biochem (Acids)      1.000000   0.138768
#
#       CO2_Sum
# 0    7.124962
# 1   14.069043
# 2    0.341473
# 3   10.257021
# 4    1.563666
# 5    2.530560
# 6    0.001023
# 9    0.601505
# 10   1.102275
# 12   0.478951
# 15   0.563491
# 16  21.077994
# 17  24.762925
# 18   5.905029
# 19   0.883733
# 21  71.104898

# %%
overall_lci[['Type', 'Resource', 'Amount', 'Unit', 'Process']]
# Out:
#             Type                            Resource        Amount   Unit  \
# 0          Input                         corn stover      0.227312    ton
# 1          Input                              diesel  20239.824203    BTU
# 2          Input                         electricity      0.000000    BTU
# 3          Input                         natural gas      0.000000    BTU
# 4          Input                         electricity   5271.355832    BTU
# 5          Input                              diesel      0.000000    BTU
# 6          Input                         natural gas      0.000000    BTU
# 7          Input                              diesel      0.009148  mmBTU
# 8          Input                              diesel      0.007260  mmBTU
# 9          Input                         electricity   2263.805243    BTU
# 10         Input                              diesel      0.000000    BTU
# 11         Input                         natural gas      0.000000    BTU
# 12         Input                         electricity  55054.333265    BTU
# 13         Input                              diesel      0.000000    BTU
# 14         Input                         natural gas      0.000000    BTU
# 15         Input                         electricity    151.251951    BTU
# 16         Input                              diesel   1289.242822    BTU
# 17         Input                         natural gas      0.000000    BTU
# 18         Input                         electricity      0.000000    BTU
# 19         Input                              diesel      0.000000    BTU
# 20         Input                         natural gas      0.000000    BTU
# 21         Input                              diesel      0.009341  mmBTU
# 22         Input                              diesel      0.007414  mmBTU
# 23         Input                             caustic      4.062575     kg
# 24         Input                    sodium carbonate     13.541916     kg
# 25         Input                             ammonia      0.151491     kg
# 26         Input                             ammonia      4.550434     kg
# 27         Input                             glucose      3.204882     kg
# 28         Input                   corn steep liquor      2.995448     kg
# 29         Input                            corn oil      0.017705     kg
# 30         Input                      host nutrients      0.089272     kg
# 31         Input                      sulfur dioxide      0.021758     kg
# 32         Input                diammonium phosphate      0.411988     kg
# 33         Input                          flocculant      0.995563     kg
# 34         Input                    boiler chemicals      0.000624     kg
# 35         Input                            fgd lime      0.400779     kg
# 36         Input             cooling tower chemicals      0.002596     kg
# 37         Input                               water    533.977433     kg
# 38         Input                         natural gas      0.203129     kg
# 39         Input                         electricity     54.228972    kWh
# 40         Input                         electricity     63.709475    kWh
# 41    Co-product                 sodium sulfate salt    -29.736374     kg
# 42         Input                         natural gas      0.079070  mmBTU
# 43         Input                             toluene      0.182816     kg
# 44  Main Product  renewable diesel - biochem (acids)      1.000000  mmBTU
#
#                           Process
# 0          Harvest and collection
# 1          Harvest and collection
# 2          Harvest and collection
# 3          Harvest and collection
# 4                   Field storage
# 5                   Field storage
# 6                   Field storage
# 7         Transportation to depot
# 8         Transportation to depot
# 9                   Depot storage
# 10                  Depot storage
# 11                  Depot storage
# 12                  Preprocessing
# 13                  Preprocessing
# 14                  Preprocessing
# 15                       Handling
# 16                       Handling
# 17                       Handling
# 18                       Blending
# 19                       Blending
# 20                       Blending
# 21  Transportation to biorefinery
# 22  Transportation to biorefinery
# 23                Fuel production
# 24                Fuel production
# 25                Fuel production
# 26                Fuel production
# 27                Fuel production
# 28                Fuel production
# 29                Fuel production
# 30                Fuel production
# 31                Fuel production
# 32                Fuel production
# 33                Fuel production
# 34                Fuel production
# 35                Fuel production
# 36                Fuel production
# 37                Fuel production
# 38                Fuel production
# 39                Fuel production
# 40                Fuel production
# 41                Fuel production
# 42                Fuel production
# 43                Fuel production
# 44                Fuel production

# %%
check.loc[(check['GHG_Sum']>0)&(check['Resource'].isin(['Sodium Carbonate'])), ['GHG', 'GHG_Sum', 'Amount', 'Input Amount']]
# Out:
#        GHG    GHG_Sum        Amount  Input Amount
# 1  1.12054  13.125854  12358.786407     12.358786

# %%
check.loc[(check['GHG_Sum']>0)&(check['Resource'].isin(['Sodium Carbonate'])), 'Amount'].values[0]
# Out:
# 12358.78640743849

# %%
check.loc[(check['GHG_Sum']>0)&(check['Resource'].isin(['Sodium Carbonate'])), 'GHG'].values[0]
# Out:
# 1.120539578591617

# %%
check.loc[(check['GHG_Sum']>0)&(check['Resource'].isin(['Sodium Carbonate'])), 'GHG_Sum'].values[0]
# Out:
# 13.125854250175411

# %%
1.12053957859162 * 12358.78640743849 / 1055.0558500000
# Out:
# 13.125854250175445

# %%
1.120539578591617 * 12358.78640743849 / 1055.0558500000
# Out:
# 13.125854250175411

# %%
check.loc[(check['GHG_Sum']>0)&(check['Resource'].isin(['Sodium Carbonate'])), 'Amount'].values[0]
# Out:
# 12358.78640743849

# %%
check.loc[~check['Resource'].isin(['Caustic']), 'GHG_Sum'].sum()-0.138768
# Out:
# 111.34886663965789

# %%
check.loc[check['Resource'].isin(['Caustic']), 'GHG_Sum'].sum()
# Out:
# 7.06045305580289

# %%
check.loc[check['Resource'].isin(['Caustic']), ['Type', 'Resource', 'Input Amount', 'Amount', 'Unit', 'CO2', 'CO2_Sum', 'Amount', 'GHG', 'GHG_Sum', 'Process']]
# Out:
#     Type Resource  Input Amount       Amount Unit       CO2   CO2_Sum  \
# 0  Input  Caustic       3.70761  3707.610287    g  1.850362  6.502424
#
#         Amount       GHG   GHG_Sum          Process
# 0  3707.610287  2.009157  7.060453  Fuel production

# %%
check.loc[check['Resource'].isin(['Caustic']), 'Amount'].sum()
# Out:
# 3707.6102866424353

# %%
check[['Type', 'Resource', 'Input Amount', 'Amount', 'Unit', 'CO2', 'CO2_Sum', 'Amount', 'GHG', 'GHG_Sum', 'Process']]
# Out:
#             Type                 Resource  Input Amount        Amount   Unit  \
# 0          Input                  Caustic      3.707610   3707.610287      g
# 1          Input         Sodium Carbonate     12.358701  12358.700962      g
# 2          Input                  Ammonia      0.135723    135.723186      g
# 3          Input                  Ammonia      3.911619   3911.618969      g
# 4          Input                  Glucose      2.871300   2871.300398      g
# 5          Input        Corn Steep Liquor      2.010341   2010.341448      g
# 6          Input                 Corn Oil      0.015862     15.862299      g
# 7          Input           Host Nutrients      0.079980     79.979703      g
# 8          Input           Sulfur Dioxide      0.019493     19.493175      g
# 9          Input     Diammonium Phosphate      0.224507    224.506952      g
# 10         Input               Flocculant      0.953559    953.558684      g
# 11         Input                 Hydrogen      1.893501      0.215339  mmBTU
# 12         Input         Boiler Chemicals      0.001013      1.013276      g
# 13         Input                 FGD Lime      0.339526    339.525921      g
# 14         Input  Cooling Tower Chemicals      0.002370      2.369579      g
# 15         Input                    Water    278.940497     73.688299    gal
# 16         Input              Natural Gas     11.864353      0.530121  mmBTU
# 17         Input              Electricity     39.193354      0.133733  mmBTU
# 18         Input              Electricity     36.826966      0.125659  mmBTU
# 19    Co-product      Sodium Sulfate Salt    -25.601718 -25601.718253      g
# 20  Main Product         Renewable Diesel      1.000000      1.000000  mmBTU
#
#               CO2    CO2_Sum        Amount            GHG    GHG_Sum  \
# 0        1.850362   6.502424   3707.610287       2.009157   7.060453
# 1        1.096125  12.839771  12358.700962       1.120540  13.125764
# 2        2.378175   0.305930    135.723186       2.635550   0.339039
# 3        2.378175   8.817084   3911.618969       2.635550   9.771299
# 4        0.514763   1.400911   2871.300398       0.771357   2.099223
# 5        0.891313   1.698340   2010.341448       1.672073   3.186027
# 6        0.060945   0.000916     15.862299       0.064980   0.000977
# 7        0.000000   0.000000     79.979703       0.000000   0.000000
# 8        0.000000   0.000000     19.493175       0.000000   0.000000
# 9        1.540386   0.327781    224.506952       1.671290   0.355636
# 10       1.168144   1.055768    953.558684       1.272029   1.149659
# 11   78307.418265  15.982724      0.215339   84192.026833  17.183786
# 12       0.000000   0.000000      1.013276       0.000000   0.000000
# 13       1.260847   0.405751    339.525921       1.282589   0.412748
# 14       0.000000   0.000000      2.369579       0.000000   0.000000
# 15       0.000000   0.000000     73.688299       0.000000   0.000000
# 16   65502.860419  32.912412      0.530121   72724.381819  36.540920
# 17  120183.904109  15.233873      0.133733  128879.369583  16.336064
# 18  120183.904109  14.314093      0.125659  128879.369583  15.349737
# 19       0.172558  -4.187257 -25601.718253       0.185530  -4.502013
# 20   75019.638598  71.104898      1.000000     146.407942   0.138768
#
#             Process
# 0   Fuel production
# 1   Fuel production
# 2   Fuel production
# 3   Fuel production
# 4   Fuel production
# 5   Fuel production
# 6   Fuel production
# 7   Fuel production
# 8   Fuel production
# 9   Fuel production
# 10  Fuel production
# 11  Fuel production
# 12  Fuel production
# 13  Fuel production
# 14  Fuel production
# 15  Fuel production
# 16  Fuel production
# 17  Fuel production
# 18  Fuel production
# 19  Fuel production
# 20  Fuel production

# %%
res_new[['Type', 'Resource', 'Input Amount', 'Amount', 'Unit', 'CO2', 'CO2_Sum', 'Amount', 'GHG', 'GHG_Sum', 'Process']]
# Out:
#             Type                 Resource  Input Amount        Amount   Unit  \
# 0          Input                  Caustic      3.707610   3707.610287      g
# 1          Input         Sodium Carbonate     12.358701  12358.700962      g
# 2          Input                  Ammonia      0.135723    135.723186      g
# 3          Input                  Ammonia      3.911619   3911.618969      g
# 4          Input                  Glucose      2.871300   2871.300398      g
# 5          Input        Corn Steep Liquor      2.010341   2010.341448      g
# 6          Input                 Corn Oil      0.015862     15.862299      g
# 7          Input           Host Nutrients      0.079980     79.979703      g
# 8          Input           Sulfur Dioxide      0.019493     19.493175      g
# 9          Input     Diammonium Phosphate      0.224507    224.506952      g
# 10         Input               Flocculant      0.953559    953.558684      g
# 11         Input                 Hydrogen      1.893501      0.215339  mmBTU
# 12         Input         Boiler Chemicals      0.001013      1.013276      g
# 13         Input                 FGD Lime      0.339526    339.525921      g
# 14         Input  Cooling Tower Chemicals      0.002370      2.369579      g
# 15         Input                    Water    278.940497     73.688299    gal
# 16         Input              Natural Gas     11.864353      0.530121  mmBTU
# 17         Input              Electricity     39.193354      0.133733  mmBTU
# 18         Input              Electricity     36.826966      0.125659  mmBTU
# 19    Co-product      Sodium Sulfate Salt    -25.601718 -25601.718253      g
# 20  Main Product         Renewable Diesel      1.000000      1.000000  mmBTU
# 21         Input                   Diesel      0.008525      0.008525  mmBTU
# 22         Input                   Diesel      0.006766      0.006766  mmBTU
# 23         Input              Electricity      0.000000      0.000000  mmBTU
# 24         Input                   Diesel      0.000000      0.000000  mmBTU
# 25         Input              Natural Gas      0.000000      0.000000  mmBTU
# 26         Input              Electricity    138.036424      0.000138  mmBTU
# 27         Input                   Diesel   1176.596189      0.001177  mmBTU
# 28         Input              Natural Gas      0.000000      0.000000  mmBTU
# 29         Input              Electricity  50244.001838      0.050244  mmBTU
# 30         Input                   Diesel      0.000000      0.000000  mmBTU
# 31         Input              Natural Gas      0.000000      0.000000  mmBTU
# 32         Input              Electricity   2066.006943      0.002066  mmBTU
# 33         Input                   Diesel      0.000000      0.000000  mmBTU
# 34         Input              Natural Gas      0.000000      0.000000  mmBTU
# 35         Input                   Diesel      0.008349      0.008349  mmBTU
# 36         Input                   Diesel      0.006626      0.006626  mmBTU
# 37         Input              Electricity   4810.775036      0.004811  mmBTU
# 38         Input                   Diesel      0.000000      0.000000  mmBTU
# 39         Input              Natural Gas      0.000000      0.000000  mmBTU
# 40         Input              Corn Stover      0.207450      0.207450    ton
# 41         Input                   Diesel  18471.384615      0.018471  mmBTU
# 42         Input              Electricity      0.000000      0.000000  mmBTU
# 43         Input              Natural Gas      0.000000      0.000000  mmBTU
# 0          Input                   Diesel      1.000000      1.000000  mmBTU
#
#               CO2    CO2_Sum        Amount            GHG    GHG_Sum  \
# 0        1.850362   6.502424   3707.610287       2.009157   7.060453
# 1        1.096125  12.839771  12358.700962       1.120540  13.125764
# 2        2.378175   0.305930    135.723186       2.635550   0.339039
# 3        2.378175   8.817084   3911.618969       2.635550   9.771299
# 4        0.514763   1.400911   2871.300398       0.771357   2.099223
# 5        0.891313   1.698340   2010.341448       1.672073   3.186027
# 6        0.060945   0.000916     15.862299       0.064980   0.000977
# 7        0.000000   0.000000     79.979703       0.000000   0.000000
# 8        0.000000   0.000000     19.493175       0.000000   0.000000
# 9        1.540386   0.327781    224.506952       1.671290   0.355636
# 10       1.168144   1.055768    953.558684       1.272029   1.149659
# 11   78307.418265  15.982724      0.215339   84192.026833  17.183786
# 12       0.000000   0.000000      1.013276       0.000000   0.000000
# 13       1.260847   0.405751    339.525921       1.282589   0.412748
# 14       0.000000   0.000000      2.369579       0.000000   0.000000
# 15       0.000000   0.000000     73.688299       0.000000   0.000000
# 16   65502.860419  32.912412      0.530121   72724.381819  36.540920
# 17  120183.904109  15.233873      0.133733  128879.369583  16.336064
# 18  120183.904109  14.314093      0.125659  128879.369583  15.349737
# 19       0.172558  -4.187257 -25601.718253       0.185530  -4.502013
# 20   75019.638598  71.104898      1.000000     146.407942   0.138768
# 21   90868.858430   0.734241      0.008525   94578.706026   0.764217
# 22   90797.481510   0.582273      0.006766   94591.721229   0.606605
# 23  120183.904109   0.000000      0.000000  128879.369583   0.000000
# 24   91113.013361   0.000000      0.000000   94636.902577   0.000000
# 25   65502.860419   0.000000      0.000000   72724.381819   0.000000
# 26  120183.904109   0.015724      0.000138  128879.369583   0.016862
# 27   90298.586693   0.100701      0.001177   94802.669831   0.105724
# 28   65502.860419   0.000000      0.000000   72724.381819   0.000000
# 29  120183.904109   5.723413      0.050244  128879.369583   6.137509
# 30   91113.013361   0.000000      0.000000   94636.902577   0.000000
# 31   65502.860419   0.000000      0.000000   72724.381819   0.000000
# 32  120183.904109   0.235344      0.002066  128879.369583   0.252371
# 33   91113.013361   0.000000      0.000000   94636.902577   0.000000
# 34   65502.860419   0.000000      0.000000   72724.381819   0.000000
# 35   90868.858430   0.719062      0.008349   94578.706026   0.748419
# 36   90797.481510   0.570236      0.006626   94591.721229   0.594065
# 37  120183.904109   0.548007      0.004811  128879.369583   0.587656
# 38   91113.013361   0.000000      0.000000   94636.902577   0.000000
# 39   65502.860419   0.000000      0.000000   72724.381819   0.000000
# 40   22763.019076   4.475780      0.207450    2687.052565   0.528342
# 41   90697.852331   1.587892      0.018471   94789.615085   1.659529
# 42  120183.904109   0.000000      0.000000  128879.369583   0.000000
# 43   65502.860419   0.000000      0.000000   72724.381819   0.000000
# 0    90324.772528  85.611366      1.000000   95451.868737  90.470916
#
#                           Process
# 0                 Fuel production
# 1                 Fuel production
# 2                 Fuel production
# 3                 Fuel production
# 4                 Fuel production
# 5                 Fuel production
# 6                 Fuel production
# 7                 Fuel production
# 8                 Fuel production
# 9                 Fuel production
# 10                Fuel production
# 11                Fuel production
# 12                Fuel production
# 13                Fuel production
# 14                Fuel production
# 15                Fuel production
# 16                Fuel production
# 17                Fuel production
# 18                Fuel production
# 19                Fuel production
# 20                Fuel production
# 21  Transportation to biorefinery
# 22  Transportation to biorefinery
# 23                       Blending
# 24                       Blending
# 25                       Blending
# 26                       Handling
# 27                       Handling
# 28                       Handling
# 29                  Preprocessing
# 30                  Preprocessing
# 31                  Preprocessing
# 32                  Depot storage
# 33                  Depot storage
# 34                  Depot storage
# 35        Transportation to depot
# 36        Transportation to depot
# 37                  Field storage
# 38                  Field storage
# 39                  Field storage
# 40         Harvest and collection
# 41         Harvest and collection
# 42         Harvest and collection
# 43         Harvest and collection
# 0              diesel (Incumbent)

# %%
calculate_allocation_ratio(format_input(lci_mapping['Fuel production'], "mass"))
# Out:
# 0.831334067862151

# %%
calculate_allocation_ratio(format_input(lci_mapping['Fuel production'], "energy"))
# Out:
# 0.8468407079764718

# %%
allocation(format_input(lci_mapping['Fuel production'], "mass"))
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input                     Fuel
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input  Chemicals and catalysts
# 16                       Input                    Water
# 17                       Input                     Fuel
# 18                       Input              Electricity
# 19                       Input              Electricity
# 20                  Co-product  Chemicals and catalysts
# 21                Main Product                     Fuel
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1                   caustic
# 2          sodium carbonate                                               use
# 3                   ammonia
# 4                   ammonia
# 5                   glucose
# 6         corn steep liquor
# 7                  corn oil
# 8            host nutrients
# 9            sulfur dioxide
# 10     diammonium phosphate
# 11               flocculant
# 12                 hydrogen
# 13         boiler chemicals
# 14                 fgd lime
# 15  cooling tower chemicals
# 16                    water
# 17              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 18              electricity                                          u.s. mix
# 19              electricity                                          u.s. mix
# 20      sodium sulfate salt
# 21         renewable diesel           fuel distribution and vehicle operation
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   154.642500     kg       0.2  Transportation to biorefinery
# 1     3.711420     kg       0.0                            NaN
# 2    12.371400     kg       0.0                            NaN
# 3     0.135723     kg       0.0                            NaN
# 4     3.915638     kg       0.0                            NaN
# 5     2.871300     kg       0.0                            NaN
# 6     2.010341     kg       0.0                            NaN
# 7     0.015862     kg       0.0                            NaN
# 8     0.079980     kg       0.0                            NaN
# 9     0.019493     kg       0.0                            NaN
# 10    0.224507     kg       0.0                            NaN
# 11    0.953559     kg       0.0                            NaN
# 12    1.893501     kg       0.0                            NaN
# 13    0.001014     kg       0.0                            NaN
# 14    0.339875     kg       0.0                            NaN
# 15    0.002372     kg       0.0                            NaN
# 16  279.227119     kg       0.0                            NaN
# 17   11.876544     kg       0.0                            NaN
# 18   39.193354    kWh       0.0                            NaN
# 19   36.864807    kWh       0.0                            NaN
# 20  -25.628025     kg       0.0                            NaN
# 21    1.000000  mmBTU       0.0                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No          Both  ...
# 2                                              No          Both  ...
# 3                                              No  Main product  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No  Main product  ...
# 7                                              No  Main product  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No          Both  ...
# 14                                             No          Both  ...
# 15                                             No          Both  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No  Main product  ...
# 19                                             No          Both  ...
# 20                                            Yes          Both  ...
# 21                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN                  caustic
# 2            NaN                NaN         sodium carbonate
# 3            NaN                NaN                  ammonia
# 4            NaN                NaN                  ammonia
# 5            NaN                NaN                  glucose
# 6            NaN                NaN        corn steep liquor
# 7            NaN                NaN                 corn oil
# 8            NaN                NaN           host nutrients
# 9            NaN                NaN           sulfur dioxide
# 10           NaN                NaN     diammonium phosphate
# 11           NaN                NaN               flocculant
# 12           NaN                NaN                 hydrogen
# 13           NaN                NaN         boiler chemicals
# 14           NaN                NaN                 fgd lime
# 15           NaN                NaN  cooling tower chemicals
# 16           NaN                NaN                    water
# 17           NaN                NaN              natural gas
# 18           NaN                NaN              electricity
# 19           NaN                NaN              electricity
# 20           NaN                NaN      sodium sulfate salt
# 21     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                use        NaN  NaN
# 3                                                           NaN  NaN
# 4                                                           NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 18                                          u.s. mix        NaN  NaN
# 19                                          u.s. mix        NaN  NaN
# 20                                                          NaN  NaN
# 21                                light duty vehicle        NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production                  Caustic         NaN          NaN
# 2   Fuel production         Sodium carbonate         NaN          NaN
# 3   Fuel production                  Ammonia         NaN          NaN
# 4   Fuel production                  Ammonia         NaN          NaN
# 5   Fuel production                  Glucose         NaN          NaN
# 6   Fuel production        Corn Steep Liquor         NaN          NaN
# 7   Fuel production                 Corn oil         NaN          NaN
# 8   Fuel production           Host nutrients         NaN          NaN
# 9   Fuel production           Sulfur Dioxide         NaN          NaN
# 10  Fuel production     Diammonium Phosphate         NaN          NaN
# 11  Fuel production               Flocculant         NaN          NaN
# 12  Fuel production                 Hydrogen  119.986744     0.090052
# 13  Fuel production         Boiler Chemicals         NaN          NaN
# 14  Fuel production                 FGD Lime         NaN          NaN
# 15  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 16  Fuel production                    Water         NaN  1000.000000
# 17  Fuel production              Natural Gas   47.141814     0.776923
# 18  Fuel production              Electricity         NaN          NaN
# 19  Fuel production              Electricity         NaN          NaN
# 20  Fuel production      Sodium sulfate salt         NaN          NaN
# 21  Fuel production                   Diesel   43.995103   793.378565
#
# [22 rows x 22 columns]

# %%
allocation(format_input(lci_mapping['Fuel production'], "value"))
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input                     Fuel
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input  Chemicals and catalysts
# 16                       Input                    Water
# 17                       Input                     Fuel
# 18                       Input              Electricity
# 19                       Input              Electricity
# 20                  Co-product  Chemicals and catalysts
# 21                Main Product                     Fuel
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1                   caustic
# 2          sodium carbonate                                               use
# 3                   ammonia
# 4                   ammonia
# 5                   glucose
# 6         corn steep liquor
# 7                  corn oil
# 8            host nutrients
# 9            sulfur dioxide
# 10     diammonium phosphate
# 11               flocculant
# 12                 hydrogen
# 13         boiler chemicals
# 14                 fgd lime
# 15  cooling tower chemicals
# 16                    water
# 17              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 18              electricity                                          u.s. mix
# 19              electricity                                          u.s. mix
# 20      sodium sulfate salt
# 21         renewable diesel           fuel distribution and vehicle operation
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   154.642500     kg       0.2  Transportation to biorefinery
# 1     3.711420     kg       0.0                            NaN
# 2    12.371400     kg       0.0                            NaN
# 3     0.135723     kg       0.0                            NaN
# 4     3.915638     kg       0.0                            NaN
# 5     2.871300     kg       0.0                            NaN
# 6     2.010341     kg       0.0                            NaN
# 7     0.015862     kg       0.0                            NaN
# 8     0.079980     kg       0.0                            NaN
# 9     0.019493     kg       0.0                            NaN
# 10    0.224507     kg       0.0                            NaN
# 11    0.953559     kg       0.0                            NaN
# 12    1.893501     kg       0.0                            NaN
# 13    0.001014     kg       0.0                            NaN
# 14    0.339875     kg       0.0                            NaN
# 15    0.002372     kg       0.0                            NaN
# 16  279.227119     kg       0.0                            NaN
# 17   11.876544     kg       0.0                            NaN
# 18   39.193354    kWh       0.0                            NaN
# 19   36.864807    kWh       0.0                            NaN
# 20  -25.628025     kg       0.0                            NaN
# 21    1.000000  mmBTU       0.0                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No          Both  ...
# 2                                              No          Both  ...
# 3                                              No  Main product  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No  Main product  ...
# 7                                              No  Main product  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No          Both  ...
# 14                                             No          Both  ...
# 15                                             No          Both  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No  Main product  ...
# 19                                             No          Both  ...
# 20                                            Yes          Both  ...
# 21                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN                  caustic
# 2            NaN                NaN         sodium carbonate
# 3            NaN                NaN                  ammonia
# 4            NaN                NaN                  ammonia
# 5            NaN                NaN                  glucose
# 6            NaN                NaN        corn steep liquor
# 7            NaN                NaN                 corn oil
# 8            NaN                NaN           host nutrients
# 9            NaN                NaN           sulfur dioxide
# 10           NaN                NaN     diammonium phosphate
# 11           NaN                NaN               flocculant
# 12           NaN                NaN                 hydrogen
# 13           NaN                NaN         boiler chemicals
# 14           NaN                NaN                 fgd lime
# 15           NaN                NaN  cooling tower chemicals
# 16           NaN                NaN                    water
# 17           NaN                NaN              natural gas
# 18           NaN                NaN              electricity
# 19           NaN                NaN              electricity
# 20           NaN                NaN      sodium sulfate salt
# 21     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                use        NaN  NaN
# 3                                                           NaN  NaN
# 4                                                           NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 18                                          u.s. mix        NaN  NaN
# 19                                          u.s. mix        NaN  NaN
# 20                                                          NaN  NaN
# 21                                light duty vehicle        NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production                  Caustic         NaN          NaN
# 2   Fuel production         Sodium carbonate         NaN          NaN
# 3   Fuel production                  Ammonia         NaN          NaN
# 4   Fuel production                  Ammonia         NaN          NaN
# 5   Fuel production                  Glucose         NaN          NaN
# 6   Fuel production        Corn Steep Liquor         NaN          NaN
# 7   Fuel production                 Corn oil         NaN          NaN
# 8   Fuel production           Host nutrients         NaN          NaN
# 9   Fuel production           Sulfur Dioxide         NaN          NaN
# 10  Fuel production     Diammonium Phosphate         NaN          NaN
# 11  Fuel production               Flocculant         NaN          NaN
# 12  Fuel production                 Hydrogen  119.986744     0.090052
# 13  Fuel production         Boiler Chemicals         NaN          NaN
# 14  Fuel production                 FGD Lime         NaN          NaN
# 15  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 16  Fuel production                    Water         NaN  1000.000000
# 17  Fuel production              Natural Gas   47.141814     0.776923
# 18  Fuel production              Electricity         NaN          NaN
# 19  Fuel production              Electricity         NaN          NaN
# 20  Fuel production      Sodium sulfate salt         NaN          NaN
# 21  Fuel production                   Diesel   43.995103   793.378565
#
# [22 rows x 22 columns]

# %%
def calculate_allocation_ratio2(df, basis="mass"):
    """
    Calculate allcation ratio
    """
    product_flag = (df["Type"] == "Main Product") | (
        (df["Type"] == "Co-product")
        & (df["Always Use Displacement Method for Co-Product?"] == "No")
        & (
            df["Amount"] > 0
        )  # if amount is less than zero, it means displacement method has been applied (for example, if displacement method is used for a process)
    )  # Select the products that should be accounted for when calculating allocation ratios
    products = df[product_flag].copy()
    products = products.rename(columns={"Amount": "Input Amount"})

    if basis in ["mass", "energy"]:
        products["Primary Unit"] = "kg" if basis == "mass" else "mmBTU"
        products["Amount"] = products.apply(unit_conversion, axis=1)

    else:
        ###################### Implement market-value-based allocation here ###########################
        try:  # If price is not specified for a process, return 1 (i.e., assume there is no co-product)
            products["Primary Unit"] = products["Market Price Unit"].str[
                2:
            ]  # Obtain the unit: if the market price unit is $/kg, the calculated unit should be kg.
            products["Amount"] = products.apply(unit_conversion, axis=1)
            products["Amount"] = products["Amount"] * products["Market Price"]
        except:
            return 1

    # products = products[
    #     products["Amount"] > 0
    # ]  # Elimante the co-products to which displacement method has been applied
    ratio = (
        products.loc[products["Type"] == "Main Product", "Amount"].sum()
        / products["Amount"].sum()
    )
    return ratio, products

# %%
r, df = calculate_allocation_ratio2(format_input(lci_mapping['Fuel production'], False, "mass"))

# %%
r
# Out:
# 0.8468465628773019

# %%
df[['Resource', 'Amount']]
# Out:
#             Resource     Amount
# 24  renewable diesel  23.820488
# 25   betaketoadipate   4.308164

# %%
def format_input2(dff, apply_loss_factor=True, basis=None):
    """
    Formatting LCI data:
        1. Convert relevant column to lower cases
        2. Convert wet weight to dry weight
        3. Convert transportation distance to fuel consumption
        4. Merge with the properties dataframe (add the LHV and density columns)
        5. Combining multiple entries of "main products"
        6. Consider the loss factor of fuel distribution
        7. Normalize the LCI data: calculate the amount per unit main output

    Parameters:
        dff: Pandas DataFrame containing LCI data
        apply_loss_factor: whether or not to apply the loss factor of fuel distribution
        basis: the basis used for combining multiple main product entries, can be None, "mass", "energy", or "value"
    """

    df = dff.copy()  # Avoid chaning the original df
    rd_dist_loss = 1.00004514306778  # Loss factor of renewable diesel distribution

    # Step 1
    df["End Use"] = df["End Use"].fillna("")
    df["Incumbent Resource"] = df["Incumbent Product"].fillna("")
    df["End Use of Incumbent Product"] = df["End Use of Incumbent Product"].fillna("")
    df["Always Use Displacement Method for Co-Product?"] = df[
        "Always Use Displacement Method for Co-Product?"
    ].fillna("No")

    lower_case_cols = [
        "Resource",
        "End Use",
        "Incumbent Product",
        "End Use of Incumbent Product",
        # "Unit",
    ]

    for col in lower_case_cols:
        df[col] = df[col].str.strip().str.lower()

    # Step 2
    df["Moisture"] = df["Moisture"].fillna(0)
    df.loc[df["Category"] != "Transportation", "Amount"] = df.loc[
        df["Category"] != "Transportation", "Amount"
    ] * (1 - df["Moisture"])
    df.loc[df["Category"] == "Transportation", "Amount"] = df.loc[
        df["Category"] == "Transportation", "Amount"
    ] / (1 - df["Moisture"])

    # df.loc[df['Category']!='Transportation', 'Amount'] = df.loc[df['Category']!='Transportation', 'Amount'] / df.loc[df['Type']=='Main Product', 'Amount'].sum()

    # Step 3
    df = convert_transport_lci(df)

    # Step 4
    df = pd.merge(df, properties, left_on="Resource", right_index=True, how="left")

    # Step 5
    main_products = df[df["Type"] == "Main Product"].copy()
    main_product_category = main_products["Category"].values[0]
    main_product_resource = main_products["Resource"].values[0]
    main_product_end_use = main_products["End Use"].values[0]
    if len(main_products) > 1:
        if (
            basis is None
        ):  # Displacement method, combine multiple entries by the primary unit
            main_products["Primary Unit"] = combination_basis[main_product_category]
            main_products = main_products.rename(columns={"Amount": "Input Amount"})
            main_products["Amount"] = main_products.apply(unit_conversion, axis=1)
            main_products["Amount"] = main_products["Amount"].sum()
            main_products["Unit"] = main_products["Primary Unit"]
            main_products = main_products.drop(["Input Amount", "Primary Unit"], axis=1)
            df = pd.concat(
                [df[df["Type"] != "Main Product"], main_products.iloc[:1]],
                ignore_index=True,
            )
        else:
            main_products.iloc[1:, main_products.columns.get_loc("Type")] = "Co-product"
            main_products["Always Use Displacement Method for Co-Product?"] = "No"
            ratio = calculate_allocation_ratio(main_products, basis=basis)
            df.loc[df["Type"] != "Main Product", "Amount"] = (
                df.loc[df["Type"] != "Main Product", "Amount"] * ratio
            )
            df = pd.concat(
                [df[df["Type"] != "Main Product"], main_products.iloc[:1]],
                ignore_index=True,
            )

    # Step 6
    if (
        (main_product_resource == "renewable diesel")
        and ("distribution" in main_product_end_use)
        and (apply_loss_factor)
    ):
        df.loc[df["Type"] == "Main Product", "Amount"] = (
            df.loc[df["Type"] == "Main Product", "Amount"] / rd_dist_loss
        )

    # Step 7
    main_product_amount = df.loc[
        df["Type"] == "Main Product", "Amount"
    ].sum()  # TODO: need to make sure the units are consistent
    df["Amount"] = df["Amount"] / main_product_amount

    return df

# %%
23.820488/(	23.820488+4.308164)
# Out:
# 0.8468407231174817

# %%
basis = "mass"
final_process_lci = format_input(lci_mapping[final_process], False, basis=basis)
main_product_df = final_process_lci.loc[final_process_lci["Type"] == "Main Product"]
main_product_series = main_product_df.iloc[0].copy()
main_product_series["Input Amount"] = main_product_series["Amount"]
main_product_category = res_new.loc[
    res_new["Type"] == "Main Product", "Category"
].values[0]
main_product_series["Primary Unit"] = display_units[main_product_category]
conversion = unit_conversion(main_product_series)

# %%
total_biomass = 0  # Initialization
total_coproduct = 0

biomass_df = final_process_lci.loc[
    final_process_lci["Category"] == "Biomass",
].copy()

if len(biomass_df) > 0:
        biomass_df = biomass_df.rename(columns={"Amount": "Input Amount"})
        biomass_df["Primary Unit"] = "ton"
        biomass_df["Amount"] = biomass_df.apply(unit_conversion, axis=1)
        total_biomass = biomass_df["Amount"].sum() / conversion

if len(coproduct_res) > 0:
    coproduct_category = coproduct_res.loc[
        coproduct_res["Type"] == "Main Product", "Category"
    ].values[0]
    coproduct_target_unit = display_units[coproduct_category]
    coproduct_df = final_process_lci.loc[
        (final_process_lci["Type"] == "Co-product")
        & (
            final_process_lci["Always Use Displacement Method for Co-Product?"]
            == "No"
        ),
    ].copy()
    coproduct_df = coproduct_df.rename(columns={"Amount": "Input Amount"})
    coproduct_df["Primary Unit"] = coproduct_target_unit
    coproduct_df["Amount"] = coproduct_df.apply(unit_conversion, axis=1)
    total_coproduct = coproduct_df["Amount"].sum() / conversion

# %%
tab = "GHG"
# lci_mapping, coproduct_mapping, final_process_mapping = read_data("2021 Biochem SOT via BDO_working.xlsm")
# lci_mapping, coproduct_mapping, final_process_mapping = read_data("Feedstock test2.xlsm")
# lci_mapping, coproduct_mapping, final_process_mapping = read_data("Feedstock test2-with INL data.xlsm")
lci_mapping, coproduct_mapping, final_process_mapping = read_data("sludge HTL3.xlsm")
coproduct_mapping = {key: "Displacement Method" for key in coproduct_mapping}
coproduct_lci = generate_coproduct_lci(
                lci_mapping, coproduct_mapping, final_process_mapping
)
overall_lci, final_process = generate_final_lci(lci_mapping, coproduct_mapping, final_process_mapping, True)
if coproduct_lci is not None:
    coproduct_res = calc(coproduct_lci)
# # test = generate_final_lci(lci_mapping, coproduct_mapping, final_process_mapping, True)

res_new_with_incumbent = calc(overall_lci, True)
res_new = res_new_with_incumbent[
        ~res_new_with_incumbent["Pathway"].str.contains("Incumbent")
    ]
main_product_total = res_new[tab + "_Sum"].sum()
main_incumbent_total = res_new_with_incumbent.loc[
        res_new_with_incumbent["Pathway"].str.contains("Incumbent"),
        tab + "_Sum",
    ].sum()
#

# %%
res_new['CO2_Sum'].sum()-71.017164
# Out:
# 18.376421378308706

# %%
res_new['GHG_Sum'].sum()
# Out:
# 19.984767532929844

# %%
res_new[['Type', 'Resource', 'Input Amount', 'Unit', 'CO2', 'CO2_Sum', 'Amount']]
# Out:
#             Type                  Resource  Input Amount   Unit  \
# 0          Input               Natural Gas      3.932129  mmBTU
# 1          Input               Electricity      3.014873  mmBTU
# 2          Input     Como/Γ-Al2O3 Catalyst      0.053781      g
# 3          Input     Nimo/Γ-Al2O3 Catalyst      0.008666      g
# 4          Input  Pt/ Gamma Al2O3 Catalyst      0.000444      g
# 5          Input                        Ni      0.000721      g
# 6          Input                     Water     45.141458    gal
# 7          Input                     Water     19.860677    gal
# 8   Main Product          Renewable Diesel      1.000000  mmBTU
# 9          Input                    Sludge    179.168747      g
# 10         Input               Natural Gas      4.475964  mmBTU
# 11         Input               Electricity      6.362124  mmBTU
# 12         Input                   Polymer      0.814774      g
# 13         Input                      Lime      7.957739      g
# 14         Input                     Water      3.847261    gal
# 15         Input         Co2 Sequestration      3.141206      g
# 16         Input                    Diesel      0.002735  mmBTU
# 17         Input                    Diesel      0.002171  mmBTU
# 18         Input                    Diesel      0.000328  mmBTU
# 19         Input                    Diesel      0.000261  mmBTU
#
#               CO2    CO2_Sum        Amount
# 0    65548.593181   4.951221      0.079694
# 1   120183.904109   1.171836      0.010287
# 2        8.622311   0.199361     24.394491
# 3        2.990643   0.011142      3.930784
# 4        6.377758   0.001216      0.201174
# 5        8.778408   0.002720      0.326963
# 6        0.000000   0.000000      5.409141
# 7        0.000000   0.000000      2.379834
# 8    74927.074009  71.017164      1.000000
# 9        0.000000   0.000000  81269.576393
# 10   65502.860419   5.632070      0.090716
# 11  120183.904109   2.472863      0.021708
# 12       1.168144   0.409189    369.575293
# 13       1.260847   4.313624   3609.569894
# 14       0.000000   0.000000      0.461004
# 15      -1.000000  -1.350475   1424.827051
# 16   90868.858430   0.235576      0.002735
# 17   90797.481510   0.186818      0.002171
# 18   90868.858430   0.028277      0.000328
# 19   90797.481510   0.022425      0.000261

# %%
0.000937+0.000743
# Out:
# 0.00168

# %%
ser["Primary Unit"]
# Out:
# 'g'

# %%
unit_conversion(res.iloc[0])
# Out:
# 1157.4805755323064

# %%
overall_lci
# Out:
#            Type                 Category     Resource  \
# 0         Input                    Waste       sludge
# 1         Input                     Fuel  natural gas
# 2         Input              Electricity  electricity
# 3         Input  Chemicals and catalysts      polymer
# 4         Input  Chemicals and catalysts         lime
# 5         Input                    Water        water
# 6  Main Product                    Other     biocrude
#
#                                             End Use    Amount Unit  Moisture  \
# 0                                                    2.551808   lb       0.0
# 1  utility/ industrial boiler (>100 mmbtu/hr input)  0.063749   lb       0.0
# 2                                          u.s. mix  0.090612  kWh       0.0
# 3                                                    0.011604   lb       0.0
# 4                                                    0.113338   lb       0.0
# 5                                                    0.054795   lb       0.0
# 6                                                    1.000000   lb       0.0
#
#    Previous Process Always Use Displacement Method for Co-Product?  \
# 0               NaN                                             No
# 1               NaN                                             No
# 2               NaN                                             No
# 3               NaN                                             No
# 4               NaN                                             No
# 5               NaN                                             No
# 6               NaN                                             No
#
#    Product Train  ...  Market Price  Market Price Unit  Incumbent Product  \
# 0            NaN  ...           NaN                NaN             sludge
# 1            NaN  ...           NaN                NaN        natural gas
# 2            NaN  ...           NaN                NaN        electricity
# 3            NaN  ...           NaN                NaN            polymer
# 4            NaN  ...           NaN                NaN               lime
# 5            NaN  ...           NaN                NaN              water
# 6            NaN  ...           NaN                NaN           biocrude
#
#                        End Use of Incumbent Product Subprocess Note  Process  \
# 0                                                          NaN  NaN      HTL
# 1  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN      HTL
# 2                                          u.s. mix        NaN  NaN      HTL
# 3                                                          NaN  NaN      HTL
# 4                                                          NaN  NaN      HTL
# 5                                                          NaN  NaN      HTL
# 6                                                          NaN  NaN      HTL
#
#    Incumbent Resource        LHV      Density
# 0              Sludge        NaN          NaN
# 1         Natural Gas  47.141814     0.776923
# 2         Electricity        NaN          NaN
# 3             Polymer        NaN          NaN
# 4                Lime        NaN          NaN
# 5               Water        NaN  1000.000000
# 6            Biocrude        NaN          NaN
#
# [7 rows x 22 columns]

# %%
coproduct_res
# Out:
#             Type                 Category         Resource End Use  \
# 25  Main Product  Chemicals and catalysts  Betaketoadipate
# 0          Input  Chemicals and catalysts      Adipic Acid
#
#     Input Amount Unit  Moisture Previous Process  \
# 25           1.0    g       0.0              NaN
# 0            1.0    g       NaN              NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 25                                             No    Co-product  ...
# 0                                             NaN           NaN  ...
#
#     PM2.5_Sum   SOx_Sum    BC_Sum    OC_Sum   CH4_Sum   N2O_Sum   CO2_Sum  \
# 25   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    0.000307  0.001822  0.000046  0.000112  0.015793  0.017427  4.287973
#
#     Biogenic CO2_Sum CO2 (w/ C in VOC & CO)_Sum   GHG_Sum
# 25               0.0                   0.000000  0.000000
# 0                0.0                   4.305206  9.397273
#
# [2 rows x 65 columns]

# %%
# basis = "value"
basis = None
final_process_lci = format_input(lci_mapping[final_process], False, basis=basis)
main_product_df = final_process_lci.loc[final_process_lci["Type"] == "Main Product"]
main_product_series = main_product_df.iloc[0].copy()
main_product_series["Input Amount"] = main_product_series["Amount"]
main_product_category = res_new.loc[
    res_new["Type"] == "Main Product", "Category"
].values[0]
main_product_series["Primary Unit"] = display_units[main_product_category]
conversion = unit_conversion(main_product_series)

total_biomass = 0  # Initialization
total_coproduct = 0

biomass_df = final_process_lci.loc[
    final_process_lci["Category"] == "Biomass",
].copy()
biomass_df = biomass_df.rename(columns={"Amount": "Input Amount"})
biomass_df["Primary Unit"] = "ton"
biomass_df["Amount"] = biomass_df.apply(unit_conversion, axis=1)
total_biomass = biomass_df["Amount"].sum() / conversion

if len(coproduct_res) > 0:
    coproduct_category = coproduct_res.loc[
        coproduct_res["Type"] == "Main Product", "Category"
    ].values[0]
    coproduct_target_unit = display_units[coproduct_category]
    coproduct_df = final_process_lci.loc[
        (final_process_lci["Type"] == "Co-product")
        & (
            final_process_lci["Always Use Displacement Method for Co-Product?"]
            == "No"
        ),
    ].copy()
    coproduct_df = coproduct_df.rename(columns={"Amount": "Input Amount"})
    coproduct_df["Primary Unit"] = coproduct_target_unit
    coproduct_df["Amount"] = coproduct_df.apply(unit_conversion, axis=1)
    total_coproduct = coproduct_df["Amount"].sum()

# %%
coproduct_total = coproduct_res[tab + "_Sum"].sum()

# %%
coproduct_res
# Out:
#             Type                 Category         Resource End Use  \
# 25  Main Product  Chemicals and catalysts  Betaketoadipate
# 0          Input  Chemicals and catalysts      Adipic Acid
#
#     Input Amount Unit  Moisture Previous Process  \
# 25           1.0    g       0.0              NaN
# 0            1.0    g       NaN              NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 25                                             No    Co-product  ...
# 0                                             NaN           NaN  ...
#
#     PM2.5_Sum   SOx_Sum    BC_Sum    OC_Sum   CH4_Sum   N2O_Sum   CO2_Sum  \
# 25   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 0    0.000307  0.001822  0.000046  0.000112  0.015793  0.017427  4.287973
#
#     Biogenic CO2_Sum CO2 (w/ C in VOC & CO)_Sum   GHG_Sum
# 25               0.0                   0.000000  0.000000
# 0                0.0                   4.305206  9.397273
#
# [2 rows x 65 columns]

# %%
coproduct_total = 4.8
cpproduct_conversion = 1
coproduct_contribution = (
        coproduct_total
        * total_coproduct
        * coproduct_conversion
        / total_biomass
        / biorefinery_conversion[tab] / conversion
    )

# %%
coproduct_total * total_coproduct / total_biomass / conversion
# Out:
# 102836.70107511932

# %%
coproduct_conversion
# Out:
# 1

# %%
main_conversion = 1
coproduct_conversion = 1
# if main_product_category in [
#     "Electricity",
#     "Fuel",
# ]:
#     main_conversion = energy.loc["MJ", "mmBTU"]

# total_biomass = data["total_biomass"]
# total_coproduct = data["total_coproduct"]
main_contribution = (
    main_product_total
    * 1
    * main_conversion
    / total_biomass
    / biorefinery_conversion[tab])

# %%
main_contribution
# Out:
# 618.5254303844678

# %%
main_conversion
# Out:
# 1055.05585

# %%
total_biomass
# Out:
# 0.00019058570390428426

# %%
final_process_lci
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input  Chemicals and catalysts
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input                     Fuel
# 16                       Input  Chemicals and catalysts
# 17                       Input  Chemicals and catalysts
# 18                       Input  Chemicals and catalysts
# 19                       Input                    Water
# 20                       Input                     Fuel
# 21                       Input              Electricity
# 22                       Input              Electricity
# 23                       Input              Electricity
# 24                Main Product                     Fuel
# 25                  Co-product  Chemicals and catalysts
# 26                  Co-product  Chemicals and catalysts
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1             sulfuric acid
# 2                   caustic
# 3                   caustic
# 4          sodium carbonate                                               use
# 5                   ammonia
# 6                   ammonia
# 7                   ammonia
# 8                   glucose
# 9         corn steep liquor
# 10                 corn oil
# 11           host nutrients
# 12           sulfur dioxide
# 13     diammonium phosphate
# 14               flocculant
# 15                 hydrogen
# 16         boiler chemicals
# 17                 fgd lime
# 18  cooling tower chemicals
# 19                    water
# 20              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 21              electricity                                          u.s. mix
# 22              electricity                                          u.s. mix
# 23              electricity                                          u.s. mix
# 24         renewable diesel           fuel distribution and vehicle operation
# 25          betaketoadipate                                     sequestration
# 26      sodium sulfate salt
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   182.415403     kg      0.20  Transportation to biorefinery
# 1    21.419076     kg      0.07                            NaN
# 2     3.462974     kg      0.00                            NaN
# 3     4.377970     kg      0.00                            NaN
# 4    14.593232     kg      0.00                            NaN
# 5     0.135717     kg      0.00                            NaN
# 6     0.037213     kg      0.00                            NaN
# 7     4.618864     kg      0.00                            NaN
# 8     2.871171     kg      0.00                            NaN
# 9     2.010251     kg      0.00                            NaN
# 10    0.015862     kg      0.00                            NaN
# 11    0.079976     kg      0.00                            NaN
# 12    0.019492     kg      0.00                            NaN
# 13    0.224497     kg      0.00                            NaN
# 14    0.953516     kg      0.00                            NaN
# 15    1.893415     kg      0.00                            NaN
# 16    0.001196     kg      0.00                            NaN
# 17    0.400914     kg      0.00                            NaN
# 18    0.002798     kg      0.00                            NaN
# 19  329.374702     kg      0.00                            NaN
# 20   14.009503     kg      0.00                            NaN
# 21   39.191584    kWh      0.00                            NaN
# 22    7.230217    kWh      0.00                            NaN
# 23   43.485514    kWh      0.00                            NaN
# 24    1.000000  mmBTU      0.00                            NaN
# 25    4.307970     kg      0.00                            NaN
# 26   30.230671     kg      0.00                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No    Co-product  ...
# 2                                              No    Co-product  ...
# 3                                              No          Both  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No    Co-product  ...
# 7                                              No          Both  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No  Main product  ...
# 14                                             No  Main product  ...
# 15                                             No  Main product  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No          Both  ...
# 19                                             No          Both  ...
# 20                                             No          Both  ...
# 21                                             No  Main product  ...
# 22                                             No    Co-product  ...
# 23                                             No          Both  ...
# 24                                             No  Main product  ...
# 25                                             No    Co-product  ...
# 26                                            Yes          Both  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN            sulfuric acid
# 2            NaN                NaN                  caustic
# 3            NaN                NaN                  caustic
# 4            NaN                NaN         sodium carbonate
# 5            NaN                NaN                  ammonia
# 6            NaN                NaN                  ammonia
# 7            NaN                NaN                  ammonia
# 8            NaN                NaN                  glucose
# 9            NaN                NaN        corn steep liquor
# 10           NaN                NaN                 corn oil
# 11           NaN                NaN           host nutrients
# 12           NaN                NaN           sulfur dioxide
# 13           NaN                NaN     diammonium phosphate
# 14           NaN                NaN               flocculant
# 15           NaN                NaN                 hydrogen
# 16           NaN                NaN         boiler chemicals
# 17           NaN                NaN                 fgd lime
# 18           NaN                NaN  cooling tower chemicals
# 19           NaN                NaN                    water
# 20           NaN                NaN              natural gas
# 21           NaN                NaN              electricity
# 22           NaN                NaN              electricity
# 23           NaN                NaN              electricity
# 24     21.535016            $/mmBTU                   diesel
# 25      1.873939               $/kg              adipic acid
# 26           NaN                NaN      sodium sulfate salt
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                           NaN  NaN
# 3                                                           NaN  NaN
# 4                                                use        NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17                                                          NaN  NaN
# 18                                                          NaN  NaN
# 19                                                          NaN  NaN
# 20  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 21                                          u.s. mix        NaN  NaN
# 22                                          u.s. mix        NaN  NaN
# 23                                          u.s. mix        NaN  NaN
# 24                                light duty vehicle        NaN  NaN
# 25                                                          NaN  NaN
# 26                                                          NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production            Sulfuric Acid         NaN          NaN
# 2   Fuel production                  Caustic         NaN          NaN
# 3   Fuel production                  Caustic         NaN          NaN
# 4   Fuel production         Sodium carbonate         NaN          NaN
# 5   Fuel production                  Ammonia         NaN          NaN
# 6   Fuel production                  Ammonia         NaN          NaN
# 7   Fuel production                  Ammonia         NaN          NaN
# 8   Fuel production                  Glucose         NaN          NaN
# 9   Fuel production        Corn Steep Liquor         NaN          NaN
# 10  Fuel production                 Corn oil         NaN          NaN
# 11  Fuel production           Host nutrients         NaN          NaN
# 12  Fuel production           Sulfur Dioxide         NaN          NaN
# 13  Fuel production     Diammonium Phosphate         NaN          NaN
# 14  Fuel production               Flocculant         NaN          NaN
# 15  Fuel production                 Hydrogen  119.986744     0.090052
# 16  Fuel production         Boiler Chemicals         NaN          NaN
# 17  Fuel production                 FGD Lime         NaN          NaN
# 18  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 19  Fuel production                    Water         NaN  1000.000000
# 20  Fuel production              Natural Gas   47.141814     0.776923
# 21  Fuel production              Electricity         NaN          NaN
# 22  Fuel production              Electricity         NaN          NaN
# 23  Fuel production              Electricity         NaN          NaN
# 24  Fuel production                   Diesel   43.400834   793.378565
# 25  Fuel production              Adipic Acid         NaN          NaN
# 26  Fuel production      Sodium sulfate salt         NaN          NaN
#
# [27 rows x 22 columns]

# %%
df = lci_mapping['Fuel production']
main_products = df[df["Type"] == "Main Product"].copy()
main_products
# Out:
#             Type Category            Resource  \
# 24  Main Product     Fuel    Renewable Diesel
# 25  Main Product     Fuel  Renewable Gasoline
#
#                                     End Use      Amount Unit  Moisture  \
# 24  Fuel Distribution and Vehicle Operation  400.000000   kg       NaN
# 25  Fuel Distribution and Vehicle Operation   56.832769   kg       NaN
#
#    Previous Process Always Use Displacement Method for Co-Product?  \
# 24              NaN                                            NaN
# 25              NaN                                            NaN
#
#    Product Train  Payload  Payload Unit  Market Price Market Price Unit  \
# 24  Main product      NaN           NaN     21.535016           $/mmBTU
# 25           NaN      NaN           NaN           NaN               NaN
#
#      Incumbent Product End Use of Incumbent Product  Subprocess  Note  \
# 24              Diesel           Light Duty Vehicle         NaN   NaN
# 25  Renewable Gasoline                          NaN         NaN   NaN
#
#             Process
# 24  Fuel production
# 25  Fuel production

# %%
main_products.iloc[1:, main_products.columns.get_loc("Type")] = "Co-product"

# %%
format_input(lci_mapping['Fuel production'], basis="mass").head(2)
# Out:
# 0.8755939308005856
#                          Type                 Category       Resource End Use  \
# 0  Input from Another Process                  Biomass    corn stover
# 1                       Input  Chemicals and catalysts  sulfuric acid
#
#        Amount Unit  Moisture               Previous Process  \
# 0  182.423638   kg      0.20  Transportation to biorefinery
# 1   21.420043   kg      0.07                            NaN
#
#   Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                             No          Both  ...
# 1                                             No    Co-product  ...
#
#    Market Price  Market Price Unit  Incumbent Product  \
# 0           NaN                NaN        corn stover
# 1           NaN                NaN      sulfuric acid
#
#   End Use of Incumbent Product Subprocess Note          Process  \
# 0                                     NaN  NaN  Fuel production
# 1                                     NaN  NaN  Fuel production
#
#    Incumbent Resource        LHV Density
# 0         Corn Stover  17.114708     NaN
# 1       Sulfuric Acid        NaN     NaN
#
# [2 rows x 22 columns]

# %%
format_input(lci_mapping['Fuel production'], basis='energy')
# Out:
# 0.888895144381354
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input  Chemicals and catalysts
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input                     Fuel
# 16                       Input  Chemicals and catalysts
# 17                       Input  Chemicals and catalysts
# 18                       Input  Chemicals and catalysts
# 19                       Input                    Water
# 20                       Input                     Fuel
# 21                       Input              Electricity
# 22                       Input              Electricity
# 23                       Input              Electricity
# 24                  Co-product  Chemicals and catalysts
# 25                  Co-product  Chemicals and catalysts
# 26                Main Product                     Fuel
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1             sulfuric acid
# 2                   caustic
# 3                   caustic
# 4          sodium carbonate                                               use
# 5                   ammonia
# 6                   ammonia
# 7                   ammonia
# 8                   glucose
# 9         corn steep liquor
# 10                 corn oil
# 11           host nutrients
# 12           sulfur dioxide
# 13     diammonium phosphate
# 14               flocculant
# 15                 hydrogen
# 16         boiler chemicals
# 17                 fgd lime
# 18  cooling tower chemicals
# 19                    water
# 20              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 21              electricity                                          u.s. mix
# 22              electricity                                          u.s. mix
# 23              electricity                                          u.s. mix
# 24          betaketoadipate                                     sequestration
# 25      sodium sulfate salt
# 26         renewable diesel           fuel distribution and vehicle operation
#
#         Amount Unit  Moisture               Previous Process  \
# 0   185.194849   kg      0.20  Transportation to biorefinery
# 1    21.745437   kg      0.07                            NaN
# 2     3.515739   kg      0.00                            NaN
# 3     4.444676   kg      0.00                            NaN
# 4    14.815588   kg      0.00                            NaN
# 5     0.137785   kg      0.00                            NaN
# 6     0.037780   kg      0.00                            NaN
# 7     4.689242   kg      0.00                            NaN
# 8     2.914919   kg      0.00                            NaN
# 9     2.040881   kg      0.00                            NaN
# 10    0.016103   kg      0.00                            NaN
# 11    0.081195   kg      0.00                            NaN
# 12    0.019789   kg      0.00                            NaN
# 13    0.227917   kg      0.00                            NaN
# 14    0.968044   kg      0.00                            NaN
# 15    1.922265   kg      0.00                            NaN
# 16    0.001215   kg      0.00                            NaN
# 17    0.407023   kg      0.00                            NaN
# 18    0.002841   kg      0.00                            NaN
# 19  334.393352   kg      0.00                            NaN
# 20   14.222964   kg      0.00                            NaN
# 21   39.788743  kWh      0.00                            NaN
# 22    7.340383  kWh      0.00                            NaN
# 23   44.148098  kWh      0.00                            NaN
# 24    4.373610   kg      0.00                            NaN
# 25   30.691293   kg      0.00                            NaN
# 26    1.000000   kg      0.00                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No    Co-product  ...
# 2                                              No    Co-product  ...
# 3                                              No          Both  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No    Co-product  ...
# 7                                              No          Both  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No  Main product  ...
# 14                                             No  Main product  ...
# 15                                             No  Main product  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No          Both  ...
# 19                                             No          Both  ...
# 20                                             No          Both  ...
# 21                                             No  Main product  ...
# 22                                             No    Co-product  ...
# 23                                             No          Both  ...
# 24                                             No    Co-product  ...
# 25                                            Yes          Both  ...
# 26                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN            sulfuric acid
# 2            NaN                NaN                  caustic
# 3            NaN                NaN                  caustic
# 4            NaN                NaN         sodium carbonate
# 5            NaN                NaN                  ammonia
# 6            NaN                NaN                  ammonia
# 7            NaN                NaN                  ammonia
# 8            NaN                NaN                  glucose
# 9            NaN                NaN        corn steep liquor
# 10           NaN                NaN                 corn oil
# 11           NaN                NaN           host nutrients
# 12           NaN                NaN           sulfur dioxide
# 13           NaN                NaN     diammonium phosphate
# 14           NaN                NaN               flocculant
# 15           NaN                NaN                 hydrogen
# 16           NaN                NaN         boiler chemicals
# 17           NaN                NaN                 fgd lime
# 18           NaN                NaN  cooling tower chemicals
# 19           NaN                NaN                    water
# 20           NaN                NaN              natural gas
# 21           NaN                NaN              electricity
# 22           NaN                NaN              electricity
# 23           NaN                NaN              electricity
# 24      1.873939               $/kg              adipic acid
# 25           NaN                NaN      sodium sulfate salt
# 26     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                           NaN  NaN
# 3                                                           NaN  NaN
# 4                                                use        NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17                                                          NaN  NaN
# 18                                                          NaN  NaN
# 19                                                          NaN  NaN
# 20  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 21                                          u.s. mix        NaN  NaN
# 22                                          u.s. mix        NaN  NaN
# 23                                          u.s. mix        NaN  NaN
# 24                                                          NaN  NaN
# 25                                                          NaN  NaN
# 26                                light duty vehicle        NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production            Sulfuric Acid         NaN          NaN
# 2   Fuel production                  Caustic         NaN          NaN
# 3   Fuel production                  Caustic         NaN          NaN
# 4   Fuel production         Sodium carbonate         NaN          NaN
# 5   Fuel production                  Ammonia         NaN          NaN
# 6   Fuel production                  Ammonia         NaN          NaN
# 7   Fuel production                  Ammonia         NaN          NaN
# 8   Fuel production                  Glucose         NaN          NaN
# 9   Fuel production        Corn Steep Liquor         NaN          NaN
# 10  Fuel production                 Corn oil         NaN          NaN
# 11  Fuel production           Host nutrients         NaN          NaN
# 12  Fuel production           Sulfur Dioxide         NaN          NaN
# 13  Fuel production     Diammonium Phosphate         NaN          NaN
# 14  Fuel production               Flocculant         NaN          NaN
# 15  Fuel production                 Hydrogen  119.986744     0.090052
# 16  Fuel production         Boiler Chemicals         NaN          NaN
# 17  Fuel production                 FGD Lime         NaN          NaN
# 18  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 19  Fuel production                    Water         NaN  1000.000000
# 20  Fuel production              Natural Gas   47.141814     0.776923
# 21  Fuel production              Electricity         NaN          NaN
# 22  Fuel production              Electricity         NaN          NaN
# 23  Fuel production              Electricity         NaN          NaN
# 24  Fuel production              Adipic Acid         NaN          NaN
# 25  Fuel production      Sodium sulfate salt         NaN          NaN
# 26  Fuel production                   Diesel   43.400834   793.378565
#
# [27 rows x 22 columns]

# %%
main_product_total
# Out:
# 117.88210453252417

# %%
117.88210453252417

# %%
117.87773834692493 * 1.00004514306778
# Out:
# 117.88305970965686

# %%
test['Fuel production']
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input                     Fuel
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input  Chemicals and catalysts
# 16                       Input                    Water
# 17                       Input                     Fuel
# 18                       Input              Electricity
# 19                       Input              Electricity
# 20                  Co-product  Chemicals and catalysts
# 21                Main Product                     Fuel
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1                   caustic
# 2          sodium carbonate                                               use
# 3                   ammonia
# 4                   ammonia
# 5                   glucose
# 6         corn steep liquor
# 7                  corn oil
# 8            host nutrients
# 9            sulfur dioxide
# 10     diammonium phosphate
# 11               flocculant
# 12                 hydrogen
# 13         boiler chemicals
# 14                 fgd lime
# 15  cooling tower chemicals
# 16                    water
# 17              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 18              electricity                                          u.s. mix
# 19              electricity                                          u.s. mix
# 20      sodium sulfate salt
# 21         renewable diesel           fuel distribution and vehicle operation
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   132.684095     kg       0.2  Transportation to biorefinery
# 1     3.184418     kg       0.0                            NaN
# 2    10.614728     kg       0.0                            NaN
# 3     0.135723     kg       0.0                            NaN
# 4     3.359639     kg       0.0                            NaN
# 5     2.871300     kg       0.0                            NaN
# 6     2.010341     kg       0.0                            NaN
# 7     0.015862     kg       0.0                            NaN
# 8     0.079980     kg       0.0                            NaN
# 9     0.019493     kg       0.0                            NaN
# 10    0.224507     kg       0.0                            NaN
# 11    0.953559     kg       0.0                            NaN
# 12    1.893501     kg       0.0                            NaN
# 13    0.000870     kg       0.0                            NaN
# 14    0.291614     kg       0.0                            NaN
# 15    0.002035     kg       0.0                            NaN
# 16  239.578365     kg       0.0                            NaN
# 17   10.190138     kg       0.0                            NaN
# 18   39.193354    kWh       0.0                            NaN
# 19   31.630202    kWh       0.0                            NaN
# 20  -21.988983     kg       0.0                            NaN
# 21    1.000045  mmBTU       0.0                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No          Both  ...
# 2                                              No          Both  ...
# 3                                              No  Main product  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No  Main product  ...
# 7                                              No  Main product  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No          Both  ...
# 14                                             No          Both  ...
# 15                                             No          Both  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No  Main product  ...
# 19                                             No          Both  ...
# 20                                            Yes          Both  ...
# 21                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN                  caustic
# 2            NaN                NaN         sodium carbonate
# 3            NaN                NaN                  ammonia
# 4            NaN                NaN                  ammonia
# 5            NaN                NaN                  glucose
# 6            NaN                NaN        corn steep liquor
# 7            NaN                NaN                 corn oil
# 8            NaN                NaN           host nutrients
# 9            NaN                NaN           sulfur dioxide
# 10           NaN                NaN     diammonium phosphate
# 11           NaN                NaN               flocculant
# 12           NaN                NaN                 hydrogen
# 13           NaN                NaN         boiler chemicals
# 14           NaN                NaN                 fgd lime
# 15           NaN                NaN  cooling tower chemicals
# 16           NaN                NaN                    water
# 17           NaN                NaN              natural gas
# 18           NaN                NaN              electricity
# 19           NaN                NaN              electricity
# 20           NaN                NaN      sodium sulfate salt
# 21     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                use        NaN  NaN
# 3                                                           NaN  NaN
# 4                                                           NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 18                                          u.s. mix        NaN  NaN
# 19                                          u.s. mix        NaN  NaN
# 20                                                          NaN  NaN
# 21                                light duty vehicle        NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production                  Caustic         NaN          NaN
# 2   Fuel production         Sodium carbonate         NaN          NaN
# 3   Fuel production                  Ammonia         NaN          NaN
# 4   Fuel production                  Ammonia         NaN          NaN
# 5   Fuel production                  Glucose         NaN          NaN
# 6   Fuel production        Corn Steep Liquor         NaN          NaN
# 7   Fuel production                 Corn oil         NaN          NaN
# 8   Fuel production           Host nutrients         NaN          NaN
# 9   Fuel production           Sulfur Dioxide         NaN          NaN
# 10  Fuel production     Diammonium Phosphate         NaN          NaN
# 11  Fuel production               Flocculant         NaN          NaN
# 12  Fuel production                 Hydrogen  119.986744     0.090052
# 13  Fuel production         Boiler Chemicals         NaN          NaN
# 14  Fuel production                 FGD Lime         NaN          NaN
# 15  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 16  Fuel production                    Water         NaN  1000.000000
# 17  Fuel production              Natural Gas   47.141814     0.776923
# 18  Fuel production              Electricity         NaN          NaN
# 19  Fuel production              Electricity         NaN          NaN
# 20  Fuel production      Sodium sulfate salt         NaN          NaN
# 21  Fuel production                   Diesel   43.400834   793.378565
#
# [22 rows x 22 columns]

# %%
test['Fuel production']
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input                     Fuel
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input  Chemicals and catalysts
# 16                       Input                    Water
# 17                       Input                     Fuel
# 18                       Input              Electricity
# 19                       Input              Electricity
# 20                  Co-product  Chemicals and catalysts
# 21                Main Product                     Fuel
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1                   caustic
# 2          sodium carbonate                                               use
# 3                   ammonia
# 4                   ammonia
# 5                   glucose
# 6         corn steep liquor
# 7                  corn oil
# 8            host nutrients
# 9            sulfur dioxide
# 10     diammonium phosphate
# 11               flocculant
# 12                 hydrogen
# 13         boiler chemicals
# 14                 fgd lime
# 15  cooling tower chemicals
# 16                    water
# 17              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 18              electricity                                          u.s. mix
# 19              electricity                                          u.s. mix
# 20      sodium sulfate salt
# 21         renewable diesel           fuel distribution and vehicle operation
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   132.678105     kg       0.2  Transportation to biorefinery
# 1     3.184275     kg       0.0                            NaN
# 2    10.614248     kg       0.0                            NaN
# 3     0.135717     kg       0.0                            NaN
# 4     3.359487     kg       0.0                            NaN
# 5     2.871171     kg       0.0                            NaN
# 6     2.010251     kg       0.0                            NaN
# 7     0.015862     kg       0.0                            NaN
# 8     0.079976     kg       0.0                            NaN
# 9     0.019492     kg       0.0                            NaN
# 10    0.224497     kg       0.0                            NaN
# 11    0.953516     kg       0.0                            NaN
# 12    1.893415     kg       0.0                            NaN
# 13    0.000870     kg       0.0                            NaN
# 14    0.291601     kg       0.0                            NaN
# 15    0.002035     kg       0.0                            NaN
# 16  239.567551     kg       0.0                            NaN
# 17   10.189678     kg       0.0                            NaN
# 18   39.191584    kWh       0.0                            NaN
# 19   31.628774    kWh       0.0                            NaN
# 20  -21.987990     kg       0.0                            NaN
# 21    1.000000  mmBTU       0.0                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No          Both  ...
# 2                                              No          Both  ...
# 3                                              No  Main product  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No  Main product  ...
# 7                                              No  Main product  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No          Both  ...
# 14                                             No          Both  ...
# 15                                             No          Both  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No  Main product  ...
# 19                                             No          Both  ...
# 20                                            Yes          Both  ...
# 21                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN                  caustic
# 2            NaN                NaN         sodium carbonate
# 3            NaN                NaN                  ammonia
# 4            NaN                NaN                  ammonia
# 5            NaN                NaN                  glucose
# 6            NaN                NaN        corn steep liquor
# 7            NaN                NaN                 corn oil
# 8            NaN                NaN           host nutrients
# 9            NaN                NaN           sulfur dioxide
# 10           NaN                NaN     diammonium phosphate
# 11           NaN                NaN               flocculant
# 12           NaN                NaN                 hydrogen
# 13           NaN                NaN         boiler chemicals
# 14           NaN                NaN                 fgd lime
# 15           NaN                NaN  cooling tower chemicals
# 16           NaN                NaN                    water
# 17           NaN                NaN              natural gas
# 18           NaN                NaN              electricity
# 19           NaN                NaN              electricity
# 20           NaN                NaN      sodium sulfate salt
# 21     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                use        NaN  NaN
# 3                                                           NaN  NaN
# 4                                                           NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 18                                          u.s. mix        NaN  NaN
# 19                                          u.s. mix        NaN  NaN
# 20                                                          NaN  NaN
# 21                                light duty vehicle        NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production                  Caustic         NaN          NaN
# 2   Fuel production         Sodium carbonate         NaN          NaN
# 3   Fuel production                  Ammonia         NaN          NaN
# 4   Fuel production                  Ammonia         NaN          NaN
# 5   Fuel production                  Glucose         NaN          NaN
# 6   Fuel production        Corn Steep Liquor         NaN          NaN
# 7   Fuel production                 Corn oil         NaN          NaN
# 8   Fuel production           Host nutrients         NaN          NaN
# 9   Fuel production           Sulfur Dioxide         NaN          NaN
# 10  Fuel production     Diammonium Phosphate         NaN          NaN
# 11  Fuel production               Flocculant         NaN          NaN
# 12  Fuel production                 Hydrogen  119.986744     0.090052
# 13  Fuel production         Boiler Chemicals         NaN          NaN
# 14  Fuel production                 FGD Lime         NaN          NaN
# 15  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 16  Fuel production                    Water         NaN  1000.000000
# 17  Fuel production              Natural Gas   47.141814     0.776923
# 18  Fuel production              Electricity         NaN          NaN
# 19  Fuel production              Electricity         NaN          NaN
# 20  Fuel production      Sodium sulfate salt         NaN          NaN
# 21  Fuel production                   Diesel   43.400834   793.378565
#
# [22 rows x 22 columns]

# %%
res_new[['Type', 'Resource', 'Amount', 'Unit', 'GHG', 'GHG_Sum']]
# Out:
#             Type                 Resource        Amount   Unit            GHG  \
# 0          Input                  Caustic   3184.274511      g       2.009157
# 1          Input         Sodium Carbonate  10614.248376      g       1.120540
# 2          Input                  Ammonia    135.717059      g       2.635550
# 3          Input                  Ammonia   3359.487006      g       2.635550
# 4          Input                  Glucose   2871.170785      g       0.771357
# 5          Input        Corn Steep Liquor   2010.250699      g       1.672073
# 6          Input                 Corn Oil     15.861583      g       0.064980
# 7          Input           Host Nutrients     79.976092      g       0.000000
# 8          Input           Sulfur Dioxide     19.492295      g       0.000000
# 9          Input     Diammonium Phosphate    224.496818      g       1.671290
# 10         Input               Flocculant    953.515640      g       1.272029
# 11         Input                 Hydrogen      0.215330  mmBTU   84192.026833
# 12         Input         Boiler Chemicals      0.870251      g       0.000000
# 13         Input                 FGD Lime    291.601234      g       1.282589
# 14         Input  Cooling Tower Chemicals      2.035109      g       0.000000
# 15         Input                    Water     63.287065    gal       0.000000
# 16         Input              Natural Gas      0.455293  mmBTU   72724.381819
# 17         Input              Electricity      0.133727  mmBTU  128879.369583
# 18         Input              Electricity      0.107922  mmBTU  128879.369583
# 19    Co-product      Sodium Sulfate Salt -21987.990261      g       0.185530
# 20  Main Product         Renewable Diesel      1.000000  mmBTU     146.407942
# 21         Input                   Diesel      0.007322  mmBTU   94578.706026
# 22         Input                   Diesel      0.005811  mmBTU   94591.721229
# 23         Input              Electricity      0.000119  mmBTU  128879.369583
# 24         Input                   Diesel      0.001011  mmBTU   94802.669831
# 25         Input              Electricity      0.043152  mmBTU  128879.369583
# 26         Input              Electricity      0.001774  mmBTU  128879.369583
# 27         Input                   Diesel      0.007170  mmBTU   94578.706026
# 28         Input                   Diesel      0.005691  mmBTU   94591.721229
# 29         Input              Electricity      0.004132  mmBTU  128879.369583
# 30         Input              Corn Stover      0.178168    ton    2687.052565
# 31         Input                   Diesel      0.015864  mmBTU   94789.615085
#
#       GHG_Sum
# 0    6.063858
# 1   11.273039
# 2    0.339024
# 3    8.392062
# 4    2.099129
# 5    3.185884
# 6    0.000977
# 7    0.000000
# 8    0.000000
# 9    0.355620
# 10   1.149607
# 11  17.183010
# 12   0.000000
# 13   0.354488
# 14   0.000000
# 15   0.000000
# 16  31.383105
# 17  16.335327
# 18  13.183094
# 19  -3.866546
# 20   0.138768
# 21   0.656347
# 22   0.520982
# 23   0.014482
# 24   0.090801
# 25   5.271189
# 26   0.216749
# 27   0.642778
# 28   0.510211
# 29   0.504707
# 30   0.453765
# 31   1.425283

# %%
res_new[['Type', 'Resource', 'Amount', 'Unit', 'GHG', 'GHG_Sum']]
# Out:
#             Type                 Resource        Amount   Unit            GHG  \
# 0          Input                  Caustic   3184.274511      g       2.009157
# 1          Input         Sodium Carbonate  10614.248376      g       1.120540
# 2          Input                  Ammonia    135.717059      g       2.635550
# 3          Input                  Ammonia   3359.487006      g       2.635550
# 4          Input                  Glucose   2871.170785      g       0.771357
# 5          Input        Corn Steep Liquor   2010.250699      g       1.672073
# 6          Input                 Corn Oil     15.861583      g       0.064980
# 7          Input           Host Nutrients     79.976092      g       0.000000
# 8          Input           Sulfur Dioxide     19.492295      g       0.000000
# 9          Input     Diammonium Phosphate    224.496818      g       1.671290
# 10         Input               Flocculant    953.515640      g       1.272029
# 11         Input                 Hydrogen      0.215330  mmBTU   84192.026833
# 12         Input         Boiler Chemicals      0.870251      g       0.000000
# 13         Input                 FGD Lime    291.601234      g       1.282589
# 14         Input  Cooling Tower Chemicals      2.035109      g       0.000000
# 15         Input                    Water     63.287065    gal       0.000000
# 16         Input              Natural Gas      0.455293  mmBTU   72724.381819
# 17         Input              Electricity      0.133727  mmBTU  128879.369583
# 18         Input              Electricity      0.107922  mmBTU  128879.369583
# 19    Co-product      Sodium Sulfate Salt -21987.990261      g       0.185530
# 20  Main Product         Renewable Diesel      1.000000  mmBTU     146.407942
# 21         Input                   Diesel      0.007322  mmBTU   94578.706026
# 22         Input                   Diesel      0.005811  mmBTU   94591.721229
# 23         Input              Electricity      0.000119  mmBTU  128879.369583
# 24         Input                   Diesel      0.001011  mmBTU   94802.669831
# 25         Input              Electricity      0.043152  mmBTU  128879.369583
# 26         Input              Electricity      0.001774  mmBTU  128879.369583
# 27         Input                   Diesel      0.007170  mmBTU   94578.706026
# 28         Input                   Diesel      0.005691  mmBTU   94591.721229
# 29         Input              Electricity      0.004132  mmBTU  128879.369583
# 30         Input              Corn Stover      0.178168    ton    2687.052565
# 31         Input                   Diesel      0.015864  mmBTU   94789.615085
#
#       GHG_Sum
# 0    6.063858
# 1   11.273039
# 2    0.339024
# 3    8.392062
# 4    2.099129
# 5    3.185884
# 6    0.000977
# 7    0.000000
# 8    0.000000
# 9    0.355620
# 10   1.149607
# 11  17.183010
# 12   0.000000
# 13   0.354488
# 14   0.000000
# 15   0.000000
# 16  31.383105
# 17  16.335327
# 18  13.183094
# 19  -3.866546
# 20   0.138768
# 21   0.656347
# 22   0.520982
# 23   0.014482
# 24   0.090801
# 25   5.271189
# 26   0.216749
# 27   0.642778
# 28   0.510211
# 29   0.504707
# 30   0.453765
# 31   1.425283

# %%
overall_lci
# Out:
#             Type                 Category                 Resource  \
# 0          Input  Chemicals and catalysts                  caustic
# 1          Input  Chemicals and catalysts         sodium carbonate
# 2          Input  Chemicals and catalysts                  ammonia
# 3          Input  Chemicals and catalysts                  ammonia
# 4          Input  Chemicals and catalysts                  glucose
# 5          Input  Chemicals and catalysts        corn steep liquor
# 6          Input  Chemicals and catalysts                 corn oil
# 7          Input  Chemicals and catalysts           host nutrients
# 8          Input  Chemicals and catalysts           sulfur dioxide
# 9          Input  Chemicals and catalysts     diammonium phosphate
# 10         Input  Chemicals and catalysts               flocculant
# 11         Input                     Fuel                 hydrogen
# 12         Input  Chemicals and catalysts         boiler chemicals
# 13         Input  Chemicals and catalysts                 fgd lime
# 14         Input  Chemicals and catalysts  cooling tower chemicals
# 15         Input                    Water                    water
# 16         Input                     Fuel              natural gas
# 17         Input              Electricity              electricity
# 18         Input              Electricity              electricity
# 19    Co-product  Chemicals and catalysts      sodium sulfate salt
# 20  Main Product                     Fuel         renewable diesel
# 21         Input           Transportation                   diesel
# 22         Input           Transportation                   diesel
# 23         Input              Electricity              electricity
# 24         Input                     Fuel                   diesel
# 25         Input              Electricity              electricity
# 26         Input              Electricity              electricity
# 27         Input           Transportation                   diesel
# 28         Input           Transportation                   diesel
# 29         Input              Electricity              electricity
# 30         Input                  Biomass              corn stover
# 31         Input                     Fuel                   diesel
#
#                                              End Use        Amount   Unit  \
# 0                                                         3.184275     kg
# 1                                                use     10.614248     kg
# 2                                                         0.135717     kg
# 3                                                         3.359487     kg
# 4                                                         2.871171     kg
# 5                                                         2.010251     kg
# 6                                                         0.015862     kg
# 7                                                         0.079976     kg
# 8                                                         0.019492     kg
# 9                                                         0.224497     kg
# 10                                                        0.953516     kg
# 11                                                        1.893415     kg
# 12                                                        0.000870     kg
# 13                                                        0.291601     kg
# 14                                                        0.002035     kg
# 15                                                      239.567551     kg
# 16  utility/ industrial boiler (>100 mmbtu/hr input)     10.189678     kg
# 17                                          u.s. mix     39.191584    kWh
# 18                                          u.s. mix     31.628774    kWh
# 19                                                      -21.987990     kg
# 20           fuel distribution and vehicle operation      1.000000  mmBTU
# 21                                            loaded      0.007322  mmBTU
# 22                                             empty      0.005811  mmBTU
# 23                                          u.s. mix    118.552338    BTU
# 24                   stationary reciprocating engine   1010.517548    BTU
# 25                                          u.s. mix  43151.971762    BTU
# 26                                          u.s. mix   1774.386395    BTU
# 27                                            loaded      0.007170  mmBTU
# 28                                             empty      0.005691  mmBTU
# 29                                          u.s. mix   4131.725598    BTU
# 30                                                        0.178168    ton
# 31                                   farming tractor  15864.115878    BTU
#
#     Moisture Previous Process Always Use Displacement Method for Co-Product?  \
# 0        0.0              NaN                                             No
# 1        0.0              NaN                                             No
# 2        0.0              NaN                                             No
# 3        0.0              NaN                                             No
# 4        0.0              NaN                                             No
# 5        0.0              NaN                                             No
# 6        0.0              NaN                                             No
# 7        0.0              NaN                                             No
# 8        0.0              NaN                                             No
# 9        0.0              NaN                                             No
# 10       0.0              NaN                                             No
# 11       0.0              NaN                                             No
# 12       0.0              NaN                                             No
# 13       0.0              NaN                                             No
# 14       0.0              NaN                                             No
# 15       0.0              NaN                                             No
# 16       0.0              NaN                                             No
# 17       0.0              NaN                                             No
# 18       0.0              NaN                                             No
# 19       0.0              NaN                                            Yes
# 20       0.0              NaN                                             No
# 21       NaN              NaN                                            NaN
# 22       NaN              NaN                                            NaN
# 23       0.0              NaN                                             No
# 24       0.0              NaN                                             No
# 25       0.0              NaN                                             No
# 26       0.0              NaN                                             No
# 27       NaN              NaN                                            NaN
# 28       NaN              NaN                                            NaN
# 29       0.0              NaN                                             No
# 30       0.0              NaN                                             No
# 31       0.0              NaN                                             No
#
#    Product Train  ...  Market Price Market Price Unit  \
# 0           Both  ...           NaN               NaN
# 1           Both  ...           NaN               NaN
# 2   Main product  ...           NaN               NaN
# 3           Both  ...           NaN               NaN
# 4   Main product  ...           NaN               NaN
# 5   Main product  ...           NaN               NaN
# 6   Main product  ...           NaN               NaN
# 7   Main product  ...           NaN               NaN
# 8   Main product  ...           NaN               NaN
# 9   Main product  ...           NaN               NaN
# 10  Main product  ...           NaN               NaN
# 11  Main product  ...           NaN               NaN
# 12          Both  ...           NaN               NaN
# 13          Both  ...           NaN               NaN
# 14          Both  ...           NaN               NaN
# 15          Both  ...           NaN               NaN
# 16          Both  ...           NaN               NaN
# 17  Main product  ...           NaN               NaN
# 18          Both  ...           NaN               NaN
# 19          Both  ...           NaN               NaN
# 20  Main product  ...     21.535016           $/mmBTU
# 21           NaN  ...           NaN               NaN
# 22           NaN  ...           NaN               NaN
# 23           NaN  ...           NaN               NaN
# 24           NaN  ...           NaN               NaN
# 25           NaN  ...           NaN               NaN
# 26           NaN  ...           NaN               NaN
# 27           NaN  ...           NaN               NaN
# 28           NaN  ...           NaN               NaN
# 29           NaN  ...           NaN               NaN
# 30           NaN  ...           NaN               NaN
# 31           NaN  ...           NaN               NaN
#
#           Incumbent Product                      End Use of Incumbent Product  \
# 0                   caustic
# 1          sodium carbonate                                               use
# 2                   ammonia
# 3                   ammonia
# 4                   glucose
# 5         corn steep liquor
# 6                  corn oil
# 7            host nutrients
# 8            sulfur dioxide
# 9      diammonium phosphate
# 10               flocculant
# 11                 hydrogen
# 12         boiler chemicals
# 13                 fgd lime
# 14  cooling tower chemicals
# 15                    water
# 16              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 17              electricity                                          u.s. mix
# 18              electricity                                          u.s. mix
# 19      sodium sulfate salt
# 20                   diesel                                light duty vehicle
# 21                      NaN                                               NaN
# 22                      NaN                                               NaN
# 23              electricity                                          u.s. mix
# 24                   diesel                                 industrial boiler
# 25              electricity                                          u.s. mix
# 26              electricity                                          u.s. mix
# 27                      NaN                                               NaN
# 28                      NaN                                               NaN
# 29              electricity                                          u.s. mix
# 30              corn stover
# 31                   diesel                                 industrial boiler
#
#    Subprocess Note                        Process       Incumbent Resource  \
# 0         NaN  NaN                Fuel production                  Caustic
# 1         NaN  NaN                Fuel production         Sodium carbonate
# 2         NaN  NaN                Fuel production                  Ammonia
# 3         NaN  NaN                Fuel production                  Ammonia
# 4         NaN  NaN                Fuel production                  Glucose
# 5         NaN  NaN                Fuel production        Corn Steep Liquor
# 6         NaN  NaN                Fuel production                 Corn oil
# 7         NaN  NaN                Fuel production           Host nutrients
# 8         NaN  NaN                Fuel production           Sulfur Dioxide
# 9         NaN  NaN                Fuel production     Diammonium Phosphate
# 10        NaN  NaN                Fuel production               Flocculant
# 11        NaN  NaN                Fuel production                 Hydrogen
# 12        NaN  NaN                Fuel production         Boiler Chemicals
# 13        NaN  NaN                Fuel production                 FGD Lime
# 14        NaN  NaN                Fuel production  Cooling Tower Chemicals
# 15        NaN  NaN                Fuel production                    Water
# 16        NaN  NaN                Fuel production              Natural Gas
# 17        NaN  NaN                Fuel production              Electricity
# 18        NaN  NaN                Fuel production              Electricity
# 19        NaN  NaN                Fuel production      Sodium sulfate salt
# 20        NaN  NaN                Fuel production                   Diesel
# 21        NaN  NaN  Transportation to biorefinery                      NaN
# 22        NaN  NaN  Transportation to biorefinery                      NaN
# 23        NaN  NaN          Handling and blending              Electricity
# 24        NaN  NaN          Handling and blending                   Diesel
# 25        NaN  NaN                  Preprocessing              Electricity
# 26        NaN  NaN                  Depot storage              Electricity
# 27        NaN  NaN        Transportation to depot                      NaN
# 28        NaN  NaN        Transportation to depot                      NaN
# 29        NaN  NaN                  Field storage              Electricity
# 30        NaN  NaN         Harvest and collection              Corn Stover
# 31        NaN  NaN         Harvest and collection                   Diesel
#
#            LHV      Density
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN
# 10         NaN          NaN
# 11  119.986744     0.090052
# 12         NaN          NaN
# 13         NaN          NaN
# 14         NaN          NaN
# 15         NaN  1000.000000
# 16   47.141814     0.776923
# 17         NaN          NaN
# 18         NaN          NaN
# 19         NaN          NaN
# 20   43.400834   793.378565
# 21   42.626181   846.935775
# 22   42.626181   846.935775
# 23         NaN          NaN
# 24   42.626181   846.935775
# 25         NaN          NaN
# 26         NaN          NaN
# 27   42.626181   846.935775
# 28   42.626181   846.935775
# 29         NaN          NaN
# 30   17.114708          NaN
# 31   42.626181   846.935775
#
# [32 rows x 22 columns]

# %%
res_new.head()
# Out:
#     Type                 Category          Resource End Use  Input Amount  \
# 0  Input  Chemicals and catalysts           Caustic              3.184275
# 1  Input  Chemicals and catalysts  Sodium Carbonate     use     10.614248
# 2  Input  Chemicals and catalysts           Ammonia              0.135717
# 3  Input  Chemicals and catalysts           Ammonia              3.359487
# 4  Input  Chemicals and catalysts           Glucose              2.871171
#
#   Unit  Moisture Previous Process  \
# 0    g       0.0              NaN
# 1    g       0.0              NaN
# 2    g       0.0              NaN
# 3    g       0.0              NaN
# 4    g       0.0              NaN
#
#   Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                             No          Both  ...
# 1                                             No          Both  ...
# 2                                             No  Main product  ...
# 3                                             No          Both  ...
# 4                                             No  Main product  ...
#
#    PM2.5_Sum   SOx_Sum    BC_Sum    OC_Sum   CH4_Sum   N2O_Sum    CO2_Sum  \
# 0   0.000359  0.002879  0.000037  0.000112  0.014543  0.000133   5.584595
# 1   0.001073  0.001817  0.000048  0.000086  0.007709  0.000011  11.027414
# 2   0.000011  0.000095  0.000002  0.000005  0.000943  0.000006   0.305916
# 3   0.000277  0.002357  0.000046  0.000112  0.023345  0.000157   7.572537
# 4   0.000188  0.001027  0.000034  0.000041  0.003729  0.002193   1.400848
#
#    Biogenic CO2_Sum CO2 (w/ C in VOC & CO)_Sum    GHG_Sum
# 0               0.0                   5.592410   6.063858
# 1               0.0                  11.038863  11.273039
# 2               0.0                   0.309050   0.339024
# 3               0.0                   7.650095   8.392062
# 4               0.0                   1.406040   2.099129
#
# [5 rows x 65 columns]

# %%
main_product_total
# Out:
# 117.87773834692493

# %%
format_input(lci_mapping[final_process]).tail(5)
# Out:
#             Type                 Category             Resource  \
# 22         Input              Electricity          electricity
# 23         Input              Electricity          electricity
# 24  Main Product                     Fuel     renewable diesel
# 25    Co-product  Chemicals and catalysts      betaketoadipate
# 26    Co-product  Chemicals and catalysts  sodium sulfate salt
#
#                                     End Use     Amount   Unit  Moisture  \
# 22                                 u.s. mix   7.230543    kWh       0.0
# 23                                 u.s. mix  43.487477    kWh       0.0
# 24  fuel distribution and vehicle operation   1.000045  mmBTU       0.0
# 25                            sequestration   4.308164     kg       0.0
# 26                                           30.232035     kg       0.0
#
#    Previous Process Always Use Displacement Method for Co-Product?  \
# 22              NaN                                             No
# 23              NaN                                             No
# 24              NaN                                             No
# 25              NaN                                             No
# 26              NaN                                            Yes
#
#    Product Train  ...  Market Price  Market Price Unit    Incumbent Product  \
# 22    Co-product  ...           NaN                NaN          electricity
# 23          Both  ...           NaN                NaN          electricity
# 24  Main product  ...     21.535016            $/mmBTU               diesel
# 25    Co-product  ...      1.873939               $/kg          adipic acid
# 26          Both  ...           NaN                NaN  sodium sulfate salt
#
#    End Use of Incumbent Product Subprocess Note          Process  \
# 22                     u.s. mix        NaN  NaN  Fuel production
# 23                     u.s. mix        NaN  NaN  Fuel production
# 24           light duty vehicle        NaN  NaN  Fuel production
# 25                                     NaN  NaN  Fuel production
# 26                                     NaN  NaN  Fuel production
#
#      Incumbent Resource        LHV     Density
# 22          Electricity        NaN         NaN
# 23          Electricity        NaN         NaN
# 24               Diesel  43.400834  793.378565
# 25          Adipic Acid        NaN         NaN
# 26  Sodium sulfate salt        NaN         NaN
#
# [5 rows x 22 columns]

# %%
format_input(lci_mapping[final_process], False).tail(5)
# Out:
#             Type                 Category             Resource  \
# 22         Input              Electricity          electricity
# 23         Input              Electricity          electricity
# 24  Main Product                     Fuel     renewable diesel
# 25    Co-product  Chemicals and catalysts      betaketoadipate
# 26    Co-product  Chemicals and catalysts  sodium sulfate salt
#
#                                     End Use     Amount   Unit  Moisture  \
# 22                                 u.s. mix   7.230217    kWh       0.0
# 23                                 u.s. mix  43.485514    kWh       0.0
# 24  fuel distribution and vehicle operation   1.000000  mmBTU       0.0
# 25                            sequestration   4.307970     kg       0.0
# 26                                           30.230671     kg       0.0
#
#    Previous Process Always Use Displacement Method for Co-Product?  \
# 22              NaN                                             No
# 23              NaN                                             No
# 24              NaN                                             No
# 25              NaN                                             No
# 26              NaN                                            Yes
#
#    Product Train  ...  Market Price  Market Price Unit    Incumbent Product  \
# 22    Co-product  ...           NaN                NaN          electricity
# 23          Both  ...           NaN                NaN          electricity
# 24  Main product  ...     21.535016            $/mmBTU               diesel
# 25    Co-product  ...      1.873939               $/kg          adipic acid
# 26          Both  ...           NaN                NaN  sodium sulfate salt
#
#    End Use of Incumbent Product Subprocess Note          Process  \
# 22                     u.s. mix        NaN  NaN  Fuel production
# 23                     u.s. mix        NaN  NaN  Fuel production
# 24           light duty vehicle        NaN  NaN  Fuel production
# 25                                     NaN  NaN  Fuel production
# 26                                     NaN  NaN  Fuel production
#
#      Incumbent Resource        LHV     Density
# 22          Electricity        NaN         NaN
# 23          Electricity        NaN         NaN
# 24               Diesel  43.400834  793.378565
# 25          Adipic Acid        NaN         NaN
# 26  Sodium sulfate salt        NaN         NaN
#
# [5 rows x 22 columns]

# %%
dff = lci_mapping['Fuel production']
df = dff.copy()  # Avoid chaning the original df
rd_dist_loss = 1.00004514306778  # Loss factor of renewable diesel distribution
apply_loss_factor = True

# Step 1
df["End Use"] = df["End Use"].fillna("")
df["Incumbent Resource"] = df["Incumbent Product"].fillna("")
df["End Use of Incumbent Product"] = df["End Use of Incumbent Product"].fillna("")
df["Always Use Displacement Method for Co-Product?"] = df[
    "Always Use Displacement Method for Co-Product?"
].fillna("No")

lower_case_cols = [
    "Resource",
    "End Use",
    "Incumbent Product",
    "End Use of Incumbent Product",
    # "Unit",
]

for col in lower_case_cols:
    df[col] = df[col].str.strip().str.lower()

# Step 2
df["Moisture"] = df["Moisture"].fillna(0)
df.loc[df["Category"] != "Transportation", "Amount"] = df.loc[
    df["Category"] != "Transportation", "Amount"
] * (1 - df["Moisture"])
df.loc[df["Category"] == "Transportation", "Amount"] = df.loc[
    df["Category"] == "Transportation", "Amount"
] / (1 - df["Moisture"])

# df.loc[df['Category']!='Transportation', 'Amount'] = df.loc[df['Category']!='Transportation', 'Amount'] / df.loc[df['Type']=='Main Product', 'Amount'].sum()

# Step 3
df = convert_transport_lci(df)

# Step 4
df = pd.merge(df, properties, left_on="Resource", right_index=True, how="left")

# Step 5
main_products = df[df["Type"] == "Main Product"].copy()
main_product_category = main_products["Category"].values[0]
main_product_resource = main_products["Resource"].values[0]
main_product_end_use = main_products["End Use"].values[0]
if len(main_products) > 1:
    main_products["Primary Unit"] = combination_basis[main_product_category]
    main_products = main_products.rename(columns={"Amount": "Input Amount"})
    main_products["Amount"] = main_products.apply(unit_conversion, axis=1)
    main_products["Amount"] = main_products["Amount"].sum()
    main_products["Unit"] = main_products["Primary Unit"]
    main_products = main_products.drop(["Input Amount", "Primary Unit"], axis=1)
    df = pd.concat(
        [df[df["Type"] != "Main Product"], main_products.iloc[:1]],
        ignore_index=True,
    )

# Step 6
main_product_amount = df.loc[
    df["Type"] == "Main Product", "Amount"
].sum()  # TODO: need to make sure the units are consistent
# print(df.tail(5))
print(main_product_amount)

if (
    (main_product_resource == "renewable diesel")
    and ("distribution" in main_product_end_use)
    and (apply_loss_factor)
):
    print('test')
    main_product_amount = main_product_amount / rd_dist_loss
    
print(main_product_amount)

df["Amount"] = df["Amount"] / main_product_amount
# Out:
# 456.832769083114
# test
# 456.8121471813911

# %%
"distribution" in main_product_end_use
# Out:
# True

# %%
final_process_lci = format_input(lci_mapping[final_process])
biomass_df = final_process_lci.loc[
        final_process_lci["Category"] == "Biomass",
    ].copy()
biomass_df = biomass_df.rename(columns={"Amount": "Input Amount"})
biomass_df["Primary Unit"] = "ton"
biomass_df["Amount"] = biomass_df.apply(unit_conversion, axis=1)
total_biomass = biomass_df["Amount"].sum()
ratio = 0.7273404712366012
main_biomass = total_biomass * ratio
coproduct_biomass = total_biomass * (1 - ratio)
    
coproduct_lci = generate_coproduct_lci(
                lci_mapping, coproduct_mapping, final_process_mapping
            )

coproduct_with_incumbent = calc(coproduct_lci)
coproduct_res = coproduct_with_incumbent[
            ~coproduct_with_incumbent["Pathway"].str.contains("Incumbent")
        ]

coproduct_total = coproduct_res[tab + "_Sum"].sum()
coproduct_incumbent_total = res_new_with_incumbent.loc[
            res_new_with_incumbent["Pathway"].str.contains("Incumbent"),
            tab + "_Sum",
        ].sum()

coproduct_conversion = 1

coproduct_contribution = (
            coproduct_total
            * coproduct_conversion
            / coproduct_biomass
            * (1 - ratio)
            / biorefinery_conversion[tab]
        )
# final_process_lci = format_input(lci_mapping[final_process])
# biomass_df = final_process_lci.loc[
#         final_process_lci["Category"] == "Biomass",
#     ].copy()
# biomass_df = biomass_df.rename(columns={"Amount": "Input Amount"})
# biomass_df["Primary Unit"] = "ton"
# biomass_df["Amount"] = biomass_df.apply(unit_conversion, axis=1)
# total_biomass = biomass_df["Amount"].sum()

# %%
if len(coproduct_res) > 0:
    coproduct_category = coproduct_res.loc[
        coproduct_res["Type"] == "Main Product", "Category"
    ].values[0]
    coproduct_target_unit = display_units[coproduct_category]
    coproduct_df = final_process_lci.loc[
        (final_process_lci["Type"] == "Co-product")
        & (
            final_process_lci["Always Use Displacement Method for Co-Product?"]
            == "No"
        ),
    ].copy()
    coproduct_df = coproduct_df.rename(columns={"Amount": "Input Amount"})
    coproduct_df["Primary Unit"] = coproduct_target_unit
    coproduct_df["Amount"] = coproduct_df.apply(unit_conversion, axis=1)
    total_coproduct = coproduct_df["Amount"].sum()

# %%
coproduct_df[['Amount', "Primary Unit", "Unit"]]
# Out:
#          Amount Primary Unit Unit
# 25  4307.969991            g   kg

# %%
main_product_total = res_new[tab + "_Sum"].sum()
main_product_total * 1 / total_biomass
# Out:
# 585.7729624968114

# %%
main_product_total*1055/total_biomass/1000
# Out:
# 617.990475434136

# %%
main_incumbent_contribution = (
    main_incumbent_total
    * 1
    * main_conversion
    / total_biomass
    / biorefinery_conversion["GHG"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 2>()
#       1 main_incumbent_contribution = (
# ----> 2     main_incumbent_total
#       3     * 1
#       4     * main_conversion
#       5     / total_biomass
#       6     / biorefinery_conversion["GHG"])
#
# NameError: name 'main_incumbent_total' is not defined

# %%
total_biomass
# Out:
# 0.20107856183058295

# %%
final_process_lci[["Category", "Always Use Displacement Method for Co-Product?", "Amount", "Unit"]]
# Out:
#                    Category Always Use Displacement Method for Co-Product?  \
# 0                   Biomass                                             No
# 1   Chemicals and catalysts                                             No
# 2   Chemicals and catalysts                                             No
# 3   Chemicals and catalysts                                             No
# 4   Chemicals and catalysts                                             No
# 5   Chemicals and catalysts                                             No
# 6   Chemicals and catalysts                                             No
# 7   Chemicals and catalysts                                             No
# 8   Chemicals and catalysts                                             No
# 9   Chemicals and catalysts                                             No
# 10  Chemicals and catalysts                                             No
# 11  Chemicals and catalysts                                             No
# 12  Chemicals and catalysts                                             No
# 13  Chemicals and catalysts                                             No
# 14  Chemicals and catalysts                                             No
# 15                     Fuel                                             No
# 16  Chemicals and catalysts                                             No
# 17  Chemicals and catalysts                                             No
# 18  Chemicals and catalysts                                             No
# 19                    Water                                             No
# 20                     Fuel                                             No
# 21              Electricity                                             No
# 22              Electricity                                             No
# 23              Electricity                                             No
# 24                     Fuel                                             No
# 25  Chemicals and catalysts                                             No
# 26  Chemicals and catalysts                                            Yes
#
#         Amount   Unit
# 0   182.415403     kg
# 1    21.419076     kg
# 2     3.462974     kg
# 3     4.377970     kg
# 4    14.593232     kg
# 5     0.135717     kg
# 6     0.037213     kg
# 7     4.618864     kg
# 8     2.871171     kg
# 9     2.010251     kg
# 10    0.015862     kg
# 11    0.079976     kg
# 12    0.019492     kg
# 13    0.224497     kg
# 14    0.953516     kg
# 15    1.893415     kg
# 16    0.001196     kg
# 17    0.400914     kg
# 18    0.002798     kg
# 19  329.374702     kg
# 20   14.009503     kg
# 21   39.191584    kWh
# 22    7.230217    kWh
# 23   43.485514    kWh
# 24    1.000000  mmBTU
# 25    4.307970     kg
# 26   30.230671     kg

# %%
final_process_lci
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input  Chemicals and catalysts
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input                     Fuel
# 16                       Input  Chemicals and catalysts
# 17                       Input  Chemicals and catalysts
# 18                       Input  Chemicals and catalysts
# 19                       Input                    Water
# 20                       Input                     Fuel
# 21                       Input              Electricity
# 22                       Input              Electricity
# 23                       Input              Electricity
# 24                Main Product                     Fuel
# 25                  Co-product  Chemicals and catalysts
# 26                  Co-product  Chemicals and catalysts
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1             sulfuric acid
# 2                   caustic
# 3                   caustic
# 4          sodium carbonate                                               use
# 5                   ammonia
# 6                   ammonia
# 7                   ammonia
# 8                   glucose
# 9         corn steep liquor
# 10                 corn oil
# 11           host nutrients
# 12           sulfur dioxide
# 13     diammonium phosphate
# 14               flocculant
# 15                 hydrogen
# 16         boiler chemicals
# 17                 fgd lime
# 18  cooling tower chemicals
# 19                    water
# 20              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 21              electricity                                          u.s. mix
# 22              electricity                                          u.s. mix
# 23              electricity                                          u.s. mix
# 24         renewable diesel                                light duty vehicle
# 25          betaketoadipate                                     sequestration
# 26      sodium sulfate salt
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   182.415403     kg      0.20  Transportation to biorefinery
# 1    21.419076     kg      0.07                            NaN
# 2     3.462974     kg      0.00                            NaN
# 3     4.377970     kg      0.00                            NaN
# 4    14.593232     kg      0.00                            NaN
# 5     0.135717     kg      0.00                            NaN
# 6     0.037213     kg      0.00                            NaN
# 7     4.618864     kg      0.00                            NaN
# 8     2.871171     kg      0.00                            NaN
# 9     2.010251     kg      0.00                            NaN
# 10    0.015862     kg      0.00                            NaN
# 11    0.079976     kg      0.00                            NaN
# 12    0.019492     kg      0.00                            NaN
# 13    0.224497     kg      0.00                            NaN
# 14    0.953516     kg      0.00                            NaN
# 15    1.893415     kg      0.00                            NaN
# 16    0.001196     kg      0.00                            NaN
# 17    0.400914     kg      0.00                            NaN
# 18    0.002798     kg      0.00                            NaN
# 19  329.374702     kg      0.00                            NaN
# 20   14.009503     kg      0.00                            NaN
# 21   39.191584    kWh      0.00                            NaN
# 22    7.230217    kWh      0.00                            NaN
# 23   43.485514    kWh      0.00                            NaN
# 24    1.000000  mmBTU      0.00                            NaN
# 25    4.307970     kg      0.00                            NaN
# 26   30.230671     kg      0.00                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No    Co-product  ...
# 2                                              No    Co-product  ...
# 3                                              No          Both  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No    Co-product  ...
# 7                                              No          Both  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No  Main product  ...
# 14                                             No  Main product  ...
# 15                                             No  Main product  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No          Both  ...
# 19                                             No          Both  ...
# 20                                             No          Both  ...
# 21                                             No  Main product  ...
# 22                                             No    Co-product  ...
# 23                                             No          Both  ...
# 24                                             No  Main product  ...
# 25                                             No    Co-product  ...
# 26                                            Yes          Both  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN            sulfuric acid
# 2            NaN                NaN                  caustic
# 3            NaN                NaN                  caustic
# 4            NaN                NaN         sodium carbonate
# 5            NaN                NaN                  ammonia
# 6            NaN                NaN                  ammonia
# 7            NaN                NaN                  ammonia
# 8            NaN                NaN                  glucose
# 9            NaN                NaN        corn steep liquor
# 10           NaN                NaN                 corn oil
# 11           NaN                NaN           host nutrients
# 12           NaN                NaN           sulfur dioxide
# 13           NaN                NaN     diammonium phosphate
# 14           NaN                NaN               flocculant
# 15           NaN                NaN                 hydrogen
# 16           NaN                NaN         boiler chemicals
# 17           NaN                NaN                 fgd lime
# 18           NaN                NaN  cooling tower chemicals
# 19           NaN                NaN                    water
# 20           NaN                NaN              natural gas
# 21           NaN                NaN              electricity
# 22           NaN                NaN              electricity
# 23           NaN                NaN              electricity
# 24     21.535016            $/mmBTU                   diesel
# 25      1.873939               $/kg              adipic acid
# 26           NaN                NaN      sodium sulfate salt
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                           NaN  NaN
# 3                                                           NaN  NaN
# 4                                                use        NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17                                                          NaN  NaN
# 18                                                          NaN  NaN
# 19                                                          NaN  NaN
# 20  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 21                                          u.s. mix        NaN  NaN
# 22                                          u.s. mix        NaN  NaN
# 23                                          u.s. mix        NaN  NaN
# 24                                light duty vehicle        NaN  NaN
# 25                                                          NaN  NaN
# 26                                                          NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production            Sulfuric Acid         NaN          NaN
# 2   Fuel production                  Caustic         NaN          NaN
# 3   Fuel production                  Caustic         NaN          NaN
# 4   Fuel production         Sodium carbonate         NaN          NaN
# 5   Fuel production                  Ammonia         NaN          NaN
# 6   Fuel production                  Ammonia         NaN          NaN
# 7   Fuel production                  Ammonia         NaN          NaN
# 8   Fuel production                  Glucose         NaN          NaN
# 9   Fuel production        Corn Steep Liquor         NaN          NaN
# 10  Fuel production                 Corn oil         NaN          NaN
# 11  Fuel production           Host nutrients         NaN          NaN
# 12  Fuel production           Sulfur Dioxide         NaN          NaN
# 13  Fuel production     Diammonium Phosphate         NaN          NaN
# 14  Fuel production               Flocculant         NaN          NaN
# 15  Fuel production                 Hydrogen  119.986744     0.090052
# 16  Fuel production         Boiler Chemicals         NaN          NaN
# 17  Fuel production                 FGD Lime         NaN          NaN
# 18  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 19  Fuel production                    Water         NaN  1000.000000
# 20  Fuel production              Natural Gas   47.141814     0.776923
# 21  Fuel production              Electricity         NaN          NaN
# 22  Fuel production              Electricity         NaN          NaN
# 23  Fuel production              Electricity         NaN          NaN
# 24  Fuel production                   Diesel   43.400834   793.378565
# 25  Fuel production              Adipic Acid         NaN          NaN
# 26  Fuel production      Sodium sulfate salt         NaN          NaN
#
# [27 rows x 22 columns]

# %%
main_final_process_lci = lci_mapping[final_process]
main_biomass = main_final_process_lci.loc[
    (main_final_process_lci["Type"] == "Input")
    & (main_final_process_lci["Category"] == "Biomass"),
    "Amount",
].sum()

# %%
format_input(main_final_process_lci)
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input  Chemicals and catalysts
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input                     Fuel
# 16                       Input  Chemicals and catalysts
# 17                       Input  Chemicals and catalysts
# 18                       Input  Chemicals and catalysts
# 19                       Input                    Water
# 20                       Input                     Fuel
# 21                       Input              Electricity
# 22                       Input              Electricity
# 23                       Input              Electricity
# 24                Main Product                     Fuel
# 25                  Co-product  Chemicals and catalysts
# 26                  Co-product  Chemicals and catalysts
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1             sulfuric acid
# 2                   caustic
# 3                   caustic
# 4          sodium carbonate                                               use
# 5                   ammonia
# 6                   ammonia
# 7                   ammonia
# 8                   glucose
# 9         corn steep liquor
# 10                 corn oil
# 11           host nutrients
# 12           sulfur dioxide
# 13     diammonium phosphate
# 14               flocculant
# 15                 hydrogen
# 16         boiler chemicals
# 17                 fgd lime
# 18  cooling tower chemicals
# 19                    water
# 20              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 21              electricity                                          u.s. mix
# 22              electricity                                          u.s. mix
# 23              electricity                                          u.s. mix
# 24         renewable diesel                                light duty vehicle
# 25          betaketoadipate                                     sequestration
# 26      sodium sulfate salt
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   182.415403     kg      0.20  Transportation to biorefinery
# 1    21.419076     kg      0.07                            NaN
# 2     3.462974     kg      0.00                            NaN
# 3     4.377970     kg      0.00                            NaN
# 4    14.593232     kg      0.00                            NaN
# 5     0.135717     kg      0.00                            NaN
# 6     0.037213     kg      0.00                            NaN
# 7     4.618864     kg      0.00                            NaN
# 8     2.871171     kg      0.00                            NaN
# 9     2.010251     kg      0.00                            NaN
# 10    0.015862     kg      0.00                            NaN
# 11    0.079976     kg      0.00                            NaN
# 12    0.019492     kg      0.00                            NaN
# 13    0.224497     kg      0.00                            NaN
# 14    0.953516     kg      0.00                            NaN
# 15    1.893415     kg      0.00                            NaN
# 16    0.001196     kg      0.00                            NaN
# 17    0.400914     kg      0.00                            NaN
# 18    0.002798     kg      0.00                            NaN
# 19  329.374702     kg      0.00                            NaN
# 20   14.009503     kg      0.00                            NaN
# 21   39.191584    kWh      0.00                            NaN
# 22    7.230217    kWh      0.00                            NaN
# 23   43.485514    kWh      0.00                            NaN
# 24    1.000000  mmBTU      0.00                            NaN
# 25    4.307970     kg      0.00                            NaN
# 26   30.230671     kg      0.00                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No    Co-product  ...
# 2                                              No    Co-product  ...
# 3                                              No          Both  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No    Co-product  ...
# 7                                              No          Both  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No  Main product  ...
# 14                                             No  Main product  ...
# 15                                             No  Main product  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No          Both  ...
# 19                                             No          Both  ...
# 20                                             No          Both  ...
# 21                                             No  Main product  ...
# 22                                             No    Co-product  ...
# 23                                             No          Both  ...
# 24                                             No  Main product  ...
# 25                                             No    Co-product  ...
# 26                                            Yes          Both  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN            sulfuric acid
# 2            NaN                NaN                  caustic
# 3            NaN                NaN                  caustic
# 4            NaN                NaN         sodium carbonate
# 5            NaN                NaN                  ammonia
# 6            NaN                NaN                  ammonia
# 7            NaN                NaN                  ammonia
# 8            NaN                NaN                  glucose
# 9            NaN                NaN        corn steep liquor
# 10           NaN                NaN                 corn oil
# 11           NaN                NaN           host nutrients
# 12           NaN                NaN           sulfur dioxide
# 13           NaN                NaN     diammonium phosphate
# 14           NaN                NaN               flocculant
# 15           NaN                NaN                 hydrogen
# 16           NaN                NaN         boiler chemicals
# 17           NaN                NaN                 fgd lime
# 18           NaN                NaN  cooling tower chemicals
# 19           NaN                NaN                    water
# 20           NaN                NaN              natural gas
# 21           NaN                NaN              electricity
# 22           NaN                NaN              electricity
# 23           NaN                NaN              electricity
# 24     21.535016            $/mmBTU                   diesel
# 25      1.873939               $/kg              adipic acid
# 26           NaN                NaN      sodium sulfate salt
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                           NaN  NaN
# 3                                                           NaN  NaN
# 4                                                use        NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17                                                          NaN  NaN
# 18                                                          NaN  NaN
# 19                                                          NaN  NaN
# 20  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 21                                          u.s. mix        NaN  NaN
# 22                                          u.s. mix        NaN  NaN
# 23                                          u.s. mix        NaN  NaN
# 24                                light duty vehicle        NaN  NaN
# 25                                                          NaN  NaN
# 26                                                          NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production            Sulfuric Acid         NaN          NaN
# 2   Fuel production                  Caustic         NaN          NaN
# 3   Fuel production                  Caustic         NaN          NaN
# 4   Fuel production         Sodium carbonate         NaN          NaN
# 5   Fuel production                  Ammonia         NaN          NaN
# 6   Fuel production                  Ammonia         NaN          NaN
# 7   Fuel production                  Ammonia         NaN          NaN
# 8   Fuel production                  Glucose         NaN          NaN
# 9   Fuel production        Corn Steep Liquor         NaN          NaN
# 10  Fuel production                 Corn oil         NaN          NaN
# 11  Fuel production           Host nutrients         NaN          NaN
# 12  Fuel production           Sulfur Dioxide         NaN          NaN
# 13  Fuel production     Diammonium Phosphate         NaN          NaN
# 14  Fuel production               Flocculant         NaN          NaN
# 15  Fuel production                 Hydrogen  119.986744     0.090052
# 16  Fuel production         Boiler Chemicals         NaN          NaN
# 17  Fuel production                 FGD Lime         NaN          NaN
# 18  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 19  Fuel production                    Water         NaN  1000.000000
# 20  Fuel production              Natural Gas   47.141814     0.776923
# 21  Fuel production              Electricity         NaN          NaN
# 22  Fuel production              Electricity         NaN          NaN
# 23  Fuel production              Electricity         NaN          NaN
# 24  Fuel production                   Diesel   43.400834   793.378565
# 25  Fuel production              Adipic Acid         NaN          NaN
# 26  Fuel production      Sodium sulfate salt         NaN          NaN
#
# [27 rows x 22 columns]

# %%
total_biomass = 0  # Initialization
biomass_df = final_process_lci.loc[
    final_process_lci["Category"] == "Biomass",
].copy()
biomass_df = biomass_df.rename(columns={"Amount": "Input Amount"})
biomass_df["Primary Unit"] = "ton"
biomass_df["Amount"] = biomass_df.apply(unit_conversion, axis=1)
total_biomass = biomass_df["Amount"].sum()

# %%
final_process_lci
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input  Chemicals and catalysts
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input                     Fuel
# 16                       Input  Chemicals and catalysts
# 17                       Input  Chemicals and catalysts
# 18                       Input  Chemicals and catalysts
# 19                       Input                    Water
# 20                       Input                     Fuel
# 21                       Input              Electricity
# 22                       Input              Electricity
# 23                       Input              Electricity
# 24                Main Product                     Fuel
# 25                  Co-product  Chemicals and catalysts
# 26                  Co-product  Chemicals and catalysts
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1             sulfuric acid
# 2                   caustic
# 3                   caustic
# 4          sodium carbonate                                               use
# 5                   ammonia
# 6                   ammonia
# 7                   ammonia
# 8                   glucose
# 9         corn steep liquor
# 10                 corn oil
# 11           host nutrients
# 12           sulfur dioxide
# 13     diammonium phosphate
# 14               flocculant
# 15                 hydrogen
# 16         boiler chemicals
# 17                 fgd lime
# 18  cooling tower chemicals
# 19                    water
# 20              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 21              electricity                                          u.s. mix
# 22              electricity                                          u.s. mix
# 23              electricity                                          u.s. mix
# 24         renewable diesel                                light duty vehicle
# 25          betaketoadipate                                     sequestration
# 26      sodium sulfate salt
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   182.415403     kg      0.20  Transportation to biorefinery
# 1    21.419076     kg      0.07                            NaN
# 2     3.462974     kg      0.00                            NaN
# 3     4.377970     kg      0.00                            NaN
# 4    14.593232     kg      0.00                            NaN
# 5     0.135717     kg      0.00                            NaN
# 6     0.037213     kg      0.00                            NaN
# 7     4.618864     kg      0.00                            NaN
# 8     2.871171     kg      0.00                            NaN
# 9     2.010251     kg      0.00                            NaN
# 10    0.015862     kg      0.00                            NaN
# 11    0.079976     kg      0.00                            NaN
# 12    0.019492     kg      0.00                            NaN
# 13    0.224497     kg      0.00                            NaN
# 14    0.953516     kg      0.00                            NaN
# 15    1.893415     kg      0.00                            NaN
# 16    0.001196     kg      0.00                            NaN
# 17    0.400914     kg      0.00                            NaN
# 18    0.002798     kg      0.00                            NaN
# 19  329.374702     kg      0.00                            NaN
# 20   14.009503     kg      0.00                            NaN
# 21   39.191584    kWh      0.00                            NaN
# 22    7.230217    kWh      0.00                            NaN
# 23   43.485514    kWh      0.00                            NaN
# 24    1.000000  mmBTU      0.00                            NaN
# 25    4.307970     kg      0.00                            NaN
# 26   30.230671     kg      0.00                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No    Co-product  ...
# 2                                              No    Co-product  ...
# 3                                              No          Both  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No    Co-product  ...
# 7                                              No          Both  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No  Main product  ...
# 14                                             No  Main product  ...
# 15                                             No  Main product  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No          Both  ...
# 19                                             No          Both  ...
# 20                                             No          Both  ...
# 21                                             No  Main product  ...
# 22                                             No    Co-product  ...
# 23                                             No          Both  ...
# 24                                             No  Main product  ...
# 25                                             No    Co-product  ...
# 26                                            Yes          Both  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN            sulfuric acid
# 2            NaN                NaN                  caustic
# 3            NaN                NaN                  caustic
# 4            NaN                NaN         sodium carbonate
# 5            NaN                NaN                  ammonia
# 6            NaN                NaN                  ammonia
# 7            NaN                NaN                  ammonia
# 8            NaN                NaN                  glucose
# 9            NaN                NaN        corn steep liquor
# 10           NaN                NaN                 corn oil
# 11           NaN                NaN           host nutrients
# 12           NaN                NaN           sulfur dioxide
# 13           NaN                NaN     diammonium phosphate
# 14           NaN                NaN               flocculant
# 15           NaN                NaN                 hydrogen
# 16           NaN                NaN         boiler chemicals
# 17           NaN                NaN                 fgd lime
# 18           NaN                NaN  cooling tower chemicals
# 19           NaN                NaN                    water
# 20           NaN                NaN              natural gas
# 21           NaN                NaN              electricity
# 22           NaN                NaN              electricity
# 23           NaN                NaN              electricity
# 24     21.535016            $/mmBTU                   diesel
# 25      1.873939               $/kg              adipic acid
# 26           NaN                NaN      sodium sulfate salt
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                           NaN  NaN
# 3                                                           NaN  NaN
# 4                                                use        NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17                                                          NaN  NaN
# 18                                                          NaN  NaN
# 19                                                          NaN  NaN
# 20  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 21                                          u.s. mix        NaN  NaN
# 22                                          u.s. mix        NaN  NaN
# 23                                          u.s. mix        NaN  NaN
# 24                                light duty vehicle        NaN  NaN
# 25                                                          NaN  NaN
# 26                                                          NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production            Sulfuric Acid         NaN          NaN
# 2   Fuel production                  Caustic         NaN          NaN
# 3   Fuel production                  Caustic         NaN          NaN
# 4   Fuel production         Sodium carbonate         NaN          NaN
# 5   Fuel production                  Ammonia         NaN          NaN
# 6   Fuel production                  Ammonia         NaN          NaN
# 7   Fuel production                  Ammonia         NaN          NaN
# 8   Fuel production                  Glucose         NaN          NaN
# 9   Fuel production        Corn Steep Liquor         NaN          NaN
# 10  Fuel production                 Corn oil         NaN          NaN
# 11  Fuel production           Host nutrients         NaN          NaN
# 12  Fuel production           Sulfur Dioxide         NaN          NaN
# 13  Fuel production     Diammonium Phosphate         NaN          NaN
# 14  Fuel production               Flocculant         NaN          NaN
# 15  Fuel production                 Hydrogen  119.986744     0.090052
# 16  Fuel production         Boiler Chemicals         NaN          NaN
# 17  Fuel production                 FGD Lime         NaN          NaN
# 18  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 19  Fuel production                    Water         NaN  1000.000000
# 20  Fuel production              Natural Gas   47.141814     0.776923
# 21  Fuel production              Electricity         NaN          NaN
# 22  Fuel production              Electricity         NaN          NaN
# 23  Fuel production              Electricity         NaN          NaN
# 24  Fuel production                   Diesel   43.400834   793.378565
# 25  Fuel production              Adipic Acid         NaN          NaN
# 26  Fuel production      Sodium sulfate salt         NaN          NaN
#
# [27 rows x 22 columns]

# %%
coproduct_total, coproduct_biomass, ratio, coproduct_conversion, coproduct_contribution
# Out:
# (8.019195755474314,
#  0.0548259859131487,
#  0.7273404712366012,
#  1,
#  0.039880908648187066)

# %%
total_biomass
# Out:
# 0.20107856183058295

# %%
final_process_lci
# Out:
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input  Chemicals and catalysts
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input                     Fuel
# 16                       Input  Chemicals and catalysts
# 17                       Input  Chemicals and catalysts
# 18                       Input  Chemicals and catalysts
# 19                       Input                    Water
# 20                       Input                     Fuel
# 21                       Input              Electricity
# 22                       Input              Electricity
# 23                       Input              Electricity
# 24                Main Product                     Fuel
# 25                  Co-product  Chemicals and catalysts
# 26                  Co-product  Chemicals and catalysts
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1             sulfuric acid
# 2                   caustic
# 3                   caustic
# 4          sodium carbonate                                               use
# 5                   ammonia
# 6                   ammonia
# 7                   ammonia
# 8                   glucose
# 9         corn steep liquor
# 10                 corn oil
# 11           host nutrients
# 12           sulfur dioxide
# 13     diammonium phosphate
# 14               flocculant
# 15                 hydrogen
# 16         boiler chemicals
# 17                 fgd lime
# 18  cooling tower chemicals
# 19                    water
# 20              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 21              electricity                                          u.s. mix
# 22              electricity                                          u.s. mix
# 23              electricity                                          u.s. mix
# 24         renewable diesel                                light duty vehicle
# 25          betaketoadipate                                     sequestration
# 26      sodium sulfate salt
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   182.415403     kg      0.20  Transportation to biorefinery
# 1    21.419076     kg      0.07                            NaN
# 2     3.462974     kg      0.00                            NaN
# 3     4.377970     kg      0.00                            NaN
# 4    14.593232     kg      0.00                            NaN
# 5     0.135717     kg      0.00                            NaN
# 6     0.037213     kg      0.00                            NaN
# 7     4.618864     kg      0.00                            NaN
# 8     2.871171     kg      0.00                            NaN
# 9     2.010251     kg      0.00                            NaN
# 10    0.015862     kg      0.00                            NaN
# 11    0.079976     kg      0.00                            NaN
# 12    0.019492     kg      0.00                            NaN
# 13    0.224497     kg      0.00                            NaN
# 14    0.953516     kg      0.00                            NaN
# 15    1.893415     kg      0.00                            NaN
# 16    0.001196     kg      0.00                            NaN
# 17    0.400914     kg      0.00                            NaN
# 18    0.002798     kg      0.00                            NaN
# 19  329.374702     kg      0.00                            NaN
# 20   14.009503     kg      0.00                            NaN
# 21   39.191584    kWh      0.00                            NaN
# 22    7.230217    kWh      0.00                            NaN
# 23   43.485514    kWh      0.00                            NaN
# 24    1.000000  mmBTU      0.00                            NaN
# 25    4.307970     kg      0.00                            NaN
# 26   30.230671     kg      0.00                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No    Co-product  ...
# 2                                              No    Co-product  ...
# 3                                              No          Both  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No    Co-product  ...
# 7                                              No          Both  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No  Main product  ...
# 14                                             No  Main product  ...
# 15                                             No  Main product  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No          Both  ...
# 19                                             No          Both  ...
# 20                                             No          Both  ...
# 21                                             No  Main product  ...
# 22                                             No    Co-product  ...
# 23                                             No          Both  ...
# 24                                             No  Main product  ...
# 25                                             No    Co-product  ...
# 26                                            Yes          Both  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN            sulfuric acid
# 2            NaN                NaN                  caustic
# 3            NaN                NaN                  caustic
# 4            NaN                NaN         sodium carbonate
# 5            NaN                NaN                  ammonia
# 6            NaN                NaN                  ammonia
# 7            NaN                NaN                  ammonia
# 8            NaN                NaN                  glucose
# 9            NaN                NaN        corn steep liquor
# 10           NaN                NaN                 corn oil
# 11           NaN                NaN           host nutrients
# 12           NaN                NaN           sulfur dioxide
# 13           NaN                NaN     diammonium phosphate
# 14           NaN                NaN               flocculant
# 15           NaN                NaN                 hydrogen
# 16           NaN                NaN         boiler chemicals
# 17           NaN                NaN                 fgd lime
# 18           NaN                NaN  cooling tower chemicals
# 19           NaN                NaN                    water
# 20           NaN                NaN              natural gas
# 21           NaN                NaN              electricity
# 22           NaN                NaN              electricity
# 23           NaN                NaN              electricity
# 24     21.535016            $/mmBTU                   diesel
# 25      1.873939               $/kg              adipic acid
# 26           NaN                NaN      sodium sulfate salt
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                           NaN  NaN
# 3                                                           NaN  NaN
# 4                                                use        NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17                                                          NaN  NaN
# 18                                                          NaN  NaN
# 19                                                          NaN  NaN
# 20  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 21                                          u.s. mix        NaN  NaN
# 22                                          u.s. mix        NaN  NaN
# 23                                          u.s. mix        NaN  NaN
# 24                                light duty vehicle        NaN  NaN
# 25                                                          NaN  NaN
# 26                                                          NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production            Sulfuric Acid         NaN          NaN
# 2   Fuel production                  Caustic         NaN          NaN
# 3   Fuel production                  Caustic         NaN          NaN
# 4   Fuel production         Sodium carbonate         NaN          NaN
# 5   Fuel production                  Ammonia         NaN          NaN
# 6   Fuel production                  Ammonia         NaN          NaN
# 7   Fuel production                  Ammonia         NaN          NaN
# 8   Fuel production                  Glucose         NaN          NaN
# 9   Fuel production        Corn Steep Liquor         NaN          NaN
# 10  Fuel production                 Corn oil         NaN          NaN
# 11  Fuel production           Host nutrients         NaN          NaN
# 12  Fuel production           Sulfur Dioxide         NaN          NaN
# 13  Fuel production     Diammonium Phosphate         NaN          NaN
# 14  Fuel production               Flocculant         NaN          NaN
# 15  Fuel production                 Hydrogen  119.986744     0.090052
# 16  Fuel production         Boiler Chemicals         NaN          NaN
# 17  Fuel production                 FGD Lime         NaN          NaN
# 18  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 19  Fuel production                    Water         NaN  1000.000000
# 20  Fuel production              Natural Gas   47.141814     0.776923
# 21  Fuel production              Electricity         NaN          NaN
# 22  Fuel production              Electricity         NaN          NaN
# 23  Fuel production              Electricity         NaN          NaN
# 24  Fuel production                   Diesel   43.400834   793.378565
# 25  Fuel production              Adipic Acid         NaN          NaN
# 26  Fuel production      Sodium sulfate salt         NaN          NaN
#
# [27 rows x 22 columns]

# %%
coproduct_contribution
# Out:
# 0.039880908648187066

# %%
biomass_df
# Out:
#                          Type Category     Resource End Use  Input Amount  \
# 0  Input from Another Process  Biomass  corn stover            182.415403
#
#   Unit  Moisture               Previous Process  \
# 0   kg       0.2  Transportation to biorefinery
#
#   Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                             No          Both  ...
#
#    Incumbent Product  End Use of Incumbent Product  Subprocess Note  \
# 0        corn stover                                       NaN  NaN
#
#            Process Incumbent Resource        LHV  Density Primary Unit  \
# 0  Fuel production        Corn Stover  17.114708      NaN          ton
#
#      Amount
# 0  0.201079
#
# [1 rows x 24 columns]

# %%
# res_new = res_new_with_incumbent[
#         ~res_new_with_incumbent["Pathway"].str.contains("Incumbent")
#     ]

# res_new['CO2_mmbtu'] = res_new['CO2_Sum'] * energy.loc['MJ', 'mmBTU']

# temp = res_new.loc[res_new['Process']=='Fuel production', ['Type', 'Resource', 'End Use', 'CO2_Sum', 'CO2', 'CO2_mmbtu', 'Amount', 'Unit', 'Primary Unit', 'Input Amount']]

# temp['CO2_mmbtu'].sum() - 74927.074009

# temp

# %%
t2 = format_input(lci_mapping['Fuel production'])
t2[['Type', 'Resource', 'Amount', 'Product Train']]
# Out:
#                           Type                 Resource      Amount  \
# 0   Input from Another Process              corn stover  182.415403
# 1                        Input            sulfuric acid   21.419076
# 2                        Input                  caustic    3.462974
# 3                        Input                  caustic    4.377970
# 4                        Input         sodium carbonate   14.593232
# 5                        Input                  ammonia    0.135717
# 6                        Input                  ammonia    0.037213
# 7                        Input                  ammonia    4.618864
# 8                        Input                  glucose    2.871171
# 9                        Input        corn steep liquor    2.010251
# 10                       Input                 corn oil    0.015862
# 11                       Input           host nutrients    0.079976
# 12                       Input           sulfur dioxide    0.019492
# 13                       Input     diammonium phosphate    0.224497
# 14                       Input               flocculant    0.953516
# 15                       Input                 hydrogen    1.893415
# 16                       Input         boiler chemicals    0.001196
# 17                       Input                 fgd lime    0.400914
# 18                       Input  cooling tower chemicals    0.002798
# 19                       Input                    water  329.374702
# 20                       Input              natural gas   14.009503
# 21                       Input              electricity   39.191584
# 22                       Input              electricity    7.230217
# 23                       Input              electricity   43.485514
# 24                Main Product         renewable diesel    1.000000
# 25                  Co-product          betaketoadipate    4.307970
# 26                  Co-product      sodium sulfate salt   30.230671
#
#    Product Train
# 0           Both
# 1     Co-product
# 2     Co-product
# 3           Both
# 4           Both
# 5   Main product
# 6     Co-product
# 7           Both
# 8   Main product
# 9   Main product
# 10  Main product
# 11  Main product
# 12  Main product
# 13  Main product
# 14  Main product
# 15  Main product
# 16          Both
# 17          Both
# 18          Both
# 19          Both
# 20          Both
# 21  Main product
# 22    Co-product
# 23          Both
# 24  Main product
# 25    Co-product
# 26          Both

# %%
t = allocation(format_input(lci_mapping['Fuel production']), 'value')
t[['Resource', 'Amount', 'Product Train']]
# Out:
#                    Resource      Amount Product Train
# 0               corn stover  132.678105          Both
# 1                   caustic    3.184275          Both
# 2          sodium carbonate   10.614248          Both
# 3                   ammonia    0.135717  Main product
# 4                   ammonia    3.359487          Both
# 5                   glucose    2.871171  Main product
# 6         corn steep liquor    2.010251  Main product
# 7                  corn oil    0.015862  Main product
# 8            host nutrients    0.079976  Main product
# 9            sulfur dioxide    0.019492  Main product
# 10     diammonium phosphate    0.224497  Main product
# 11               flocculant    0.953516  Main product
# 12                 hydrogen    1.893415  Main product
# 13         boiler chemicals    0.000870          Both
# 14                 fgd lime    0.291601          Both
# 15  cooling tower chemicals    0.002035          Both
# 16                    water  239.567551          Both
# 17              natural gas   10.189678          Both
# 18              electricity   39.191584  Main product
# 19              electricity   31.628774          Both
# 20      sodium sulfate salt  -21.987990          Both
# 21         renewable diesel    1.000000  Main product

# %%
def allocation2(df, basis="mass"):
    """
    Calcuate the LCI data after allocation

    Parameters:
        df: the original LCI dataframe that contains inputs and outputs
        basis: the basis for process-level allocation. Must be one of the following: "mass", "energy", or "value".
    """
    ratio = calculate_allocation_ratio(df, basis)
    print(ratio)

    not_allocated = (df["Type"] == "Main Product") | (
        (df["Type"] == "Co-product")
        & (df["Always Use Displacement Method for Co-Product?"] == "No")
        & (
            df["Amount"] > 0
        )  # if amount is less than zero, it means displacement method has been applied (for example, if displacement method is used for a process)
    )
    allocated = df[~not_allocated].copy()

    # allocated['Ratio'] = allocated
    allocated["Amount"] = allocated["Amount"] * allocated["Product Train"].fillna(
        "Both"
    ).map({"Both": ratio, "Co-product": 0, "Main product": 1}).fillna(ratio)

    allocated = allocated[allocated["Amount"] != 0]
    allocated.loc[
        (allocated["Type"] == "Co-product") & (allocated["Amount"] > 0), "Amount"
    ] = -allocated.loc[
        (allocated["Type"] == "Co-product") & (allocated["Amount"] > 0), "Amount"
    ]  # Only for the co-products for which displacement methods should but have not been applied

    return pd.concat(
        [allocated, df[df["Type"].isin(["Main Product"])]], ignore_index=True
    )

# %%
allocation2(t2, 'value')
# Out:
# 0.7273404712346352
#                           Type                 Category  \
# 0   Input from Another Process                  Biomass
# 1                        Input  Chemicals and catalysts
# 2                        Input  Chemicals and catalysts
# 3                        Input  Chemicals and catalysts
# 4                        Input  Chemicals and catalysts
# 5                        Input  Chemicals and catalysts
# 6                        Input  Chemicals and catalysts
# 7                        Input  Chemicals and catalysts
# 8                        Input  Chemicals and catalysts
# 9                        Input  Chemicals and catalysts
# 10                       Input  Chemicals and catalysts
# 11                       Input  Chemicals and catalysts
# 12                       Input                     Fuel
# 13                       Input  Chemicals and catalysts
# 14                       Input  Chemicals and catalysts
# 15                       Input  Chemicals and catalysts
# 16                       Input                    Water
# 17                       Input                     Fuel
# 18                       Input              Electricity
# 19                       Input              Electricity
# 20                  Co-product  Chemicals and catalysts
# 21                Main Product                     Fuel
#
#                    Resource                                           End Use  \
# 0               corn stover
# 1                   caustic
# 2          sodium carbonate                                               use
# 3                   ammonia
# 4                   ammonia
# 5                   glucose
# 6         corn steep liquor
# 7                  corn oil
# 8            host nutrients
# 9            sulfur dioxide
# 10     diammonium phosphate
# 11               flocculant
# 12                 hydrogen
# 13         boiler chemicals
# 14                 fgd lime
# 15  cooling tower chemicals
# 16                    water
# 17              natural gas  utility/ industrial boiler (>100 mmbtu/hr input)
# 18              electricity                                          u.s. mix
# 19              electricity                                          u.s. mix
# 20      sodium sulfate salt
# 21         renewable diesel                                light duty vehicle
#
#         Amount   Unit  Moisture               Previous Process  \
# 0   132.678105     kg       0.2  Transportation to biorefinery
# 1     3.184275     kg       0.0                            NaN
# 2    10.614248     kg       0.0                            NaN
# 3     0.135717     kg       0.0                            NaN
# 4     3.359487     kg       0.0                            NaN
# 5     2.871171     kg       0.0                            NaN
# 6     2.010251     kg       0.0                            NaN
# 7     0.015862     kg       0.0                            NaN
# 8     0.079976     kg       0.0                            NaN
# 9     0.019492     kg       0.0                            NaN
# 10    0.224497     kg       0.0                            NaN
# 11    0.953516     kg       0.0                            NaN
# 12    1.893415     kg       0.0                            NaN
# 13    0.000870     kg       0.0                            NaN
# 14    0.291601     kg       0.0                            NaN
# 15    0.002035     kg       0.0                            NaN
# 16  239.567551     kg       0.0                            NaN
# 17   10.189678     kg       0.0                            NaN
# 18   39.191584    kWh       0.0                            NaN
# 19   31.628774    kWh       0.0                            NaN
# 20  -21.987990     kg       0.0                            NaN
# 21    1.000000  mmBTU       0.0                            NaN
#
#    Always Use Displacement Method for Co-Product? Product Train  ...  \
# 0                                              No          Both  ...
# 1                                              No          Both  ...
# 2                                              No          Both  ...
# 3                                              No  Main product  ...
# 4                                              No          Both  ...
# 5                                              No  Main product  ...
# 6                                              No  Main product  ...
# 7                                              No  Main product  ...
# 8                                              No  Main product  ...
# 9                                              No  Main product  ...
# 10                                             No  Main product  ...
# 11                                             No  Main product  ...
# 12                                             No  Main product  ...
# 13                                             No          Both  ...
# 14                                             No          Both  ...
# 15                                             No          Both  ...
# 16                                             No          Both  ...
# 17                                             No          Both  ...
# 18                                             No  Main product  ...
# 19                                             No          Both  ...
# 20                                            Yes          Both  ...
# 21                                             No  Main product  ...
#
#     Market Price  Market Price Unit        Incumbent Product  \
# 0            NaN                NaN              corn stover
# 1            NaN                NaN                  caustic
# 2            NaN                NaN         sodium carbonate
# 3            NaN                NaN                  ammonia
# 4            NaN                NaN                  ammonia
# 5            NaN                NaN                  glucose
# 6            NaN                NaN        corn steep liquor
# 7            NaN                NaN                 corn oil
# 8            NaN                NaN           host nutrients
# 9            NaN                NaN           sulfur dioxide
# 10           NaN                NaN     diammonium phosphate
# 11           NaN                NaN               flocculant
# 12           NaN                NaN                 hydrogen
# 13           NaN                NaN         boiler chemicals
# 14           NaN                NaN                 fgd lime
# 15           NaN                NaN  cooling tower chemicals
# 16           NaN                NaN                    water
# 17           NaN                NaN              natural gas
# 18           NaN                NaN              electricity
# 19           NaN                NaN              electricity
# 20           NaN                NaN      sodium sulfate salt
# 21     21.535016            $/mmBTU                   diesel
#
#                         End Use of Incumbent Product Subprocess Note  \
# 0                                                           NaN  NaN
# 1                                                           NaN  NaN
# 2                                                use        NaN  NaN
# 3                                                           NaN  NaN
# 4                                                           NaN  NaN
# 5                                                           NaN  NaN
# 6                                                           NaN  NaN
# 7                                                           NaN  NaN
# 8                                                           NaN  NaN
# 9                                                           NaN  NaN
# 10                                                          NaN  NaN
# 11                                                          NaN  NaN
# 12                                                          NaN  NaN
# 13                                                          NaN  NaN
# 14                                                          NaN  NaN
# 15                                                          NaN  NaN
# 16                                                          NaN  NaN
# 17  utility/ industrial boiler (>100 mmbtu/hr input)        NaN  NaN
# 18                                          u.s. mix        NaN  NaN
# 19                                          u.s. mix        NaN  NaN
# 20                                                          NaN  NaN
# 21                                light duty vehicle        NaN  NaN
#
#             Process       Incumbent Resource         LHV      Density
# 0   Fuel production              Corn Stover   17.114708          NaN
# 1   Fuel production                  Caustic         NaN          NaN
# 2   Fuel production         Sodium carbonate         NaN          NaN
# 3   Fuel production                  Ammonia         NaN          NaN
# 4   Fuel production                  Ammonia         NaN          NaN
# 5   Fuel production                  Glucose         NaN          NaN
# 6   Fuel production        Corn Steep Liquor         NaN          NaN
# 7   Fuel production                 Corn oil         NaN          NaN
# 8   Fuel production           Host nutrients         NaN          NaN
# 9   Fuel production           Sulfur Dioxide         NaN          NaN
# 10  Fuel production     Diammonium Phosphate         NaN          NaN
# 11  Fuel production               Flocculant         NaN          NaN
# 12  Fuel production                 Hydrogen  119.986744     0.090052
# 13  Fuel production         Boiler Chemicals         NaN          NaN
# 14  Fuel production                 FGD Lime         NaN          NaN
# 15  Fuel production  Cooling Tower Chemicals         NaN          NaN
# 16  Fuel production                    Water         NaN  1000.000000
# 17  Fuel production              Natural Gas   47.141814     0.776923
# 18  Fuel production              Electricity         NaN          NaN
# 19  Fuel production              Electricity         NaN          NaN
# 20  Fuel production      Sodium sulfate salt         NaN          NaN
# 21  Fuel production                   Diesel   43.400834   793.378565
#
# [22 rows x 22 columns]

# %%
temp3[['Resource', 'Input Amount', 'Amount', 'Unit', 'Primary Unit']]
# Out:
#            Resource  Input Amount    Amount   Unit Primary Unit
# 0       corn stover           0.4  0.000441    ton          ton
# 1  renewable diesel           1.0  0.041136  mmBTU        mmBTU

# %%
0.000441/0.038547
# Out:
# 0.011440579033387813

# %%
temp3
# Out:
#            Type Category          Resource             End Use  Input Amount  \
# 0         Input  Biomass       corn stover                               0.4
# 1  Main Product     Fuel  renewable diesel  light duty vehicle           1.0
#
#     Unit  Moisture Previous Process  \
# 0    ton       0.2    Preprocessing
# 1  mmBTU       0.0              NaN
#
#   Always Use Displacement Method for Co-Product? Product Train  ...     PM2.5  \
# 0                                             No          Both  ...  6.988316
# 1                                             No          Both  ...  1.567383
#
#   Petroleum, Btu        SOx Total energy, Btu        VOC  \
# 0   66135.304478  58.328462     362403.007572  24.470884
# 1       0.000000   0.000000          0.000000  33.424434
#
#    Water consumption: gallons Primary Unit  CO2 (w/ C in VOC & CO)  \
# 0                   59.889275          ton            22892.926773
# 1                    0.000000        mmBTU            63460.451046
#
#            GHG    Amount
# 0  2687.052565  0.000441
# 1    41.436049  0.038547
#
# [2 rows x 39 columns]

# %%
unit_conversion(temp.loc[1])
# Out:
# 0.03854677892255507

# %%
mass_to_energy(temp.loc[1, 'Input Amount'], temp.loc[1, 'Unit'], temp.loc[1, 'LHV']) * energy.loc[temp.loc[1, 'Primary Unit'], "MJ"]
# Out:
# 0.03854677892255507

# %%
def unit_conversion(series):
    "Perform unit operation for each LCI data entry"
    input_unit = series["Unit"]
    amount = series["Input Amount"]
    density = series["Density"]
    lhv = series["LHV"]
    output_unit = series["Primary Unit"]

    if units[input_unit] != units[output_unit]:
        if (
            output_unit in volume_units
        ):  # Ouput is vlume, them input must be mass, because only water has output unit of volume. Modified from origin
            m3_amount = amount * mass.loc["kg", input_unit] / density
            return m3_amount * volume.loc[output_unit, "m3"]
        elif input_unit in volume_units:  # Input unit is volume
            kg_amount = volume_to_mass(amount, input_unit, density)  # Amount in kg
            if (
                output_unit in mass_units
            ):  # Input unit is volume and output unit is mass
                return kg_amount * mass.loc[output_unit, "kg"]
            else:  # Input unit is volume and output unit is energy
                return kg_amount * lhv * energy.loc[output_unit, "MJ"]
        elif output_unit in energy_units:  # output is energy and input is mass
            return (
                mass_to_energy(amount, input_unit, lhv) * energy.loc[output_unit, "MJ"]
            )
        else:  # output is mass and input is energy
            return energy_to_mass(amount, input_unit, lhv) * mass.loc[output_unit, "kg"]
    elif input_unit in mass_units:  # Both input and output are mass unit.
        return amount * mass.loc[output_unit, input_unit]
    elif input_unit in energy_units:  # Both input and output are energy unit.
        return amount * energy.loc[output_unit, input_unit]
    else:  # Both input and output are volume unit.
        return amount * volume.loc[output_unit, input_unit]

# %%
temp2[['Resource', 'Input Amount', 'Unit', 'Amount', 'Primary Unit']]
# Out:
#            Resource  Input Amount Unit    Amount Primary Unit
# 0       corn stover           0.4   kg  0.000441          ton
# 1  renewable diesel           1.0   kg  0.038547        mmBTU

# %%
temp[['Resource', 'Amount', 'Input Amount', 'Unit', 'Primary Unit', "GHG", "GHG_Sum"]]
# Out:
#            Resource     Amount  Input Amount   Unit Primary Unit  \
# 0       corn stover   0.011439           0.4    ton          ton
# 1  renewable diesel   1.000000           1.0  mmBTU        mmBTU
# 0            diesel  25.942505           1.0  mmBTU        mmBTU
#
#             GHG      GHG_Sum
# 0   2687.052565     0.029132
# 1     41.436049     0.039274
# 0  94636.902577  2327.003169

# %%
res[['Resource', 'Amount', 'Input Amount', 'Unit', 'Primary Unit', "GHG", "GHG_Sum"]]
# Out:
#            Resource    Amount  Input Amount   Unit Primary Unit          GHG  \
# 0       corn stover  0.011439           0.4    ton          ton  2687.052565
# 1  renewable diesel  1.000000           1.0  mmBTU        mmBTU    41.436049
#
#     GHG_Sum
# 0  0.029132
# 1  0.039274

# %%
temp.loc[0, 'CO2']*temp.loc[0, 'Amount']
# Out:
# 0     0.010037
# 0    12.944332
# dtype: float64

# %%
temp.loc[0, 'CO2']
# Out:
# 0    22763.019076
# 0    12944.332260
# Name: CO2, dtype: float64

# %%
biomass_main = res_new.loc[~(res_new['Pathway'].str.contains("Incumbent"))&(res_new['Type'].str.contains('Input'))&(res_new['Category']=='Biomass'), 'Amount'].sum()
biomass_coproduct = coproduct_res.loc[~(coproduct_res['Pathway'].str.contains("Incumbent"))&(coproduct_res['Type'].str.contains('Input'))&(coproduct_res['Category']=='Biomass'), 'Amount'].sum()

# %%
df = format_input(lci_mapping['Fuel Production'])
ratio = calculate_allocation_ratio(df, "mass")

# %%
ratio
# Out:
# 0.079418132828804

# %%
main_conversion = 1
coproduct_conversion = 1

if overall_lci.loc[overall_lci['Type']=='Main Product', 'Category'].values[0] in ['Electricity', 'Fuel']:
    main_conversion = energy.loc['MJ', 'mmBTU']

if coproduct_lci.loc[coproduct_lci['Type']=='Main Product', 'Category'].values[0] in ['Electricity', 'Fuel']:
    coproduct_conversion = energy.loc['MJ', 'mmBTU']

# %%
main_conversion
# Out:
# 1055.05585

# %%
coproduct_conversion
# Out:
# 1055.05585

# %%
biorefinery_res = main_product_total * main_conversion / biomass_main * ratio + coproduct_total * coproduct_conversion / biomass_coproduct * (1 - ratio)

# %%
biorefinery_res
# Out:
# 2348855.248664811

# %%
energy
# Out:
#                    J            kJ              MJ           Wh           kWh  \
# Energy
# J       1.000000e+00  1.000000e+03  1000000.000000  3600.000000  3.600000e+06
# kJ      1.000000e-03  1.000000e+00     1000.000000     3.600000  3.600000e+03
# MJ      1.000000e-06  1.000000e-03        1.000000     0.003600  3.600000e+00
# Wh      2.777778e-04  2.777778e-01      277.777778     1.000000  1.000000e+03
# kWh     2.777778e-07  2.777778e-04        0.277778     0.001000  1.000000e+00
# BTU     9.478171e-04  9.478171e-01      947.817123     3.412142  3.412142e+03
# mmBTU   9.478171e-10  9.478171e-07        0.000948     0.000003  3.412142e-03
# hph     3.725061e-07  3.725061e-04        0.372506     0.001341  1.341022e+00
#
#                 BTU         mmBTU           hph
# Energy
# J       1055.055850  1.055056e+09  2.684520e+06
# kJ         1.055056  1.055056e+06  2.684520e+03
# MJ         0.001055  1.055056e+03  2.684520e+00
# Wh         0.293071  2.930711e+05  7.456999e+02
# kWh        0.000293  2.930711e+02  7.456999e-01
# BTU        1.000000  1.000000e+06  2.544434e+03
# mmBTU      0.000001  1.000000e+00  2.544434e-03
# hph        0.000393  3.930148e+02  1.000000e+00

# %%
di = {'a': 1, 'c': 2, 'd': 3, 'b': 5}

# %%
di.keys()
# Out:
# dict_keys(['a', 'c', 'd', 'b'])

# %%
for key, value in di.items():
    print(key, value)
# Out:
# a 1
# c 2
# d 3
# b 5

# %%
from collections import OrderedDict
 
print("This is a Dict:\n")
d = {}
d['a'] = 1
d['b'] = 2
d['c'] = 3
d['d'] = 4
 
for key, value in d.items():
    print(key, value)
# Out:
# This is a Dict:
#
# a 1
# b 2
# c 3
# d 4

# %%
l = [1,2,3]

# %%
l[:-1:]
# Out:
# [1, 2]

# %%
l[::-1]
# Out:
# [3, 2, 1]

# %%
import pandas as pd
a = pd.DataFrame({'a': ['a', 'b', 'temp']})

# %%
a
# Out:
#       a
# 0     a
# 1     b
# 2  temp

# %%
a['a'].map({'a': 'B'})
# Out:
# 0      B
# 1    NaN
# 2    NaN
# Name: a, dtype: object

# %%
a
# Out:
#       a
# 0     a
# 1     b
# 2  temp

# %%
a['Resource'] = ['ccc','bbb','k co2']

# %%
a
# Out:
#       a Resource
# 0     a      ccc
# 1     b      bbb
# 2  temp    k co2

# %%
a['Resource'].str.replace('co2', "CO2")
# Out:
# 0      ccc
# 1      bbb
# 2    k CO2
# Name: Resource, dtype: object
